# %%
#import library
import pandas as pd 
import numpy as np
import tweepy
import csv
import re

# menghitung sentimen kata-kata yang berbahasa inggris
from textblob import TextBlob 
from datetime import datetime

# %%
access_token ="258199811-llOno7xx7uvYJuoGQNvrXAtHsgeeDJDQRDhCZb0Y"
access_token_secret ="bD4LwtQ2OtmBuKCnTXR4A5HQYTqqWH3IWEhbAfHrysBax"
api_key ="oTozcNGFucJwfqL6TEfqQtaWi"
api_key_secret ="6cRNX3IHJIStqfWGdcv2PMM6B625VLaDxk34vM3BT9EpIsHKje"

auth = tweepy.OAuthHandler(api_key, api_key_secret)
auth.set_access_token(access_token,access_token_secret)
api = tweepy.API(auth)

# %% [markdown]
# **Keyword vaksinasi covid**

# %%
# Februari 2022
feb23 = api.search(q='vaksinasi covid', lang='id', count=100,since='2022-02-22',until='2022-02-23')
feb22 = api.search(q='vaksinasi covid', lang='id', count=100,since='2022-02-13',until='2022-02-22')
feb21 = api.search(q='vaksinasi covid', lang='id', count=100,since='2022-02-20',until='2022-02-21')
feb20 = api.search(q='vaksinasi covid', lang='id', count=100,since='2022-02-19',until='2021-02-20')
feb19 = api.search(q='vaksinasi covid', lang='id', count=100,since='2022-02-18',until='2021-02-19')
feb18 = api.search(q='vaksinasi covid', lang='id', count=100,since='2022-02-17',until='2021-02-18')
feb17 = api.search(q='vaksinasi covid', lang='id', count=100,since='2022-02-16',until='2021-02-17')
feb16 = api.search(q='vaksinasi covid', lang='id', count=100,since='2022-02-15',until='2021-02-16')
feb15 = api.search(q='vaksinasi covid', lang='id', count=100,since='2022-02-14',until='2021-02-15')
feb14 = api.search(q='vaksinasi covid', lang='id', count=100,since='2022-02-13',until='2021-02-14')

# %%
#Merge List
hasilSearch1 = feb23+feb22+feb21
hasilSearch2 = feb20+feb19+feb18
hasilSearch3 = feb17+feb16+feb15
hasilSearch4 = feb14
hasilSearch = hasilSearch1+hasilSearch2+hasilSearch3+hasilSearch4

# %%
# hasilSearch

# %%
hasilAnalisis = []

for tweet in hasilSearch:
    tweet_properties = {}
    tweet_properties['tanggal_tweet'] = tweet.created_at
    tweet_properties['pengguna'] = tweet.user.screen_name
    tweet_properties['tweet'] = tweet.text
    tweet_bersih = ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",tweet.text).split())
    hasilAnalisis.append(tweet_properties)

tanggal_tweet=[]
pengguna=[]
tweet=[]

for i in range (0,len(hasilAnalisis)):
    tanggal_tweet.append(hasilAnalisis[i]['tanggal_tweet'])
    pengguna.append(hasilAnalisis[i]['pengguna'])
    tweet.append(hasilAnalisis[i]['tweet'])

februari_vaksinasi = pd.DataFrame({'tanggal_tweet':tanggal_tweet,'pengguna':pengguna,'tweet':tweet})
februari_vaksinasi
# Out:
#           tanggal_tweet  ...                                              tweet
# 0   2022-02-22 23:56:59  ...  Vaksinasi Melindungi Diri Kita Dari Covid-19. ...
# 1   2022-02-22 23:55:14  ...  Memperlancar pelaksanaan vaksinasi, ketahuilah...
# 2   2022-02-22 23:53:03  ...  Memperlancar pelaksanaan vaksinasi, ketahuilah...
# 3   2022-02-22 23:51:06  ...  RT @ProfesorZubairi: Kenapa Indonesia belum bi...
# 4   2022-02-22 23:48:02  ...  KH. Embay Mulya Syarief Mengajak Ponpes, Ulama...
# ..                  ...  ...                                                ...
# 295 2022-02-20 16:29:42  ...  RT @KKMPutrajaya: Tempoh Isolasi Bagi Kes COVI...
# 296 2022-02-20 16:29:09  ...  RT @KemenkesRI: #RilisSehat\n\nKasus Konfirmas...
# 297 2022-02-20 16:23:44  ...  RT @infoPKU: Info vaksinasi Covid-19, Senin (2...
# 298 2022-02-20 16:23:19  ...  [ UPDATE STATISTIK COVID-19 DI KOTA BANDUNG PE...
# 299 2022-02-20 16:22:37  ...  Info vaksinasi Covid-19, Senin (21/2/2022)\n\n...
#
# ...

# %% [markdown]
# **keyword vaksin covid-19**

# %%
# Februari 2022
feb23 = api.search(q='vaksin covid-19', lang='id', count=100,since='2022-02-22',until='2022-02-23')
feb22 = api.search(q='vaksin covid-19', lang='id', count=100,since='2022-02-13',until='2022-02-22')
feb21 = api.search(q='vaksin covid-19', lang='id', count=100,since='2022-02-20',until='2022-02-21')
feb20 = api.search(q='vaksin covid-19', lang='id', count=100,since='2022-02-19',until='2021-02-20')
feb19 = api.search(q='vaksin covid-19', lang='id', count=100,since='2022-02-18',until='2021-02-19')
feb18 = api.search(q='vaksin covid-19', lang='id', count=100,since='2022-02-17',until='2021-02-18')
feb17 = api.search(q='vaksin covid-19', lang='id', count=100,since='2022-02-16',until='2021-02-17')
feb16 = api.search(q='vaksin covid-19', lang='id', count=100,since='2022-02-15',until='2021-02-16')
feb15 = api.search(q='vaksin covid-19', lang='id', count=100,since='2022-02-14',until='2021-02-15')
feb14 = api.search(q='vaksin covid-19', lang='id', count=100,since='2022-02-13',until='2021-02-14')

# %%
#Merge List
hasilSearch1 = feb23+feb22+feb21
hasilSearch2 = feb20+feb19+feb18
hasilSearch3 = feb17+feb16+feb15
hasilSearch4 = feb14
hasilSearch = hasilSearch1+hasilSearch2+hasilSearch3+hasilSearch4
# hasilSearch

# %%
hasilAnalisis = []

for tweet in hasilSearch:
    tweet_properties = {}
    tweet_properties['tanggal_tweet'] = tweet.created_at
    tweet_properties['pengguna'] = tweet.user.screen_name
    tweet_properties['tweet'] = tweet.text
    tweet_bersih = ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",tweet.text).split())
    hasilAnalisis.append(tweet_properties)

tanggal_tweet=[]
pengguna=[]
tweet=[]

for i in range (0,len(hasilAnalisis)):
    tanggal_tweet.append(hasilAnalisis[i]['tanggal_tweet'])
    pengguna.append(hasilAnalisis[i]['pengguna'])
    tweet.append(hasilAnalisis[i]['tweet'])

februari_vaksincovid19 = pd.DataFrame({'tanggal_tweet':tanggal_tweet,'pengguna':pengguna,'tweet':tweet})
februari_vaksincovid19
# Out:
#           tanggal_tweet  ...                                              tweet
# 0   2022-02-22 23:55:50  ...  RT @BuletinTV3: COVID-19 | Hanya jemaah lengka...
# 1   2022-02-22 23:53:21  ...  RT @Khairykj: MIS-C yang boleh berlaku akibat ...
# 2   2022-02-22 23:50:22  ...  RT @Khairykj: MIS-C yang boleh berlaku akibat ...
# 3   2022-02-22 23:49:45  ...  RT @khairul_hafidz: Rumusan:\n1. Kanak-kanak d...
# 4   2022-02-22 23:47:43  ...  waspada penyebaran covid-19 varian omicron yu ...
# ..                  ...  ...                                                ...
# 295 2022-02-20 15:49:04  ...  Vaksin Covid-19 untuk Anak, Indikator: Masyara...
# 296 2022-02-20 15:47:04  ...  Vaksin Covid-19 untuk Anak, Indikator: Masyara...
# 297 2022-02-20 15:46:20  ...  Menit terakhir dari virus corona, siaran langs...
# 298 2022-02-20 15:46:10  ...  RT @beritartm: 20 Februari - Kadar kematian pe...
# 299 2022-02-20 15:43:35  ...  20 Februari - Kadar kematian pesakit COVID-19 ...
#
# ...

# %%
# mount process for access google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# export februari_vaksinasi_300 to google drive
# februari_vaksinasi.to_excel('/content/drive/MyDrive/SKRIPSI_TEXT_MINING/februari_vaksinasi_300.xlsx',index=False)
# februari_vaksincovid19.to_excel('/content/drive/MyDrive/SKRIPSI_TEXT_MINING/februari_vaksincovid19_300.xlsx',index=False)

# %% [markdown]
# -----------------------------

# %% [markdown]
# ## **1. Crawling data september 2021 - oktober 2021**
# > **30/09/21 - 07/10/21**

# %%
access_token ="258199811-llOno7xx7uvYJuoGQNvrXAtHsgeeDJDQRDhCZb0Y"
access_token_secret ="bD4LwtQ2OtmBuKCnTXR4A5HQYTqqWH3IWEhbAfHrysBax"
api_key ="oTozcNGFucJwfqL6TEfqQtaWi"
api_key_secret ="6cRNX3IHJIStqfWGdcv2PMM6B625VLaDxk34vM3BT9EpIsHKje"

auth = tweepy.OAuthHandler(api_key, api_key_secret)
auth.set_access_token(access_token,access_token_secret)
api = tweepy.API(auth)

# %%
#Septmber - Oktober 2021
okt06 = api.search(q='vaksinasi', lang='id', count=100,since='2021-10-06',until='2021-10-07')
okt05 = api.search(q='vaksinasi', lang='id', count=100,since='2021-10-05',until='2021-10-06')
okt04 = api.search(q='vaksinasi', lang='id', count=100,since='2021-10-04',until='2021-10-05')
okt03 = api.search(q='vaksinasi', lang='id', count=100,since='2021-10-03',until='2021-10-04')
okt02 = api.search(q='vaksinasi', lang='id', count=100,since='2021-10-02',until='2021-10-03')
okt01 = api.search(q='vaksinasi', lang='id', count=100,since='2021-10-01',until='2021-10-02')
sep30 = api.search(q='vaksinasi', lang='id', count=100,since='2021-09-30',until='2021-10-01')

# %%
#Merge List
hasilSearch1 = okt06+okt05+okt04
hasilSearch2 = okt03+okt02+okt01+sep30
hasilSearch = hasilSearch1+hasilSearch2

# %%
hasilAnalisis = []

for tweet in hasilSearch:
    tweet_properties = {}
    tweet_properties['tanggal_tweet'] = tweet.created_at
    tweet_properties['pengguna'] = tweet.user.screen_name
    tweet_properties['tweet'] = tweet.text
    tweet_bersih = ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",tweet.text).split())
    hasilAnalisis.append(tweet_properties)

tanggal_tweet=[]
pengguna=[]
tweet=[]

for i in range (0,len(hasilAnalisis)):
    tanggal_tweet.append(hasilAnalisis[i]['tanggal_tweet'])
    pengguna.append(hasilAnalisis[i]['pengguna'])
    tweet.append(hasilAnalisis[i]['tweet'])

oktober_1000 = pd.DataFrame({'tanggal_tweet':tanggal_tweet,'pengguna':pengguna,'tweet':tweet})

# %%
oktober_1000
# Out:
#           tanggal_tweet  ...                                              tweet
# 0   2021-10-07 23:59:59  ...  RT @KKMPutrajaya: Selepas rentas negeri dibena...
# 1   2021-10-07 23:59:56  ...  Jaga Vaksinasi Covid-19 di Puskesmas Tangkilin...
# 2   2021-10-07 23:59:21  ...  RT @KKMPutrajaya: mengawal pergerakan mereka y...
# 3   2021-10-07 23:58:22  ...  Vaksinasi untuk Menyelamatkan diri sendiri dan...
# 4   2021-10-07 23:58:14  ...  Vaksinasi penting dilakukan untuk meningkatkan...
# ..                  ...  ...                                                ...
# 795 2021-09-30 23:33:55  ...  RT @jpagov: SIARAN MEDIA : PENETAPAN SYARAT VA...
# 796 2021-09-30 23:33:49  ...  Dengan Kos Vaksinasi 2 Kali Ganda Kalau Tidak ...
# 797 2021-09-30 23:33:45  ...  DIPERPANJANG...!!!\n\nKanggo Kanca-Kanca Wong ...
# 798 2021-09-30 23:33:35  ...  RT @501Awani: Keadaan pesakit adalah bergejala...
# 799 2021-09-30 23:33:18  ...  Dirbinmas Polda DIY Kombes Pol. Drs. Anjar Gun...
#
# ...

# %%
#mount process for access google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#export oktober_1000 to google drive
# oktober_1000.to_excel('/content/drive/MyDrive/SKRIPSI_TEXT_MINING/oktober_1000.xlsx',index=False)

# %%
# cek data hasil export
import pandas as pd
import numpy as np

cek_oktober_1000 = pd.read_excel('/content/drive/MyDrive/SKRIPSI_TEXT_MINING/oktober_1000.xlsx')
cek_oktober_1000
# Out:
#           tanggal_tweet  ...                                              tweet
# 0   2021-10-07 23:59:59  ...  RT @KKMPutrajaya: Selepas rentas negeri dibena...
# 1   2021-10-07 23:59:56  ...  Jaga Vaksinasi Covid-19 di Puskesmas Tangkilin...
# 2   2021-10-07 23:59:21  ...  RT @KKMPutrajaya: mengawal pergerakan mereka y...
# 3   2021-10-07 23:58:22  ...  Vaksinasi untuk Menyelamatkan diri sendiri dan...
# 4   2021-10-07 23:58:14  ...  Vaksinasi penting dilakukan untuk meningkatkan...
# ..                  ...  ...                                                ...
# 795 2021-09-30 23:33:55  ...  RT @jpagov: SIARAN MEDIA : PENETAPAN SYARAT VA...
# 796 2021-09-30 23:33:49  ...  Dengan Kos Vaksinasi 2 Kali Ganda Kalau Tidak ...
# 797 2021-09-30 23:33:45  ...  DIPERPANJANG...!!!\n\nKanggo Kanca-Kanca Wong ...
# 798 2021-09-30 23:33:35  ...  RT @501Awani: Keadaan pesakit adalah bergejala...
# 799 2021-09-30 23:33:18  ...  Dirbinmas Polda DIY Kombes Pol. Drs. Anjar Gun...
#
# ...

# %% [markdown]
# ## **2. Crawling data september 2021 - oktober 2021**
# > **30/09/21 - 07/10/21**

# %%
access_token ="258199811-llOno7xx7uvYJuoGQNvrXAtHsgeeDJDQRDhCZb0Y"
access_token_secret ="bD4LwtQ2OtmBuKCnTXR4A5HQYTqqWH3IWEhbAfHrysBax"
api_key ="oTozcNGFucJwfqL6TEfqQtaWi"
api_key_secret ="6cRNX3IHJIStqfWGdcv2PMM6B625VLaDxk34vM3BT9EpIsHKje"

auth = tweepy.OAuthHandler(api_key, api_key_secret)
auth.set_access_token(access_token,access_token_secret)
api = tweepy.API(auth)

# %%
#Septmber - Oktober 2021
okt06 = api.search(q='vaksinasi', lang='id', count=100,since='2021-10-06',until='2021-10-07')
okt05 = api.search(q='vaksinasi', lang='id', count=100,since='2021-10-05',until='2021-10-06')
okt04 = api.search(q='vaksinasi', lang='id', count=100,since='2021-10-04',until='2021-10-05')
okt03 = api.search(q='vaksinasi', lang='id', count=100,since='2021-10-03',until='2021-10-04')
okt02 = api.search(q='vaksinasi', lang='id', count=100,since='2021-10-02',until='2021-10-03')
okt01 = api.search(q='vaksinasi', lang='id', count=100,since='2021-10-01',until='2021-10-02')
sep30 = api.search(q='vaksinasi', lang='id', count=100,since='2021-09-30',until='2021-10-01')

# %%
#Merge List
hasilSearch1 = okt06+okt05+okt04
hasilSearch2 = okt03+okt02+okt01+sep30
hasilSearch = hasilSearch1+hasilSearch2

# %%
hasilAnalisis = []

for tweet in hasilSearch:
    tweet_properties = {}
    tweet_properties['tanggal_tweet'] = tweet.created_at
    tweet_properties['pengguna'] = tweet.user.screen_name
    tweet_properties['tweet'] = tweet.text
    tweet_bersih = ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",tweet.text).split())
    hasilAnalisis.append(tweet_properties)

tanggal_tweet=[]
pengguna=[]
tweet=[]

for i in range (0,len(hasilAnalisis)):
    tanggal_tweet.append(hasilAnalisis[i]['tanggal_tweet'])
    pengguna.append(hasilAnalisis[i]['pengguna'])
    tweet.append(hasilAnalisis[i]['tweet'])

oktober_2000 = pd.DataFrame({'tanggal_tweet':tanggal_tweet,'pengguna':pengguna,'tweet':tweet})

# %%
oktober_2000
# Out:
#           tanggal_tweet  ...                                              tweet
# 0   2021-10-07 23:59:59  ...  RT @DivHumas_Polri: Walau kondisi pandemi Covi...
# 1   2021-10-07 23:59:53  ...  RT @icyfoxgalaxy: Selamat siang semuaa~~\n\nAk...
# 2   2021-10-07 23:59:49  ...  RT @rdzaminhat: semalam ada seorang yang berpe...
# 3   2021-10-07 23:59:43  ...  RT @NengPoji: Semalam ada lelaki 28 tahun data...
# 4   2021-10-07 23:59:43  ...  RT @widazakaria: Serius lah dia yang sebar 136...
# ..                  ...  ...                                                ...
# 795 2021-09-30 23:54:49  ...  waspada hoax seputaran papua\n.\n-- Vaksin Sem...
# 796 2021-09-30 23:54:36  ...  RT @bumilangit: Orang  sebar cerita tipu pasal...
# 797 2021-09-30 23:54:32  ...  Pemerhatian 30 minit oleh pasukan perubatan me...
# 798 2021-09-30 23:54:24  ...  HIPMI Selenggarakan Vaksin Covid-19 Turut Sumb...
# 799 2021-09-30 23:54:19  ...                            @schfess selamat vaksin
#
# ...

# %%
#mount process for access google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#export oktober_1000 to google drive
#oktober_2000.to_excel('/content/drive/MyDrive/SKRIPSI_TEXT_MINING/oktober_2000.xlsx',index=False)

# %%
# cek data hasil export
import pandas as pd
import numpy as np

cek_oktober_2000 = pd.read_excel('/content/drive/MyDrive/SKRIPSI_TEXT_MINING/oktober_2000.xlsx')
cek_oktober_2000
# Out:
#           tanggal_tweet  ...                                              tweet
# 0   2021-10-07 23:59:59  ...  RT @DivHumas_Polri: Walau kondisi pandemi Covi...
# 1   2021-10-07 23:59:53  ...  RT @icyfoxgalaxy: Selamat siang semuaa~~\n\nAk...
# 2   2021-10-07 23:59:49  ...  RT @rdzaminhat: semalam ada seorang yang berpe...
# 3   2021-10-07 23:59:43  ...  RT @NengPoji: Semalam ada lelaki 28 tahun data...
# 4   2021-10-07 23:59:43  ...  RT @widazakaria: Serius lah dia yang sebar 136...
# ..                  ...  ...                                                ...
# 795 2021-09-30 23:54:49  ...  waspada hoax seputaran papua\n.\n-- Vaksin Sem...
# 796 2021-09-30 23:54:36  ...  RT @bumilangit: Orang  sebar cerita tipu pasal...
# 797 2021-09-30 23:54:32  ...  Pemerhatian 30 minit oleh pasukan perubatan me...
# 798 2021-09-30 23:54:24  ...  HIPMI Selenggarakan Vaksin Covid-19 Turut Sumb...
# 799 2021-09-30 23:54:19  ...                            @schfess selamat vaksin
#
# ...

# %% [markdown]
# ## **3. Crawling data oktober 2021**
# > **23/10/21 - 31/10/21**

# %%
access_token ="258199811-llOno7xx7uvYJuoGQNvrXAtHsgeeDJDQRDhCZb0Y"
access_token_secret ="bD4LwtQ2OtmBuKCnTXR4A5HQYTqqWH3IWEhbAfHrysBax"
api_key ="oTozcNGFucJwfqL6TEfqQtaWi"
api_key_secret ="6cRNX3IHJIStqfWGdcv2PMM6B625VLaDxk34vM3BT9EpIsHKje"

auth = tweepy.OAuthHandler(api_key, api_key_secret)
auth.set_access_token(access_token,access_token_secret)
api = tweepy.API(auth)

# %%
#Oktober 2021
okt30 = api.search(q='vaksinasi', lang='id', count=100,since='2021-10-30',until='2021-10-31')
okt29 = api.search(q='vaksinasi', lang='id', count=100,since='2021-10-29',until='2021-10-30')
okt28 = api.search(q='vaksinasi', lang='id', count=100,since='2021-10-28',until='2021-10-29')
okt27 = api.search(q='vaksinasi', lang='id', count=100,since='2021-10-27',until='2021-10-28')
okt26 = api.search(q='vaksinasi', lang='id', count=100,since='2021-10-26',until='2021-10-27')
okt25 = api.search(q='vaksinasi', lang='id', count=100,since='2021-10-25',until='2021-10-26')
okt24 = api.search(q='vaksinasi', lang='id', count=100,since='2021-10-24',until='2021-10-25')
okt23 = api.search(q='vaksinasi', lang='id', count=100,since='2021-10-23',until='2021-10-24')

# %%
#Merge List
hasilSearch = okt30 + okt29 + okt28 + okt27 + okt26 + okt25 + okt24 + okt23

# %%
hasilAnalisis = []

for tweet in hasilSearch:
    tweet_properties = {}
    tweet_properties['tanggal_tweet'] = tweet.created_at
    tweet_properties['pengguna'] = tweet.user.screen_name
    tweet_properties['tweet'] = tweet.text
    tweet_bersih = ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",tweet.text).split())
    hasilAnalisis.append(tweet_properties)

tanggal_tweet=[]
pengguna=[]
tweet=[]

for i in range (0,len(hasilAnalisis)):
    tanggal_tweet.append(hasilAnalisis[i]['tanggal_tweet'])
    pengguna.append(hasilAnalisis[i]['pengguna'])
    tweet.append(hasilAnalisis[i]['tweet'])

oktober_akhir = pd.DataFrame({'tanggal_tweet':tanggal_tweet,'pengguna':pengguna,'tweet':tweet})

# %%
oktober_akhir
# Out:
#           tanggal_tweet  ...                                              tweet
# 0   2021-10-31 23:58:13  ...  “Untuk pengetahuan semua, terdapat beberapa ne...
# 1   2021-10-31 23:58:12  ...  Bakti 𝗣𝗼𝗹𝗿𝗶 Menjaga Keselamatan Masyarakat.\n𝘒...
# 2   2021-10-31 23:57:55  ...  Bakti 𝗣𝗼𝗹𝗿𝗶 Menjaga Keselamatan Masyarakat.\n𝘒...
# 3   2021-10-31 23:57:43  ...  Bakti 𝗣𝗼𝗹𝗿𝗶 Menjaga Keselamatan Masyarakat.\n𝘒...
# 4   2021-10-31 23:57:37  ...  RT @bandung_goid: Halo, Wargi Bandung!\n\nBeri...
# ..                  ...  ...                                                ...
# 895 2021-10-23 23:12:44  ...  Vaksinasi Bukan Hanya Semata Menyelamatkan Dir...
# 896 2021-10-23 23:11:26  ...  RT @gibran_tweet: ‘Santri Siaga Jiwa Raga’ tur...
# 897 2021-10-23 23:11:02  ...  RT @InsafKini: Tahniah &amp; Syabas Kementeria...
# 898 2021-10-23 23:10:56  ...  RT @ariestarico2: Dilansir dari Nikkei Asia, t...
# 899 2021-10-23 23:10:24  ...  RT @TedHilbert: Orang yang divaksinasi lengkap...
#
# ...

# %%
#mount process for access google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#export oktober_1000 to google drive
# oktober_akhir.to_excel('/content/drive/MyDrive/SKRIPSI_TEXT_MINING/oktober_akhir_1000.xlsx',index=False)

# %%
# cek data hasil export
import pandas as pd
import numpy as np

cek_oktober_akhir = pd.read_excel('/content/drive/MyDrive/SKRIPSI_TEXT_MINING/oktober_akhir_1000.xlsx')
cek_oktober_akhir
# Out:
#           tanggal_tweet  ...                                              tweet
# 0   2021-10-31 23:58:13  ...  “Untuk pengetahuan semua, terdapat beberapa ne...
# 1   2021-10-31 23:58:12  ...  Bakti 𝗣𝗼𝗹𝗿𝗶 Menjaga Keselamatan Masyarakat.\n𝘒...
# 2   2021-10-31 23:57:55  ...  Bakti 𝗣𝗼𝗹𝗿𝗶 Menjaga Keselamatan Masyarakat.\n𝘒...
# 3   2021-10-31 23:57:43  ...  Bakti 𝗣𝗼𝗹𝗿𝗶 Menjaga Keselamatan Masyarakat.\n𝘒...
# 4   2021-10-31 23:57:37  ...  RT @bandung_goid: Halo, Wargi Bandung!\n\nBeri...
# ..                  ...  ...                                                ...
# 895 2021-10-23 23:12:44  ...  Vaksinasi Bukan Hanya Semata Menyelamatkan Dir...
# 896 2021-10-23 23:11:26  ...  RT @gibran_tweet: ‘Santri Siaga Jiwa Raga’ tur...
# 897 2021-10-23 23:11:02  ...  RT @InsafKini: Tahniah &amp; Syabas Kementeria...
# 898 2021-10-23 23:10:56  ...  RT @ariestarico2: Dilansir dari Nikkei Asia, t...
# 899 2021-10-23 23:10:24  ...  RT @TedHilbert: Orang yang divaksinasi lengkap...
#
# ...

# %% [markdown]
# # **@Explorasi tweepy for crawling data twitter about vaksinasi in Indonesia**

# %%
import pandas as pd 
import numpy as np
import tweepy
import csv
import re

# menghitung sentimen kata-kata yang berbahasa inggris
from textblob import TextBlob 
from datetime import datetime

# %%
access_token ="258199811-llOno7xx7uvYJuoGQNvrXAtHsgeeDJDQRDhCZb0Y"
access_token_secret ="bD4LwtQ2OtmBuKCnTXR4A5HQYTqqWH3IWEhbAfHrysBax"
api_key ="oTozcNGFucJwfqL6TEfqQtaWi"
api_key_secret ="6cRNX3IHJIStqfWGdcv2PMM6B625VLaDxk34vM3BT9EpIsHKje"

auth = tweepy.OAuthHandler(api_key, api_key_secret)
auth.set_access_token(access_token,access_token_secret)
api = tweepy.API(auth)

# %%
# November 2021
nov29 = api.search(q='vaksinasi', lang='id', count=100,since='2021-11-29',until='2021-11-30')
nov28 = api.search(q='vaksinasi', lang='id', count=100,since='2021-11-28',until='2021-11-29')
nov27 = api.search(q='vaksinasi', lang='id', count=100,since='2021-11-27',until='2021-11-28')
nov26 = api.search(q='vaksinasi', lang='id', count=100,since='2021-11-26',until='2021-11-27')
nov25 = api.search(q='vaksinasi', lang='id', count=100,since='2021-11-25',until='2021-11-26')
nov24 = api.search(q='vaksinasi', lang='id', count=100,since='2021-11-24',until='2021-11-25')
nov23 = api.search(q='vaksinasi', lang='id', count=100,since='2021-11-23',until='2021-11-24')
nov22 = api.search(q='vaksinasi', lang='id', count=100,since='2021-11-22',until='2021-11-23')
nov21 = api.search(q='vaksinasi', lang='id', count=100,since='2021-11-21',until='2021-11-22')
nov20 = api.search(q='vaksinasi', lang='id', count=100,since='2021-11-20',until='2021-11-21')

# %% [markdown]
# > **keterbatasan:** hanya dapat berlaku 10 hari kebelakang dari hari penarikan dimulai

# %%
#Merge List
hasilSearch = nov29 + nov28 + nov27 + nov26 + nov25 + nov24 + nov23 + nov22 + nov21 + nov20

# %%
hasilSearch
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
hasilAnalisis = []
for tweet in hasilSearch:
    tweet_properties = {}
    tweet_properties['tanggal_tweet'] = tweet.created_at
    tweet_properties['pengguna'] = tweet.user.screen_name
    tweet_properties['tweet'] = tweet.text
    tweet_bersih = ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",tweet.text).split())
    hasilAnalisis.append(tweet_properties)

tanggal_tweet=[]
pengguna=[]
tweet=[]
sentimen=[]
for i in range (0,len(hasilAnalisis)):
    tanggal_tweet.append(hasilAnalisis[i]['tanggal_tweet'])
    pengguna.append(hasilAnalisis[i]['pengguna'])
    tweet.append(hasilAnalisis[i]['tweet'])

november_30 = pd.DataFrame({'tanggal_tweet':tanggal_tweet,'pengguna':pengguna,'tweet':tweet})

# %%
# # view data in list
# hasilAnalisis

#view data in dataframe
november_30
# Out:
#           tanggal_tweet  ...                                              tweet
# 0   2021-11-29 23:59:30  ...  RT @forjakeu: Gelombang ketiga pandemi virus c...
# 1   2021-11-29 23:58:43  ...  RT @Penyair_Berdiri: Progress Percepatan Vaksi...
# 2   2021-11-29 23:58:27  ...  @Penyair_Berdiri Ajak saudara dan tetangga yan...
# 3   2021-11-29 23:58:12  ...  RT @ariestarico2: Di saat bersamaan, tidak ada...
# 4   2021-11-29 23:58:11  ...  RT @Penyair_Berdiri: Sebagai upaya Percepatan ...
# ..                  ...  ...                                                ...
# 808 2021-11-21 23:00:00  ...  Pemerintah rencanakan opsi perluas cakupan vak...
# 809 2021-11-21 23:00:00  ...  Mensos Risma menyampaikan bahwa Kementerian So...
# 810 2021-11-21 22:58:47  ...  RT @TedHilbert: Mencegah infeksi dan penularan...
# 811 2021-11-21 22:57:26  ...  RT @liputan6dotcom: Cek Jadwal Vaksinasi COVID...
# 812 2021-11-21 22:56:39  ...  Jadwal Vaksinasi hari Senin tanggal 22 Novembe...
#
# ...

# %% [markdown]
# > **command code with sentiment labeling within**

# %%
# # %run bulan.py

# hasilAnalisis = []

# for tweet in hasilSearch:
#     tweet_properties = {}
#     tweet_properties['tanggal_tweet'] = tweet.created_at
#     tweet_properties['pengguna'] = tweet.user.screen_name
#     tweet_properties['tweet'] = tweet.text
#     tweet_bersih = ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",tweet.text).split())
#     hasilAnalisis.append(tweet_properties)    

#     analysis = TextBlob(tweet_bersih)
# #     try:
# #         analysis = analysis.translate(to='en')
# #     except Exception as e:
# #         print(e)    

#     if analysis.sentiment.polarity > 0.0:
#         tweet_properties["sentimen"] = 'positif'
#     elif analysis.sentiment.polarity == 0.0:
#         tweet_properties["sentimen"] = 'netral'
#     else:
#         tweet_properties["sentimen"] = 'negatif'
        
#     if tweet.retweet_count > 0:
#         if tweet_properties not in hasilAnalisis:
#             hasilAnalisis.append(tweet_properties)
#     else:
#         hasilAnalisis.append(tweet_properties)
        
# # hasilAnalisis

# tanggal_tweet=[]
# pengguna=[]
# tweet=[]
# sentimen=[]

# for i in range (0,len(hasilAnalisis)):
#     tanggal_tweet.append(hasilAnalisis[i]['tanggal_tweet'])
#     pengguna.append(hasilAnalisis[i]['pengguna'])
#     tweet.append(hasilAnalisis[i]['tweet'])
#     sentimen.append(hasilAnalisis[i]['sentimen'])

# oktober_akhir = pd.DataFrame({'tanggal_tweet':tanggal_tweet,'pengguna':pengguna,'tweet':tweet,'sentimen':sentimen})

# %%
november_30
# Out:
#           tanggal_tweet  ...                                              tweet
# 0   2021-11-29 23:59:30  ...  RT @forjakeu: Gelombang ketiga pandemi virus c...
# 1   2021-11-29 23:58:43  ...  RT @Penyair_Berdiri: Progress Percepatan Vaksi...
# 2   2021-11-29 23:58:27  ...  @Penyair_Berdiri Ajak saudara dan tetangga yan...
# 3   2021-11-29 23:58:12  ...  RT @ariestarico2: Di saat bersamaan, tidak ada...
# 4   2021-11-29 23:58:11  ...  RT @Penyair_Berdiri: Sebagai upaya Percepatan ...
# ..                  ...  ...                                                ...
# 808 2021-11-21 23:00:00  ...  Pemerintah rencanakan opsi perluas cakupan vak...
# 809 2021-11-21 23:00:00  ...  Mensos Risma menyampaikan bahwa Kementerian So...
# 810 2021-11-21 22:58:47  ...  RT @TedHilbert: Mencegah infeksi dan penularan...
# 811 2021-11-21 22:57:26  ...  RT @liputan6dotcom: Cek Jadwal Vaksinasi COVID...
# 812 2021-11-21 22:56:39  ...  Jadwal Vaksinasi hari Senin tanggal 22 Novembe...
#
# ...

# %%
#mount process for access google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#export november_30 to google drive
# november_30.to_excel('/content/drive/MyDrive/SKRIPSI_TEXT_MINING/november_30.xlsx',index=False)

# %% [markdown]
# # **@Explorasi BeautifulSoup dan WorldCoud**

# %%
from bs4 import BeautifulSoup

# import visualisasi untuk worldcloud
import seaborn as sns
import folium
from folium import plugins
from PIL import Image
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# %%
url = 'https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/alice_novel.txt'
page = requests.get(url)

soup = BeautifulSoup(page.content,'html.parser')
print(soup.text)
# Out:
# Project Gutenberg's Alice's Adventures in Wonderland, by Lewis Carroll
#
# This eBook is for the use of anyone anywhere at no cost and with
# almost no restrictions whatsoever.  You may copy it, give it away or
# re-use it under the terms of the Project Gutenberg License included
# with this eBook or online at www.gutenberg.org
#
#
# Title: Alice's Adventures in Wonderland
#
# Author: Lewis Carroll
#
# Posting Date: June 25, 2008 [EBook #11]
# Release Date: March, 1994
# [Last updated: December 20, 2011]
#
# Language: English
#
#
# *** START OF THIS PROJECT GUTENBERG EBOOK ALICE'S ADVENTURES IN WONDERLAND ***
#
#
#
#
#
#
#
#
#
#
# ALICE'S ADVENTURES IN WONDERLAND
#
# Lewis Carroll
#
# THE MILLENNIUM FULCRUM EDITION 3.0
#
#
#
#
# CHAPTER I. Down the Rabbit-Hole
#
# Alice was beginning to get very tired of sitting by her sister on the
# bank, and of having nothing to do: once or twice she had peeped into the
# book her sister was reading, but it had no pictures or conversations in
# ...

# %%
from io import StringIO
StringIO(soup.txt)

# %%
df = pd.read_table(StringIO(soup.text), sep='\t')
df
# Out:
#      Project Gutenberg's Alice's Adventures in Wonderland, by Lewis Carroll
# 0     This eBook is for the use of anyone anywhere a...
# 1     almost no restrictions whatsoever.  You may co...
# 2     re-use it under the terms of the Project Guten...
# 3        with this eBook or online at www.gutenberg.org
# 4               Title: Alice's Adventures in Wonderland
# ...                                                 ...
# 2489  all their simple sorrows, and find a pleasure ...
# 2490  remembering her own child-life, and the happy ...
# 2491                                            THE END
# 2492  End of Project Gutenberg's Alice's Adventures ...
# 2493  *** END OF THIS PROJECT GUTENBERG EBOOK ALICE'...
#
# [2494 rows x 1 columns]

# %%
df['CONTENT'] = df
df
# Out:
#      Project Gutenberg's Alice's Adventures in Wonderland, by Lewis Carroll                                            CONTENT
# 0     This eBook is for the use of anyone anywhere a...                      This eBook is for the use of anyone anywhere a...
# 1     almost no restrictions whatsoever.  You may co...                      almost no restrictions whatsoever.  You may co...
# 2     re-use it under the terms of the Project Guten...                      re-use it under the terms of the Project Guten...
# 3        with this eBook or online at www.gutenberg.org                         with this eBook or online at www.gutenberg.org
# 4               Title: Alice's Adventures in Wonderland                                Title: Alice's Adventures in Wonderland
# ...                                                 ...                                                                    ...
# ...

# %%
from wordcloud import WordCloud, STOPWORDS
STOPWORDS
# kata-kata ga penting
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'all',
#  'also',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  "can't",
#  'cannot',
#  'com',
#  'could',
#  "couldn't",
#  'did',
#  "didn't",
#  'do',
#  'does',
#  "doesn't",
#  'doing',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'else',
#  'ever',
#  'few',
#  'for',
#  'from',
#  'further',
#  'get',
#  'had',
#  "hadn't",
#  'has',
#  "hasn't",
#  'have',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'her',
#  'here',
#  "here's",
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  "how's",
#  'however',
#  'http',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'k',
#  "let's",
# ...

# %%
comment_words = ''
stopwords = set(STOPWORDS)
 
# iterate through the csv file
for val in df.CONTENT:
     
    # typecaste each val to string
    val = str(val)
 
    # split the value
    tokens = val.split()
     
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
     
    comment_words += " ".join(tokens)+" "
 
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()
