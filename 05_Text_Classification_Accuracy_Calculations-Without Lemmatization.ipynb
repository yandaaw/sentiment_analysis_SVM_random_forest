# %%
# !pip install Sastrawi
# !pip install nltk
# Out:
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      |████████████████████████████████| 209 kB 5.3 MB/s
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk) (1.15.0)

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (3.0.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.4.1)
# Requirement already satisfied: numpy>=1.14.6 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.19.5)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.1.0)

# %%
# !pip install pydotplus
# Out:
# Requirement already satisfied: pydotplus in /usr/local/lib/python3.7/dist-packages (2.0.2)
# Requirement already satisfied: pyparsing>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from pydotplus) (3.0.6)

# %%
#mount process for access google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Import Library
import pandas as pd
import numpy as np
import string
import os
import re
from datetime import datetime

# Import matplotlib library for visualize the data
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import NLTK library - word_tokenize library for tokenization process using nltk
# for process of pos-tagging, lemmatization and cleaning the stopwords  
import nltk
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize 
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
from nltk.stem import LancasterStemmer
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')

# Import Sklearn Library
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import accuracy_score, confusion_matrix, recall_score, f1_score, precision_score, plot_confusion_matrix
from sklearn.metrics import precision_recall_fscore_support as score

from sklearn import model_selection, svm 
from sklearn import svm #for svm algorithm
from sklearn.svm import SVC

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
import sklearn.tree as tree

# ------------------------------------------------------------------------------------------------------------------------------------
# Additional library for data pre-processing process
import spacy
import csv

from sklearn.feature_extraction.text import CountVectorizer
from sklearn import model_selection, naive_bayes 
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

import pydotplus
#from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
#from Sastrawi.Stemmer.StemmerFactory import StemmerFactory #import Indonesian Stemmer
from scipy.spatial import distance
from six import StringIO
from IPython.display import Image
porter_stemmer = PorterStemmer()

#for stopwords removal
from spacy.lang.en import English

#load English tokenizer, tagger, parser, NER and word vectors
nlp = English()
from spacy.lang.en.stop_words import STOP_WORDS
sp = spacy.load('en_core_web_sm')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %% [markdown]
# ---------------------------

# %% [markdown]
# # **SVM Classifier Algorithm (Support vector machine Algorithm)**
# > **data training 70% dan data testing 30% dengan menjadikan test_size=0.3**

# %% [markdown]
# ## **Hold-Out Method**

# %%
corpus = pd.read_excel('/content/drive/MyDrive/SKRIPSI_TEXT_MINING/sample_reviews_2.1_nolemma.xlsx')

# %%
corpus.head()
# Out:
#           username  ...    label
# 0           pqrzan  ...   netral
# 1     mcreativepky  ...   netral
# 2        veemarisa  ...   netral
# 3          GSaraw4  ...  positif
# 4  Papalov03973158  ...   netral
#
# [5 rows x 11 columns]

# %% [markdown]
# > **Text Classification dan Kalkulasi Akurasi**
# - data training 70% dan data testing 30% dengan menjadikan test_size=0.3

# %%
#rename colume text_lemmatized into text_final
corpus = corpus.rename(columns={'text_stemmed':'text_final'})

#HOLD-OUT - Dividing testing and training data
#Train_X,Test_X,Train_Y,Test_Y = model_selection.train_test_split(df_new['text_final'],df_new['label'],test_size=0.3)
#Train_X,Test_X,Train_Y,Test_Y = model_selection.train_test_split(df_new['text_final'],df_new['label'],test_size=0.33, random_state=66)
Train_X,Test_X,Train_Y,Test_Y = train_test_split(corpus['text_final'],corpus['label'],test_size=0.3)

# Label encode - transform Categorical data of string (negatif, netral, positif) into numerical values (0,1,2)
Encoder = LabelEncoder()
Train_Y = Encoder.fit_transform(Train_Y)
Test_Y = Encoder.fit_transform(Test_Y)

# %%
#TF-IDF Vectorizer 
Tfidf_vect = TfidfVectorizer(max_features=5000)
Tfidf_vect.fit(corpus['text_final'])

Train_X_Tfidf = Tfidf_vect.transform(Train_X)
Test_X_Tfidf = Tfidf_vect.transform(Test_X)

#CHECKING
print(Tfidf_vect.vocabulary_)
print(Train_X_Tfidf)
# Out:
# {'cross': 629, 'stat': 2707, 'allow': 89, 'roadblock': 2420, 'check': 473, 'person': 2101, 'either': 836, 'complet': 550, 'vaccin': 3047, 'keep': 1441, 'covid': 613, 'tangkelil': 2847, 'puskesk': 2287, 'build': 396, 'batu': 274, 'polic': 2163, 'chief': 476, 'personnel': 2102, 'pam': 2004, 'control': 582, 'movement': 1810, 'refus': 2352, 'receiv': 2336, 'inject': 1300, '
hyperparameter Tuning**

# %%
from sklearn.model_selection import GridSearchCV

# defining parameter range
param_grid = {'C': [0.1, 1, 10, 100, 1000],
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
              'kernel': ['rbf']}

grid = GridSearchCV(SVC(), param_grid, refit = True, verbose=3)

# fitting the model for grid search
grid.fit(Train_X_Tfidf, Train_Y)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.662 total time=   0.1s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.662 total time=   0.1s
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.662 total time=   0.1s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.665 total time=   0.1s
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.662 total time=   0.1s
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.662 total time=   0.1s
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.662 total time=   0.1s
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.665 total time=   0.1s
# [CV 1/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 2/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.662 total time=   0.1s
# [CV 3/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.662 total time=   0.1s
# [CV 4/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.662 total time=   0.1s
# [CV 5/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.665 total time=   0.1s
# [CV 1/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 2/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.662 total time=   0.1s
# [CV 3/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.662 total time=   0.1s
# [CV 4/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.662 total time=   0.1s
# [CV 5/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.665 total time=   0.1s
# [CV 1/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 2/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.662 total time=   0.1s
# [CV 3/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.662 total time=   0.1s
# [CV 4/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.662 total time=   0.1s
# [CV 5/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.665 total time=   0.1s
# [CV 1/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.727 total time=   0.1s
# [CV 2/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.722 total time=   0.1s
# [CV 3/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.732 total time=   0.1s
# [CV 4/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.707 total time=   0.1s
# [CV 5/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.721 total time=   0.1s
# [CV 1/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 2/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.662 total time=   0.1s
# [CV 3/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 4/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.662 total time=   0.1s
# [CV 5/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.670 total time=   0.1s
# [CV 1/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 2/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.662 total time=   0.1s
# [CV 3/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.662 total time=   0.1s
# [CV 4/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.662 total time=   0.1s
# [CV 5/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.665 total time=   0.1s
# [CV 1/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 2/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.662 total time=   0.1s
# [CV 3/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.662 total time=   0.1s
# [CV 4/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.662 total time=   0.1s
# [CV 5/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.665 total time=   0.1s
# [CV 1/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 2/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.662 total time=   0.1s
# [CV 3/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.662 total time=   0.1s
# [CV 4/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.662 total time=   0.1s
# [CV 5/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.665 total time=   0.1s
# [CV 1/5] END .........C=10, gamma=1, kernel=rbf;, score=0.778 total time=   0.1s
# [CV 2/5] END .........C=10, gamma=1, kernel=rbf;, score=0.753 total time=   0.1s
# [CV 3/5] END .........C=10, gamma=1, kernel=rbf;, score=0.758 total time=   0.1s
# [CV 4/5] END .........C=10, gamma=1, kernel=rbf;, score=0.753 total time=   0.1s
# [CV 5/5] END .........C=10, gamma=1, kernel=rbf;, score=0.772 total time=   0.1s
# [CV 1/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.828 total time=   0.1s
# [CV 2/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.818 total time=   0.1s
# [CV 3/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.833 total time=   0.1s
# [CV 4/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.818 total time=   0.1s
# [CV 5/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.832 total time=   0.1s
# [CV 1/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 2/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.662 total time=   0.1s
# [CV 3/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 4/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.662 total time=   0.1s
# [CV 5/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.675 total time=   0.1s
# [CV 1/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 2/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.662 total time=   0.1s
# [CV 3/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.662 total time=   0.1s
# [CV 4/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.662 total time=   0.1s
# [CV 5/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.665 total time=   0.1s
# [CV 1/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 2/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.662 total time=   0.1s
# [CV 3/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.662 total time=   0.1s
# [CV 4/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.662 total time=   0.1s
# [CV 5/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.665 total time=   0.1s
# [CV 1/5] END ........C=100, gamma=1, kernel=rbf;, score=0.778 total time=   0.1s
# [CV 2/5] END ........C=100, gamma=1, kernel=rbf;, score=0.753 total time=   0.1s
# [CV 3/5] END ........C=100, gamma=1, kernel=rbf;, score=0.758 total time=   0.1s
# [CV 4/5] END ........C=100, gamma=1, kernel=rbf;, score=0.753 total time=   0.1s
# [CV 5/5] END ........C=100, gamma=1, kernel=rbf;, score=0.772 total time=   0.1s
# [CV 1/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.843 total time=   0.1s
# [CV 2/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.818 total time=   0.1s
# [CV 3/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.828 total time=   0.1s
# [CV 4/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.818 total time=   0.1s
# [CV 5/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.838 total time=   0.1s
# [CV 1/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.838 total time=   0.1s
# [CV 2/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.833 total time=   0.1s
# [CV 3/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.833 total time=   0.1s
# [CV 4/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.833 total time=   0.1s
# [CV 5/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.843 total time=   0.1s
# [CV 1/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 2/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.662 total time=   0.1s
# [CV 3/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 4/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.662 total time=   0.1s
# [CV 5/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.675 total time=   0.1s
# [CV 1/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 2/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.662 total time=   0.1s
# [CV 3/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.662 total time=   0.1s
# [CV 4/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.662 total time=   0.1s
# [CV 5/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.665 total time=   0.1s
# [CV 1/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.778 total time=   0.1s
# [CV 2/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.753 total time=   0.1s
# [CV 3/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.758 total time=   0.1s
# [CV 4/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.753 total time=   0.1s
# [CV 5/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.772 total time=   0.1s
# [CV 1/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.843 total time=   0.1s
# [CV 2/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.818 total time=   0.1s
# [CV 3/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.828 total time=   0.1s
# [CV 4/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.818 total time=   0.1s
# [CV 5/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.838 total time=   0.1s
# [CV 1/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.854 total time=   0.1s
# [CV 2/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.828 total time=   0.1s
# [CV 3/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.823 total time=   0.1s
# [CV 4/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.823 total time=   0.1s
# [CV 5/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.853 total time=   0.1s
# [CV 1/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.838 total time=   0.1s
# [CV 2/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.828 total time=   0.1s
# [CV 3/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.828 total time=   0.1s
# [CV 4/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.833 total time=   0.1s
# [CV 5/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.843 total time=   0.1s
# [CV 1/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 2/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.662 total time=   0.1s
# [CV 3/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 4/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.662 total time=   0.1s
# [CV 5/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.675 total time=   0.1s
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['rbf']},
#              verbose=3)

# %%
# print best parameter after tuning
print(grid.best_params_)

# print how our model looks after hyper-parameter tunning
print(grid.best_estimator_)
# Out:
# {'C': 1000, 'gamma': 0.01, 'kernel': 'rbf'}
# SVC(C=1000, gamma=0.01)

# %%
# re-run prediction model 
grid_predictions = grid.predict(Test_X_Tfidf)

#print classification report
print(classification_report(Test_Y, grid_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.29      0.41        38
#            1       0.83      0.97      0.90       287
#            2       0.91      0.67      0.77       100
#
#     accuracy                           0.84       425
#    macro avg       0.81      0.64      0.69       425
# weighted avg       0.84      0.84      0.82       425

# %% [markdown]
# > **Classifier - SVM Algorithm**

# %%
# fit the training dataset on the classifier
SVM = svm.SVC(C=1000, kernel='rbf', gamma=0.01)
SVM.fit(Train_X_Tfidf,Train_Y)

# predict the labels on validation dataset
predictions_SVM = SVM.predict(Test_X_Tfidf)

# %% [markdown]
# > **Visualize Classifier - SVM Algorithm**

# %%
# visualize classifier SVM algorithm toward the data
conf_matrix = confusion_matrix(Test_Y, predictions_SVM)
class_label = ["NEGATIF", "NETRAL", "POSITIF"]
test = pd.DataFrame(conf_matrix, index = class_label, columns = class_label)
sns.heatmap(test, annot = True, fmt = "d")
plt.title("Confusion Matrix SVM")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
# SVM RESULT
print("SVM RESULT")
print("Accuracy Score =",accuracy_score(predictions_SVM, Test_Y))
precision, recall, fscore, support = score(Test_Y, predictions_SVM, average='weighted')
print("Precision =", precision)
print("Recall =", recall)
print("F-score =", fscore)
# Out:
# SVM RESULT
# Accuracy Score = 0.84
# Precision = 0.8369162850295422
# Recall = 0.84
# F-score = 0.8234410096719078

# %% [markdown]
# # **Random-forest-Classifier Algorithm**
# > **data training 70% dan data testing 30% dengan menjadikan test_size=0.3**

# %% [markdown]
# ## **Random-forest-Classifier Algorithm**
# > **Hyperparameter Tuning**

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier

# %%
# # Number of trees in random forest
# n_estimators = [int(x) for x in np.linspace(start = 10, stop = 80, num = 10)]
# # Number of features to consider at every split
# max_features = ['auto', 'sqrt']
# # Maximum number of levels in tree
# max_depth = [4,10]
# # Minimum number of samples required to split a node
# min_samples_split = [2, 5]
# # Minimum number of samples required at each leaf node
# min_samples_leaf = [1, 2]
# # Method of selecting samples for training each tree
# bootstrap = [True, False]
# ------------------------------------------------------------------------------------------------------------

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 50, stop = 300, num = 5)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 110, num = 5)]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Method of selecting samples for training each tree
bootstrap = [True, False]

# %%
# Create the param grid
param_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}
print(param_grid)
# Out:
# {'n_estimators': [50, 112, 175, 237, 300], 'max_features': ['auto', 'sqrt'], 'max_depth': [10, 35, 60, 85, 110, None], 'min_samples_split': [2, 5, 10], 'min_samples_leaf': [1, 2, 4], 'bootstrap': [True, False]}

# %%
rf_Model = RandomForestClassifier()

# %%
from sklearn.model_selection import GridSearchCV
rf_Grid = GridSearchCV(estimator = rf_Model, param_grid = param_grid, cv = 3, verbose=2, n_jobs = 4)

# %%
rf_Grid.fit(Train_X_Tfidf, Train_Y)
# Out:
# Fitting 3 folds for each of 1080 candidates, totalling 3240 fits
# GridSearchCV(cv=3, estimator=RandomForestClassifier(), n_jobs=4,
#              param_grid={'bootstrap': [True, False],
#                          'max_depth': [10, 35, 60, 85, 110, None],
#                          'max_features': ['auto', 'sqrt'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [50, 112, 175, 237, 300]},
#              verbose=2)

# %%
# print how our model looks after hyper-parameter tunning
rf_Grid.best_params_
# Out:
# {'bootstrap': False,
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 1,
#  'min_samples_split': 10,
#  'n_estimators': 300}

# %%
#check accuracy
print (f'Train Accuracy - : {rf_Grid.score(Train_X_Tfidf,Train_Y):.3f}')
print (f'Test Accuracy - : {rf_Grid.score(Test_X_Tfidf,Test_Y):.3f}')
# Out:
# Train Accuracy - : 0.999
# Test Accuracy - : 0.873

# %% [markdown]
# > **Classifier - Random-forest Algorithm**

# %%
# from sklearn.model_selection import train_test_split
# from sklearn import model_selection

# fit the training dataset on the classifier
rf_clf = RandomForestClassifier(n_estimators=300, max_depth= None, max_features='sqrt', bootstrap=False, min_samples_leaf=1, min_samples_split=10)
rf_clf.fit(Train_X_Tfidf, Train_Y)

# predict the labels on validation dataset
predictions_RFC = rf_clf.predict(Test_X_Tfidf )

# %% [markdown]
# > **Visualize Classifier - Random-forest Algorithm**

# %%
# visualize classifier Random-forest algorithm toward the data
conf_matrix = confusion_matrix(Test_Y, predictions_RFC)
class_label = ["NEGATIF", "NETRAL", "POSITIF"]
test = pd.DataFrame(conf_matrix, index = class_label, columns = class_label)
sns.heatmap(test, annot = True, fmt = "d")
plt.title("Confusion Matrix Random-Forest")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
# RANDOM FOREST RESULT
print("RANDOM FOREST RESULT")
print("Accuracy Score =",accuracy_score(predictions_RFC, Test_Y))
precision, recall, fscore, support = score(Test_Y, predictions_RFC, average='weighted')
print("Precision =", precision)
print("Recall =", recall)
print("F-score =", fscore)
# Out:
# RANDOM FOREST RESULT
# Accuracy Score = 0.8729411764705882
# Precision = 0.877634246143456
# Recall = 0.8729411764705882
# F-score = 0.8595503935495117

# %% [markdown]
# <br>

# %% [markdown]
# --------------------------

# %% [markdown]
# # **SVM Classifier Algorithm (Support vector machine Algorithm)**
# > **data training 80% dan data testing 20% dengan menjadikan test_size=0.2**

# %% [markdown]
# ## **Hold-Out Method**

# %%
corpus = pd.read_excel('/content/drive/MyDrive/SKRIPSI_TEXT_MINING/sample_reviews_2.1_nolemma.xlsx')

# %%
corpus.head()
# Out:
#           username  ...    label
# 0           pqrzan  ...   netral
# 1     mcreativepky  ...   netral
# 2        veemarisa  ...   netral
# 3          GSaraw4  ...  positif
# 4  Papalov03973158  ...   netral
#
# [5 rows x 11 columns]

# %% [markdown]
# > **Text Classification dan Kalkulasi Akurasi**
# - data training 80% dan data testing 20% dengan menjadikan test_size=0.2

# %%
#rename colume text_lemmatized into text_final
corpus = corpus.rename(columns={'text_stemmed':'text_final'})

#HOLD-OUT - Dividing testing and training data
#Train_X,Test_X,Train_Y,Test_Y = model_selection.train_test_split(df_new['text_final'],df_new['label'],test_size=0.2)
#Train_X,Test_X,Train_Y,Test_Y = model_selection.train_test_split(df_new['text_final'],df_new['label'],test_size=0.20, random_state=66)
Train_X,Test_X,Train_Y,Test_Y = train_test_split(corpus['text_final'],corpus['label'],test_size=0.2)

# Label encode - transform Categorical data of string (negatif, netral, positif) into numerical values (0,1,2)
Encoder = LabelEncoder()
Train_Y = Encoder.fit_transform(Train_Y)
Test_Y = Encoder.fit_transform(Test_Y)

# %%
#TF-IDF Vectorizer 
Tfidf_vect = TfidfVectorizer(max_features=5000)
Tfidf_vect.fit(corpus['text_final'])

Train_X_Tfidf = Tfidf_vect.transform(Train_X)
Test_X_Tfidf = Tfidf_vect.transform(Test_X)

#CHECKING
print(Tfidf_vect.vocabulary_)
print(Train_X_Tfidf)
# Out:
# {'cross': 629, 'stat': 2707, 'allow': 89, 'roadblock': 2420, 'check': 473, 'person': 2101, 'either': 836, 'complet': 550, 'vaccin': 3047, 'keep': 1441, 'covid': 613, 'tangkelil': 2847, 'puskesk': 2287, 'build': 396, 'batu': 274, 'polic': 2163, 'chief': 476, 'personnel': 2102, 'pam': 2004, 'control': 582, 'movement': 1810, 'refus': 2352, 'receiv': 2336, 'inject': 1300, 'freedom': 1031, 'save': 2476, 'famili': 953, 'prove': 2257, 'safe': 2452, 'import': 1262, 'done': 767, 'increas': 1275, 'bodi': 354, 'immun': 1257, 'avoid': 211, 'spread': 2687, 'individu': 1283, 'take': 2832, 'still': 2716, 'countri': 606, 'need': 1865, 'adher': 37, 'exist': 921, 'sop': 2658, 'like': 1575, 'enthusiasm': 876, 'commun': 545, 'particip': 2032, 'high': 1184, 'proven': 2258, 'commemor': 539, 'tni': 2930, 'anniversari': 122, 'east': 823, 'java': 1364, 'region': 2357, 'appreci': 158, 'simultan': 2592, 'creation': 622, 'herd': 1178, 'pandem': 2012, 'humanitarian': 1228, 'problem': 2230, 'across': 25, 'nation': 1852, 'alhamdulillah': 84, 'dki': 757, 'jakarta': 1353, 'provinci': 2261, 'govern': 1094, 'collabor': 527, 'deng': 700, 'lead': 1547, 'coordin': 592, 'meet': 1713, 'acceler': 14, 'aglomer': 61, 'regenc': 2354, 'citi': 502, 'let': 1565, 'immedi': 1256, 'order': 1968, 'reduc': 2348, 'number': 1915, 'must': 1830, 'compli': 551, 'health': 1163, 'protocol': 2254, 'make': 1643, 'sure': 2791, 'base': 269, 'circular': 498, 'hk': 1192, 'concern': 557, 'menu': 1732, 'prepar': 2207, 'agenc': 58, 'three': 2909, 'pillar': 2130, 'desa': 708, 'bungatang': 403, 'hold': 1199, 'deliber': 689, 'process': 2234, 'continu': 578, 'run': 2438, 'around': 170, 'world': 3187, 'regardless': 2353, 'whether': 3153, 'benefici': 295, 'resid': 2391, 'enthusiast': 877, 'member': 1722, 'panarukan': 2009, 'siamap': 2578, 'siaman': 2577, 'carri': 435, 'secur': 2510, 'statu': 2712, 'involv': 1332, 'student': 2736, 'ipt': 1334, 'staff': 2699, 'septemb': 2539, '

# [CV 4/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.863 total time=   0.2s
# [CV 5/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.845 total time=   0.2s
# [CV 1/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.824 total time=   0.2s
# [CV 2/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.841 total time=   0.2s
# [CV 3/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.823 total time=   0.2s
# [CV 4/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.854 total time=   0.2s
# [CV 5/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.845 total time=   0.2s
# [CV 1/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.656 total time=   0.2s
# [CV 2/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.668 total time=   0.2s
# [CV 3/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.664 total time=   0.2s
# [CV 4/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.668 total time=   0.2s
# [CV 5/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.664 total time=   0.2s
# [CV 1/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.656 total time=   0.2s
# [CV 2/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.659 total time=   0.1s
# [CV 3/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.659 total time=   0.2s
# [CV 4/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.659 total time=   0.1s
# [CV 5/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.655 total time=   0.2s
# [CV 1/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.767 total time=   0.2s
# [CV 2/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.774 total time=   0.2s
# [CV 3/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.774 total time=   0.2s
# [CV 4/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.757 total time=   0.2s
# [CV 5/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.739 total time=   0.2s
# [CV 1/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.828 total time=   0.2s
# [CV 2/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.827 total time=   0.2s
# [CV 3/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.827 total time=   0.2s
# [CV 4/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.863 total time=   0.2s
# [CV 5/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.845 total time=   0.2s
# [CV 1/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.828 total time=   0.2s
# [CV 2/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.832 total time=   0.2s
# [CV 3/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.836 total time=   0.2s
# [CV 4/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.863 total time=   0.2s
# [CV 5/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.845 total time=   0.2s
# [CV 1/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.824 total time=   0.2s
# [CV 2/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.841 total time=   0.2s
# [CV 3/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.823 total time=   0.2s
# [CV 4/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.854 total time=   0.2s
# [CV 5/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.845 total time=   0.2s
# [CV 1/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.656 total time=   0.2s
# [CV 2/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.668 total time=   0.2s
# [CV 3/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.664 total time=   0.2s
# [CV 4/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.668 total time=   0.2s
# [CV 5/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.664 total time=   0.2s
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['rbf']},
#              verbose=3)

# %%
# print best parameter after tuning
print(grid.best_params_)

# print how our model looks after hyper-parameter tunning
print(grid.best_estimator_)
# Out:
# {'C': 1000, 'gamma': 0.01, 'kernel': 'rbf'}
# SVC(C=1000, gamma=0.01)

# %%
# re-run prediction model 
grid_predictions = grid.predict(Test_X_Tfidf)

#print classification report
print(classification_report(Test_Y, grid_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.33      0.44        21
#            1       0.86      0.96      0.91       199
#            2       0.90      0.68      0.77        63
#
#     accuracy                           0.86       283
#    macro avg       0.80      0.66      0.71       283
# weighted avg       0.85      0.86      0.84       283

# %% [markdown]
# > **Classifier - SVM Algorithm**

# %%
# fit the training dataset on the classifier
SVM = svm.SVC(C=1000, kernel='rbf', gamma=0.01)
SVM.fit(Train_X_Tfidf,Train_Y)

# predict the labels on validation dataset
predictions_SVM = SVM.predict(Test_X_Tfidf)

# %% [markdown]
# > **Visualize Classifier - SVM Algorithm**

# %%
# visualize classifier SVM algorithm toward the data
conf_matrix = confusion_matrix(Test_Y, predictions_SVM)
class_label = ["NEGATIF", "NETRAL", "POSITIF"]
test = pd.DataFrame(conf_matrix, index = class_label, columns = class_label)
sns.heatmap(test, annot = True, fmt = "d")
plt.title("Confusion Matrix SVM")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
# SVM RESULT
print("SVM RESULT")
print("Accuracy Score =",accuracy_score(predictions_SVM, Test_Y))
precision, recall, fscore, support = score(Test_Y, predictions_SVM, average='weighted')
print("Precision =", precision)
print("Recall =", recall)
print("F-score =", fscore)
# Out:
# SVM RESULT
# Accuracy Score = 0.8551236749116607
# Precision = 0.8493730209719609
# Recall = 0.8551236749116607
# F-score = 0.8432890214852097

# %% [markdown]
# # **Random-forest-Classifier Algorithm**
# > **data training 80% dan data testing 20% dengan menjadikan test_size=0.2**

# %% [markdown]
# ## **Random-forest-Classifier Algorithm**
# > **Hyperparameter Tuning**

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier

# %%
# # Number of trees in random forest
# n_estimators = [int(x) for x in np.linspace(start = 10, stop = 80, num = 10)]
# # Number of features to consider at every split
# max_features = ['auto', 'sqrt']
# # Maximum number of levels in tree
# max_depth = [4,10]
# # Minimum number of samples required to split a node
# min_samples_split = [2, 5]
# # Minimum number of samples required at each leaf node
# min_samples_leaf = [1, 2]
# # Method of selecting samples for training each tree
# bootstrap = [True, False]
# ------------------------------------------------------------------------------------------------------------

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 50, stop = 300, num = 5)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 110, num = 5)]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Method of selecting samples for training each tree
bootstrap = [True, False]

# %%
# Create the param grid
param_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}
print(param_grid)
# Out:
# {'n_estimators': [50, 112, 175, 237, 300], 'max_features': ['auto', 'sqrt'], 'max_depth': [10, 35, 60, 85, 110, None], 'min_samples_split': [2, 5, 10], 'min_samples_leaf': [1, 2, 4], 'bootstrap': [True, False]}

# %%
rf_Model = RandomForestClassifier()

# %%
from sklearn.model_selection import GridSearchCV
rf_Grid = GridSearchCV(estimator = rf_Model, param_grid = param_grid, cv = 3, verbose=2, n_jobs = 4)

# %%
rf_Grid.fit(Train_X_Tfidf, Train_Y)
# Out:
# Fitting 3 folds for each of 1080 candidates, totalling 3240 fits
# GridSearchCV(cv=3, estimator=RandomForestClassifier(), n_jobs=4,
#              param_grid={'bootstrap': [True, False],
#                          'max_depth': [10, 35, 60, 85, 110, None],
#                          'max_features': ['auto', 'sqrt'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [50, 112, 175, 237, 300]},
#              verbose=2)

# %%
# print how our model looks after hyper-parameter tunning
rf_Grid.best_params_
# Out:
# {'bootstrap': False,
#  'max_depth': 110,
#  'max_features': 'auto',
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 237}

# %%
#check accuracy
print (f'Train Accuracy - : {rf_Grid.score(Train_X_Tfidf,Train_Y ):.3f}')
print (f'Test Accuracy - : {rf_Grid.score(Test_X_Tfidf,Test_Y):.3f}')
# Out:
# Train Accuracy - : 1.000
# Test Accuracy - : 0.905

# %% [markdown]
# > **Classifier - Random-forest Algorithm**

# %%
# from sklearn.model_selection import train_test_split
# from sklearn import model_selection

# fit the training dataset on the classifier
rf_clf = RandomForestClassifier(n_estimators=237, max_depth= 110, max_features='auto', bootstrap=False, min_samples_leaf=1, min_samples_split=2)
rf_clf.fit(Train_X_Tfidf, Train_Y)

# predict the labels on validation dataset
predictions_RFC = rf_clf.predict(Test_X_Tfidf )

# %% [markdown]
# > **Visualize Classifier - Random-forest Algorithm**

# %%
# visualize classifier Random-forest algorithm toward the data
conf_matrix = confusion_matrix(Test_Y, predictions_RFC)
class_label = ["NEGATIF", "NETRAL", "POSITIF"]
test = pd.DataFrame(conf_matrix, index = class_label, columns = class_label)
sns.heatmap(test, annot = True, fmt = "d")
plt.title("Confusion Matrix Random-Forest")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
# RANDOM FOREST RESULT
print("RANDOM FOREST RESULT")
print("Accuracy Score =",accuracy_score(predictions_RFC, Test_Y))
precision, recall, fscore, support = score(Test_Y, predictions_RFC, average='weighted')
print("Precision =", precision)
print("Recall =", recall)
print("F-score =", fscore)
# Out:
# RANDOM FOREST RESULT
# Accuracy Score = 0.901060070671378
# Precision = 0.9053359133537873
# Recall = 0.901060070671378
# F-score = 0.8930718603989081

# %% [markdown]
# <br>

# %% [markdown]
# ------------------------------------------

# %% [markdown]
# #@Additional Experiment
# ### **Repository Draft for SVM and Random-forest-Classifier Algorithm**

# %%
# !pip install Sastrawi
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk) (1.15.0)

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (1.0.1)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.4.1)
# Requirement already satisfied: numpy>=1.14.6 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.19.5)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (3.0.0)

# %%
# !pip install pydotplus
# Out:
# Requirement already satisfied: pydotplus in /usr/local/lib/python3.7/dist-packages (2.0.2)
# Requirement already satisfied: pyparsing>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from pydotplus) (3.0.6)

# %%
#mount process for access google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Import Library
import pandas as pd
import numpy as np
import string
import os
import re
from datetime import datetime

# Import matplotlib library for visualize the data
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import NLTK library - word_tokenize library for tokenization process using nltk
# for process of pos-tagging, lemmatization and cleaning the stopwords  
import nltk
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize 
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
from nltk.stem import LancasterStemmer
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')

# Import Sklearn Library
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import accuracy_score, confusion_matrix, recall_score, f1_score, precision_score, plot_confusion_matrix
from sklearn.metrics import precision_recall_fscore_support as score

from sklearn import model_selection, svm 
from sklearn import svm #for svm algorithm
from sklearn.svm import SVC

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
import sklearn.tree as tree

# ------------------------------------------------------------------------------------------------------------------------------------
# Additional library for data pre-processing process
import spacy
import csv

from sklearn.feature_extraction.text import CountVectorizer
from sklearn import model_selection, naive_bayes 
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

import pydotplus
#from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
#from Sastrawi.Stemmer.StemmerFactory import StemmerFactory #import Indonesian Stemmer
from scipy.spatial import distance
from six import StringIO
from IPython.display import Image
porter_stemmer = PorterStemmer()

#for stopwords removal
from spacy.lang.en import English

#load English tokenizer, tagger, parser, NER and word vectors
nlp = English()
from spacy.lang.en.stop_words import STOP_WORDS
sp = spacy.load('en_core_web_sm')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %% [markdown]
# # **SVM Classifier Algorithm (Support vector machine Algorithm)**
# > **data training 70% dan data testing 30% dengan menjadikan test_size=0.3**

# %% [markdown]
# ## **Hold-Out Method**

# %%
corpus = pd.read_excel('/content/drive/MyDrive/SKRIPSI_TEXT_MINING/sample_reviews_2.1_nolemma.xlsx')

# %%
corpus.head()
# Out:
#           username  ...    label
# 0           pqrzan  ...   netral
# 1     mcreativepky  ...   netral
# 2        veemarisa  ...   netral
# 3          GSaraw4  ...  positif
# 4  Papalov03973158  ...   netral
#
# [5 rows x 11 columns]

# %% [markdown]
# > **Text Classification dan Kalkulasi Akurasi**
# - data training 70% dan data testing 30% dengan menjadikan test_size=0.3

# %%
#rename colume text_lemmatized into text_final
corpus = corpus.rename(columns={'text_stemmed':'text_final'})

#HOLD-OUT - Dividing testing and training data
Train_X,Test_X,Train_Y,Test_Y = train_test_split(corpus['text_final'],corpus['label'],test_size=0.3)

# Label encode - transform Categorical data of string (negatif, netral, positif) into numerical values (0,1,2)
Encoder = LabelEncoder()
Train_Y = Encoder.fit_transform(Train_Y)
Test_Y = Encoder.fit_transform(Test_Y)

# %%
#TF-IDF Vectorizer 
Tfidf_vect = TfidfVectorizer(max_features=5000)
Tfidf_vect.fit(corpus['text_final'])

Train_X_Tfidf = Tfidf_vect.transform(Train_X)
Test_X_Tfidf = Tfidf_vect.transform(Test_X)

#CHECKING
print(Tfidf_vect.vocabulary_)
print(Train_X_Tfidf)
# Out:
# {'cross': 629, 'stat': 2707, 'allow': 89, 'roadblock': 2420, 'check': 473, 'person': 2101, 'either': 836, 'complet': 550, 'vaccin': 3047, 'keep': 1441, 'covid': 613, 'tangkelil': 2847, 'puskesk': 2287, 'build': 396, 'batu': 274, 'polic': 2163, 'chief': 476, 'personnel': 2102, 'pam': 2004, 'control': 582, 'movement': 1810, 'refus': 2352, 'receiv': 2336, 'inject': 1300, 'freedom': 1031, 'save': 2476, 'famili': 953, 'prove': 2257, 'safe': 2452, 'import': 1262, 'done': 767, 'increas': 1275, 'bodi': 354, 'immun': 1257, 'avoid': 211, 'spread': 2687, 'individu': 1283, 'take': 2832, 'still': 2716, 'countri': 606, 'need': 1865, 'adher': 37, 'exist': 921, 'sop': 2658, 'like': 1575, 'enthusiasm': 876, 'commun': 545, 'particip': 2032, 'high': 1184, 'proven': 2258, 'commemor': 539, 'tni': 2930, 'anniversari': 122, 'east': 823, 'java': 1364, 'region': 2357, 'appreci': 158, 'simultan': 2592, 'creation': 622, 'herd': 1178, 'pandem': 2012, 'humanitarian': 1228, 'problem': 2230, 'across': 25, 'nation': 1852, 'alhamdulillah': 84, 'dki': 757, 'jakarta': 1353, 'provinci': 2261, 'govern': 1094, 'collabor': 527, 'deng': 700, 'lead': 1547, 'coordin': 592, 'meet': 1713, 'acceler': 14, 'aglomer': 61, 'regenc': 2354, 'citi': 502, 'let': 1565, 'immedi': 1256, 'order': 1968, 'reduc': 2348, 'number': 1915, 'must': 1830, 'compli': 551, 'health': 1163, 'protocol': 2254, 'make': 1643, 'sure': 2791, 'base': 269, 'circular': 498, 'hk': 1192, 'concern': 557, 'menu': 1732, 'prepar': 2207, 'agenc': 58, 'three': 2909, 'pillar': 2130, 'desa': 708, 'bungatang': 403, 'hold': 1199, 'deliber': 689, 'process': 2234, 'continu': 578, 'run': 2438, 'around': 170, 'world': 3187, 'regardless': 2353, 'whether': 3153, 'benefici': 295, 'resid': 2391, 'enthusiast': 877, 'member': 1722, 'panarukan': 2009, 'siamap': 2578, 'siaman': 2577, 'carri': 435, 'secur': 2510, 'statu': 2712, 'involv': 1332, 'student': 2736, 'ipt': 1334, 'staff': 2699, 'septemb': 2539, 'pleas': 2148, 'risk': 2414, 'mysejahtera': 1836, 'hous
#   (2, 3047)	0.20576995730014827
#   (2, 2748)	0.49792351849243216
#   (2, 2251)	0.40878898369467415
#   (2, 2172)	0.46022591241702837
#   (2, 2080)	0.35059722676586325
#   (2, 1286)	0.45595630858524877
#   (3, 3047)	0.05151056822651037
#   (3, 2551)	0.29115473747667203
#   :	:
#   (985, 2725)	0.4058105732594132
#   (985, 2214)	0.3148281066822335
#   (985, 2187)	0.3593757380443497
#   (985, 1865)	0.31110540975195855
#   (985, 613)	0.16979435890461855
#   (985, 570)	0.4226464551495546
#   (986, 3047)	0.06255598151822267
#   (986, 2389)	0.27012505971834905
#   (986, 2362)	0.4023405224447219
#   (986, 2361)	0.4023405224447219
#   (986, 2121)	0.3285793811776787
#   (986, 2095)	0.4023405224447219
#   (986, 1991)	0.4023405224447219
#   (986, 729)	0.3285793811776787
#   (986, 550)	0.24429244321892257
#   (987, 3145)	0.3493651394820286
#   (987, 3047)	0.07314126743885381
#   (987, 2255)	0.47042177325673046
#   (987, 1652)	0.4273005302590779
#   (987, 1651)	0.3493651394820286
#   (987, 763)	0.35895497712331387
#   (987, 610)	0.37029734765401606
#   (987, 23)	0.28405486165871097
#   (988, 3047)	0.23068729447854044
#   (988, 2487)	0.9730279400747807

# %% [markdown]
# ## **SVM Classifier Algorithm (Support vector machine Algorithm)**

# %%
# fit the training dataset on the classifier
#SVM = svm.SVC(C=1.0, kernel='rbf', degree=3, gamma='scale')
SVM = svm.SVC()
SVM.fit(Train_X_Tfidf,Train_Y)

# predict the labels on validation dataset
predictions_SVM = SVM.predict(Test_X_Tfidf)

# %%
# visualize classifier SVM algorithm toward the data
conf_matrix = confusion_matrix(Test_Y, predictions_SVM)
class_label = ["NEGATIF", "NETRAL", "POSITIF"]
test = pd.DataFrame(conf_matrix, index = class_label, columns = class_label)
sns.heatmap(test, annot = True, fmt = "d")
plt.title("Confusion Matrix SVM")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
# SVM RESULT
print("SVM RESULT")
print("Accuracy Score =",accuracy_score(predictions_SVM, Test_Y))
precision, recall, fscore, support = score(Test_Y, predictions_SVM, average='weighted')
print("Precision =", precision)
print("Recall =", recall)
print("F-score =", fscore)
# Out:
# SVM RESULT
# Accuracy Score = 0.7247058823529412
# Precision = 0.7138693467336683
# Recall = 0.7247058823529412
# F-score = 0.6483172012947634
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # **Random-forest-Classifier Algorithm**
# > **data training 70% dan data testing 30% dengan menjadikan test_size=0.3**

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# > **Classifier - Random-forest Algorithm**

# %%
# from sklearn.model_selection import train_test_split
# from sklearn import model_selection

# fit the training dataset on the classifier
# rf_clf = RandomForestClassifier(n_estimators=100, max_depth= 'None', max_features='auto', bootstrap=True, min_samples_leaf=1, min_samples_split=2)
rf_clf = RandomForestClassifier()
rf_clf.fit(Train_X_Tfidf, Train_Y)

# predict the labels on validation dataset
predictions_RFC = rf_clf.predict(Test_X_Tfidf )

# %% [markdown]
# > **Visualize Classifier - Random-forest Algorithm**

# %%
# visualize classifier Random-forest algorithm toward the data
conf_matrix = confusion_matrix(Test_Y, predictions_RFC)
class_label = ["NEGATIF", "NETRAL", "POSITIF"]
test = pd.DataFrame(conf_matrix, index = class_label, columns = class_label)
sns.heatmap(test, annot = True, fmt = "d")
plt.title("Confusion Matrix Random-Forest")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
# RANDOM FOREST RESULT
print("RANDOM FOREST RESULT")
print("Accuracy Score =",accuracy_score(predictions_RFC, Test_Y))
precision, recall, fscore, support = score(Test_Y, predictions_RFC, average='weighted')
print("Precision =", precision)
print("Recall =", recall)
print("F-score =", fscore)
# Out:
# RANDOM FOREST RESULT
# Accuracy Score = 0.8588235294117647
# Precision = 0.8563003147671583
# Recall = 0.8588235294117647
# F-score = 0.8312811963571063

# %% [markdown]
# # **SVM Classifier Algorithm (Support vector machine Algorithm)**
# > **data training 80% dan data testing 20% dengan menjadikan test_size=0.2**

# %% [markdown]
# ## **Hold-Out Method**

# %%
corpus = pd.read_excel('/content/drive/MyDrive/SKRIPSI_TEXT_MINING/sample_reviews_2.1_nolemma.xlsx')

# %%
corpus.head()
# Out:
#           username  ...    label
# 0           pqrzan  ...   netral
# 1     mcreativepky  ...   netral
# 2        veemarisa  ...   netral
# 3          GSaraw4  ...  positif
# 4  Papalov03973158  ...   netral
#
# [5 rows x 11 columns]

# %% [markdown]
# > **Text Classification dan Kalkulasi Akurasi**
# - data training 80% dan data testing 20% dengan menjadikan test_size=0.2

# %%
#rename colume text_lemmatized into text_final
corpus = corpus.rename(columns={'text_stemmed':'text_final'})

#HOLD-OUT - Dividing testing and training data
Train_X,Test_X,Train_Y,Test_Y = train_test_split(corpus['text_final'],corpus['label'],test_size=0.2)

# Label encode - transform Categorical data of string (negatif, netral, positif) into numerical values (0,1,2)
Encoder = LabelEncoder()
Train_Y = Encoder.fit_transform(Train_Y)
Test_Y = Encoder.fit_transform(Test_Y)

# %%
#TF-IDF Vectorizer 
Tfidf_vect = TfidfVectorizer(max_features=5000)
Tfidf_vect.fit(corpus['text_final'])

Train_X_Tfidf = Tfidf_vect.transform(Train_X)
Test_X_Tfidf = Tfidf_vect.transform(Test_X)

#CHECKING
print(Tfidf_vect.vocabulary_)
print(Train_X_Tfidf)
# Out:
# {'cross': 629, 'stat': 2707, 'allow': 89, 'roadblock': 2420, 'check': 473, 'person': 2101, 'either': 836, 'complet': 550, 'vaccin': 3047, 'keep': 1441, 'covid': 613, 'tangkelil': 2847, 'puskesk': 2287, 'build': 396, 'batu': 274, 'polic': 2163, 'chief': 476, 'personnel': 2102, 'pam': 2004, 'control': 582, 'movement': 1810, 'refus': 2352, 'receiv': 2336, 'inject': 1300, 'freedom': 1031, 'save': 2476, 'famili': 953, 'prove': 2257, 'safe': 2452, 'import': 1262, 'done': 767, 'increas': 1275, 'bodi': 354, 'immun': 1257, 'avoid': 211, 'spread': 2687, 'individu': 1283, 'take': 2832, 'still': 2716, 'countri': 606, 'need': 1865, 'adher': 37, 'exist': 921, 'sop': 2658, 'like': 1575, 'enthusiasm': 876, 'commun': 545, 'particip': 2032, 'high': 1184, 'proven': 2258, 'commemor': 539, 'tni': 2930, 'anniversari': 122, 'east': 823, 'java': 1364, 'region': 2357, 'appreci': 158, 'simultan': 2592, 'creation': 622, 'herd': 1178, 'pandem': 2012, 'humanitarian': 1228, 'problem': 2230, 'across': 25, 'nation': 1852, 'alhamdulillah': 84, 'dki': 757, 'jakarta': 1353, 'provinci': 2261, 'govern': 1094, 'collabor': 527, 'deng': 700, 'lead': 1547, 'coordin': 592, 'meet': 1713, 'acceler': 14, 'aglomer': 61, 'regenc': 2354, 'citi': 502, 'let': 1565, 'immedi': 1256, 'order': 1968, 'reduc': 2348, 'number': 1915, 'must': 1830, 'compli': 551, 'health': 1163, 'protocol': 2254, 'make': 1643, 'sure': 2791, 'base': 269, 'circular': 498, 'hk': 1192, 'concern': 557, 'menu': 1732, 'prepar': 2207, 'agenc': 58, 'three': 2909, 'pillar': 2130, 'desa': 708, 'bungatang': 403, 'hold': 1199, 'deliber': 689, 'process': 2234, 'continu': 578, 'run': 2438, 'around': 170, 'world': 3187, 'regardless': 2353, 'whether': 3153, 'benefici': 295, 'resid': 2391, 'enthusiast': 877, 'member': 1722, 'panarukan': 2009, 'siamap': 2578, 'siaman': 2577,
#   (2, 2341)	0.3672019691752491
#   (2, 2230)	0.31440406264047643
#   (2, 745)	0.4178326891649829
#   (2, 725)	0.34123136692128264
#   (2, 458)	0.2995808211559491
#   (2, 90)	0.34123136692128264
#   (2, 20)	0.37953202804313274
#   (3, 3047)	0.13127693279780814
#   (3, 2739)	0.4221661018253289
#   (3, 2716)	0.24358659705930238
#   (3, 2413)	0.4221661018253289
#   (3, 2364)	0.36083140733474267
#   (3, 2336)	0.28343563997409027
#   :	:
#   (1127, 598)	0.3548929171278167
#   (1127, 513)	0.30041068231193035
#   (1127, 502)	0.2478000608326132
#   (1127, 383)	0.30041068231193035
#   (1128, 3047)	0.12050296418300484
#   (1128, 2892)	0.561905839635627
#   (1128, 2817)	0.6811225367886113
#   (1128, 988)	0.4536661249036976
#   (1129, 3047)	0.0635842882510533
#   (1129, 2352)	0.40895426997260587
#   (1129, 2336)	0.27456542514581406
#   (1129, 1810)	0.38702588586172776
#   (1129, 1300)	0.2702365514547348
#   (1129, 1031)	0.35939938911115826
#   (1129, 582)	0.6335159979910545
#   (1130, 2484)	0.22542010517894506
#   (1130, 2357)	0.192930195240517
#   (1130, 2260)	0.3177488199210051
#   (1130, 2209)	0.19747739596388433
#   (1130, 1549)	0.3177488199210051
#   (1130, 1074)	0.23909455261154702
#   (1130, 1020)	0.6354976398420102
#   (1130, 592)	0.2715844625499751
#   (1130, 380)	0.3177488199210051
#   (1130, 94)	0.18786133373708974

# %% [markdown]
# ## **SVM Classifier Algorithm (Support vector machine Algorithm)**

# %%
# fit the training dataset on the classifier
#SVM = svm.SVC(C=1.0, kernel='rbf', degree=3, gamma='scale')
SVM = svm.SVC()
SVM.fit(Train_X_Tfidf,Train_Y)

# predict the labels on validation dataset
predictions_SVM = SVM.predict(Test_X_Tfidf)

# %%
# visualize classifier SVM algorithm toward the data
conf_matrix = confusion_matrix(Test_Y, predictions_SVM)
class_label = ["NEGATIF", "NETRAL", "POSITIF"]
test = pd.DataFrame(conf_matrix, index = class_label, columns = class_label)
sns.heatmap(test, annot = True, fmt = "d")
plt.title("Confusion Matrix SVM")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
# SVM RESULT
print("SVM RESULT")
print("Accuracy Score =",accuracy_score(predictions_SVM, Test_Y))
precision, recall, fscore, support = score(Test_Y, predictions_SVM, average='weighted')
print("Precision =", precision)
print("Recall =", recall)
print("F-score =", fscore)
# Out:
# SVM RESULT
# Accuracy Score = 0.7597173144876325
# Precision = 0.7379974623790878
# Recall = 0.7597173144876325
# F-score = 0.6982898892132261
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # **Random-forest-Classifier Algorithm**
# > **data training 80% dan data testing 20% dengan menjadikan test_size=0.2**

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# > **Classifier - Random-forest Algorithm**

# %%
# from sklearn.model_selection import train_test_split
# from sklearn import model_selection

# fit the training dataset on the classifier
# rf_clf = RandomForestClassifier(n_estimators=100, max_depth= 'None', max_features='auto', bootstrap=True, min_samples_leaf=1, min_samples_split=2)
rf_clf = RandomForestClassifier()
rf_clf.fit(Train_X_Tfidf, Train_Y)

# predict the labels on validation dataset
predictions_RFC = rf_clf.predict(Test_X_Tfidf )

# %% [markdown]
# > **Visualize Classifier - Random-forest Algorithm**

# %%
# visualize classifier Random-forest algorithm toward the data
conf_matrix = confusion_matrix(Test_Y, predictions_RFC)
class_label = ["NEGATIF", "NETRAL", "POSITIF"]
test = pd.DataFrame(conf_matrix, index = class_label, columns = class_label)
sns.heatmap(test, annot = True, fmt = "d")
plt.title("Confusion Matrix Random-Forest")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
# RANDOM FOREST RESULT
print("RANDOM FOREST RESULT")
print("Accuracy Score =",accuracy_score(predictions_RFC, Test_Y))
precision, recall, fscore, support = score(Test_Y, predictions_RFC, average='weighted')
print("Precision =", precision)
print("Recall =", recall)
print("F-score =", fscore)
# Out:
# RANDOM FOREST RESULT
# Accuracy Score = 0.8798586572438163
# Precision = 0.8911481995625106
# Recall = 0.8798586572438163
# F-score = 0.8659912737568992
