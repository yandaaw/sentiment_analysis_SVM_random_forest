# %%
import pandas as pd
import numpy as np

from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, recall_score, f1_score, precision_score, plot_confusion_matrix
from sklearn.svm import SVC
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier


# Additional library
import os
import re
from datetime import datetime
import matplotlib.pyplot as plt

# %%
# !pip install google-trans-new
# !pip install googletrans==3.1.0a0
# Out:
# Collecting google-trans-new
#   Downloading google_trans_new-1.1.9-py3-none-any.whl (9.2 kB)
# Installing collected packages: google-trans-new
# Successfully installed google-trans-new-1.1.9
# Collecting googletrans==3.1.0a0
#   Downloading googletrans-3.1.0a0.tar.gz (19 kB)
# Collecting httpx==0.13.3
#   Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 2.9 MB/s
# Requirement already satisfied: chardet==3.* in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (3.0.4)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2021.10.8)
# Collecting httpcore==0.9.*
#   Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 1.4 MB/s
# Requirement already satisfied: idna==2.* in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2.10)
# Collecting sniffio
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Collecting rfc3986<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting hstspreload
#   Downloading hstspreload-2021.11.1-py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 18.3 MB/s
# Collecting h2==3.*
#   Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 3.9 MB/s
# Collecting h11<0.10,>=0.8
#   Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 2.6 MB/s
# Collecting hpack<4,>=3.0
#   Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Collecting hyperframe<6,>=5.2.0
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-3.1.0a0-py3-none-any.whl size=16367 sha256=38f18c3d12a568ad2af9281b21b44bb52b1132628eaad717b5abeec73d979b5c
#   Stored in directory: /root/.cache/pip/wheels/0c/be/fe/93a6a40ffe386e16089e44dad9018ebab9dc4cb9eb7eab65ae
# Successfully built googletrans
# Installing collected packages: hyperframe, hpack, sniffio, h2, h11, rfc3986, httpcore, hstspreload, httpx, googletrans
# Successfully installed googletrans-3.1.0a0 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2021.11.1 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 rfc3986-1.5.0 sniffio-1.2.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_sep = pd.read_excel('/content/drive/MyDrive/SKRIPSI_TEXT_MINING/oktober_1000.xlsx')
df_okt = pd.read_excel('/content/drive/MyDrive/SKRIPSI_TEXT_MINING/oktober_2000.xlsx')
df_okt_akh = pd.read_excel('/content/drive/MyDrive/SKRIPSI_TEXT_MINING/oktober_akhir_1000.xlsx')

# %%
# cek value count
df_sep['tanggal_tweet'].value_counts()

# for col in df_sep:
#   print(df_sep[col].unique)
# Out:
# 2021-10-03 23:55:08    2
# 2021-10-03 23:32:52    2
# 2021-10-04 23:51:45    2
# 2021-09-30 23:53:24    2
# 2021-10-05 23:41:43    2
#                       ..
# 2021-10-04 23:42:29    1
# 2021-10-03 23:31:03    1
# 2021-10-02 23:45:03    1
# 2021-10-03 23:52:29    1
# 2021-10-04 23:35:00    1
# Name: tanggal_tweet, Length: 763, dtype: int64

# %%
#merge dataset
frames = [df_sep, df_okt, df_okt_akh]
df = pd.concat(frames)

#replace column's name
df = df.rename(columns={"tanggal_tweet": "date", "pengguna": "username", "tweet":"tweet"})
df = df[['date','username','tweet']]

# %%
df.head() #2500 rows × 3 columns
# Out:
#                  date  ...                                              tweet
# 0 2021-10-07 23:59:59  ...  RT @KKMPutrajaya: Selepas rentas negeri dibena...
# 1 2021-10-07 23:59:56  ...  Jaga Vaksinasi Covid-19 di Puskesmas Tangkilin...
# 2 2021-10-07 23:59:21  ...  RT @KKMPutrajaya: mengawal pergerakan mereka y...
# 3 2021-10-07 23:58:22  ...  Vaksinasi untuk Menyelamatkan diri sendiri dan...
# 4 2021-10-07 23:58:14  ...  Vaksinasi penting dilakukan untuk meningkatkan...
#
# [5 rows x 3 columns]

# %% [markdown]
# ## CLEANSING DATA

# %%
import string
string.punctuation

# #function
# def remove_punctuation(txt):
#   txt_nopunct = [c for c in txt if c not in string.punctuation]
#   return txt_punct 

# #apply function
# df['clean_tweet'] = df['tweet'].apply(lambda x: remove_punctuation())
# df
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %% [markdown]
# > **data cleansing process including Removing Punctuation inside**

# %%
# Mengubah kata ke lowercase
# def caseFolding(text):
#     text = text.lower()
#     return text

# Menghilangkan karakter khusus dan angka / REMOVING PUNCTUATION
def cleansing(text):
    text = ' '.join(re.sub("[@#][A-Za-z0-9_]+|([^0-9A-Za-z \t])|(\w+:\/\/\S+)+|^https?:\/\/.*[\r\n]*"," ", text).split(' '))
    text = re.sub(r"\d+", "", text)
    text = ' '.join(text.split())
    return text

# Menghilangkan duplicate
# def remove_duplikat_tweet(tweet_array):
#     text_list_tweet = list()
#     list_tweet     = list()
#     for x in tweet_array:
#         if x['clean_tweet'] not in text_list_tweet:
#             text_list_tweet.append(x['clean_tweet'])
#             list_tweet.append(x)
#     return list_tweet

# %%
list_tweet = list()
for index, row in df.iterrows():
    _tweet = row['tweet']
    # _tweet = caseFolding(_tweet)
    _tweet = cleansing(_tweet)
    
    tmp_list = {
        #'id'          : row['id'], 
        'username'    : row['username'],
        'tweet'       : row['tweet'],
        'clean_tweet' : _tweet
    }
    list_tweet.append(tmp_list)

df_list_tweet = pd.DataFrame(list_tweet)
df_list_tweet['clean_tweet']=df_list_tweet['clean_tweet'].replace(regex={'RT': ''})

# %%
df_list_tweet
# print(list_tweet)
# Out:
#              username  ...                                        clean_tweet
# 0              pqrzan  ...   Selepas rentas negeri dibenarkan tiada sekata...
# 1        mcreativepky  ...  Jaga Vaksinasi Covid di Puskesmas Tangkiling K...
# 2           veemarisa  ...   mengawal pergerakan mereka yang enggan meneri...
# 3             GSaraw4  ...  Vaksinasi untuk Menyelamatkan diri sendiri dan...
# 4     Papalov03973158  ...  Vaksinasi penting dilakukan untuk meningkatkan...
# ...               ...  ...                                                ...
# 2495       sssatpolll  ...  Vaksinasi Bukan Hanya Semata Menyelamatkan Dir...
# 2496          KangOys  ...   Santri Siaga Jiwa Raga turut jadi pedoman di ...
# 2497    AmierHamzah75  ...   Tahniah amp Syabas Kementerian Kesihatan Mala...
# 2498     parwatyRizky  ...   Dilansir dari Nikkei Asia total skor dalam in...
# 2499      AnggaHertoh  ...   Orang yang divaksinasi lengkap berusia memili...
#
# [2500 rows x 3 columns]

# %%
# Menghilangkan tweet yang sama dari data hasil cleansing
new_list_tweet = df_list_tweet.drop_duplicates(subset=['clean_tweet'])
print('Total tweet sebelum sebelum duplicate :', len(df_list_tweet))
print('Total tweet sesudah sesudah remove duplicate :', len(new_list_tweet))

df_new_list_tweet = pd.DataFrame(new_list_tweet)
df_new_list_tweet
# Out:
# Total tweet sebelum sebelum duplicate : 2500
# Total tweet sesudah sesudah remove duplicate : 1415
#              username  ...                                        clean_tweet
# 0              pqrzan  ...   Selepas rentas negeri dibenarkan tiada sekata...
# 1        mcreativepky  ...  Jaga Vaksinasi Covid di Puskesmas Tangkiling K...
# 2           veemarisa  ...   mengawal pergerakan mereka yang enggan meneri...
# 3             GSaraw4  ...  Vaksinasi untuk Menyelamatkan diri sendiri dan...
# 4     Papalov03973158  ...  Vaksinasi penting dilakukan untuk meningkatkan...
# ...               ...  ...                                                ...
# 2491       KontanNews  ...   Vaksinasi Covid per Oktober bertambah juta dosis
# 2492  SuaraBojonegoro  ...  Edukasi Vaksinasi Kepada Warga Oleh Bhabinkamt...
# 2494       sssatpolll  ...  Keberhasilan PPKM Vaksinasi Dan Disiplin Proke...
# 2496          KangOys  ...   Santri Siaga Jiwa Raga turut jadi pedoman di ...
# 2499      AnggaHertoh  ...   Orang yang divaksinasi lengkap berusia memili...
#
# [1415 rows x 3 columns]

# %%
#export df_new_list_tweet to google drive
# df_new_list_tweet.to_excel('/content/drive/MyDrive/SKRIPSI_TEXT_MINING/df_new_list_tweet_2.1.xlsx')

# %% [markdown]
# ## Translate tweet ke bahasa inggris

# %% [markdown]
# > **install googletrans library**
# - https://youtu.be/8zfS23WSIuI
# - https://py-googletrans.readthedocs.io/en/latest/ [*googletrans*]

# %%
# !pip install googletrans
# !pip install google-trans-new
# !pip install google_trans_new
# Out:
# Collecting googletrans
#   Downloading googletrans-3.0.0.tar.gz (17 kB)
# Collecting httpx==0.13.3
#   Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 2.8 MB/s
# Requirement already satisfied: chardet==3.* in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans) (3.0.4)
# Collecting hstspreload
#   Downloading hstspreload-2021.12.1-py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 24.5 MB/s
# Collecting rfc3986<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting httpcore==0.9.*
#   Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 1.3 MB/s
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans) (2021.10.8)
# Requirement already satisfied: idna==2.* in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans) (2.10)
# Collecting sniffio
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Collecting h2==3.*
#   Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 3.7 MB/s
# Collecting h11<0.10,>=0.8
#   Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 2.2 MB/s
# Collecting hyperframe<6,>=5.2.0
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Collecting hpack<4,>=3.0
#   Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-3.0.0-py3-none-any.whl size=15735 sha256=85d31c7579303913d40e98d1beb49d0b68e9608275c40adb6d7b69d7164d9849
#   Stored in directory: /root/.cache/pip/wheels/20/da/eb/a54579056f265eede0417df537dd56d3df5b9eb2b25df0003d
# Successfully built googletrans
# Installing collected packages: hyperframe, hpack, sniffio, h2, h11, rfc3986, httpcore, hstspreload, httpx, googletrans
# Successfully installed googletrans-3.0.0 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2021.12.1 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 rfc3986-1.5.0 sniffio-1.2.0
# Collecting google-trans-new
#   Downloading google_trans_new-1.1.9-py3-none-any.whl (9.2 kB)
# Installing collected packages: google-trans-new
# Successfully installed google-trans-new-1.1.9
# Requirement already satisfied: google_trans_new in /usr/local/lib/python3.7/dist-packages (1.1.9)

# %%
# !pip install googletrans==3.1.0a0
# Out:
# Collecting googletrans==3.1.0a0
#   Downloading googletrans-3.1.0a0.tar.gz (19 kB)
# Requirement already satisfied: httpx==0.13.3 in /usr/local/lib/python3.7/dist-packages (from googletrans==3.1.0a0) (0.13.3)
# Requirement already satisfied: idna==2.* in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2.10)
# Requirement already satisfied: hstspreload in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2021.12.1)
# Requirement already satisfied: chardet==3.* in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (3.0.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (1.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2021.10.8)
# Requirement already satisfied: httpcore==0.9.* in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (0.9.1)
# Requirement already satisfied: rfc3986<2,>=1.3 in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (1.5.0)
# Requirement already satisfied: h11<0.10,>=0.8 in /usr/local/lib/python3.7/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (0.9.0)
# Requirement already satisfied: h2==3.* in /usr/local/lib/python3.7/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in /usr/local/lib/python3.7/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (3.0.0)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-3.1.0a0-py3-none-any.whl size=16367 sha256=12985f81dd668423d1b6aa0977bdaac75412e9803d381f8048aa870f45b7a15d
#   Stored in directory: /root/.cache/pip/wheels/0c/be/fe/93a6a40ffe386e16089e44dad9018ebab9dc4cb9eb7eab65ae
# Successfully built googletrans
# Installing collected packages: googletrans
#   Attempting uninstall: googletrans
#     Found existing installation: googletrans 3.0.0
#     Uninstalling googletrans-3.0.0:
#       Successfully uninstalled googletrans-3.0.0
# Successfully installed googletrans-3.1.0a0

# %%
# Contoh eng to ind
from googletrans import Translator
translator = Translator()
translator.translate('This sentence is written in English', dest='id').text
# Out:
# 'Kalimat ini ditulis dalam bahasa Inggris'

# %%
# Contoh ind to eng
from googletrans import Translator
translator = Translator()
translator.translate('Kalimat ini ditulis dalam bahasa Inggris', dest='en').text
# Out:
# 'This sentence is written in English'

# %%
translated_data = df_new_list_tweet
translated_data.head()
# Out:
#           username  ...                                        clean_tweet
# 0           pqrzan  ...   Selepas rentas negeri dibenarkan tiada sekata...
# 1     mcreativepky  ...  Jaga Vaksinasi Covid di Puskesmas Tangkiling K...
# 2        veemarisa  ...   mengawal pergerakan mereka yang enggan meneri...
# 3          GSaraw4  ...  Vaksinasi untuk Menyelamatkan diri sendiri dan...
# 4  Papalov03973158  ...  Vaksinasi penting dilakukan untuk meningkatkan...
#
# [5 rows x 3 columns]

# %%
#translate tweets to English
from googletrans import Translator
translator = Translator()

translations = []

for i in translated_data.index:
  translated = translator.translate(translated_data.clean_tweet[i], dest='en').text
  translations.append(translated)

# %%
# tampung hasil translate ke variable/dataframe translations
translations = pd.DataFrame(translations)

# gabungkan hasli translate kedalam data translated_data
translated_data['en_tweet'] = translations

# %%
translated_data
# Out:
#              username  ...                                           en_tweet
# 0              pqrzan  ...   After cross-state allowed no roadblocks to ch...
# 1        mcreativepky  ...  Keep Covid Vaccination at Tangkeliling Puskesk...
# 2           veemarisa  ...   Control the movement of those who refuse to r...
# 3             GSaraw4  ...  Vaccination to save yourself and the vaccine f...
# 4     Papalov03973158  ...  Important vaccination is done to increase the ...
# ...               ...  ...                                                ...
# 1410       KontanNews  ...  Covid vaccination as of October increases mill...
# 1411  SuaraBojonegoro  ...  Education vaccination to residents by Bhabinka...
# 1412       sssatpolll  ...  The success of PPKM Vaccination and Discipline...
# 1413          KangOys  ...   Santri Alert Soul Soul also became a guidelin...
# 1414      AnggaHertoh  ...   People who are vaccinated in full aged have a...
#
# [1415 rows x 4 columns]

# %%
#export df_new_list_tweet to google drive
# translated_data.to_excel('/content/drive/MyDrive/SKRIPSI_TEXT_MINING/translated_data_tweets_2.1.xlsx', index=False)

# %% [markdown]
# ## Data Pre-processing

# %%
# !pip install Sastrawi
# from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
# from Sastrawi.Stemmer.StemmerFactory import StemmerFactory #import Indonesian Stemmer

# from nltk.stem import LancasterStemmer

#from sklearn.feature_extraction.text import CountVectorizer

# %%
# Import Library
import pandas as pd
import numpy as np

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk) (1.15.0)

# %%
# word_tokenize library for tokenization process using nltk
import nltk
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize 
nltk.download('punkt')

# library for process of pos-tagging, lemmatization and cleaning the stopwords   
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
porter_stemmer = PorterStemmer()
from sklearn.feature_extraction.text import TfidfVectorizer # pembobotan kemudian u/ menghitung polarity
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')

# additional library
# from scipy.spatial import distance
# from sklearn.metrics.pairwise import cosine_similarity

# nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
sample_reviews = pd.read_excel('/content/drive/MyDrive/SKRIPSI_TEXT_MINING/translated_data_tweets_2.1.xlsx')

# %%
df_corpus = sample_reviews 
df_corpus.head()
# Out:
#           username  ...                                           en_tweet
# 0           pqrzan  ...   After cross-state allowed no roadblocks to ch...
# 1     mcreativepky  ...  Keep Covid Vaccination at Tangkeliling Puskesk...
# 2        veemarisa  ...   Control the movement of those who refuse to r...
# 3          GSaraw4  ...  Vaccination to save yourself and the vaccine f...
# 4  Papalov03973158  ...  Important vaccination is done to increase the ...
#
# [5 rows x 4 columns]

# %% [markdown]
# > **CASE FOLDING**

# %%
#konversi tweet ke LOWER CASE / CASE FOLDING
df_corpus['text'] = df_corpus['en_tweet'].str.lower()

# %%
# cek data null
# word_tokenize tidak akan jalan kalau data masih ada yang null
# data tweet null karena ada user yang tidak mention apapun

df_corpus.isnull().sum()
# Out:
# username       0
# tweet          0
# clean_tweet    1
# en_tweet       1
# text           1
# dtype: int64

# %%
df_corpus.head(5)
# Out:
#           username  ...                                               text
# 0           pqrzan  ...   after cross-state allowed no roadblocks to ch...
# 1     mcreativepky  ...  keep covid vaccination at tangkeliling puskesk...
# 2        veemarisa  ...   control the movement of those who refuse to r...
# 3          GSaraw4  ...  vaccination to save yourself and the vaccine f...
# 4  Papalov03973158  ...  important vaccination is done to increase the ...
#
# [5 rows x 5 columns]

# %% [markdown]
# > **TOKENIZATION**

# %%
#drop data null
corpus = df_corpus.dropna()

#konversi tweet ke proses TOKENIZATION menggunakan word_tokenize
corpus['text_tokenized'] = corpus.apply(lambda row: nltk.word_tokenize(row['text']), axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
corpus.head()
# Out:
#           username  ...                                     text_tokenized
# 0           pqrzan  ...  [after, cross-state, allowed, no, roadblocks, ...
# 1     mcreativepky  ...  [keep, covid, vaccination, at, tangkeliling, p...
# 2        veemarisa  ...  [control, the, movement, of, those, who, refus...
# 3          GSaraw4  ...  [vaccination, to, save, yourself, and, the, va...
# 4  Papalov03973158  ...  [important, vaccination, is, done, to, increas...
#
# [5 rows x 6 columns]

# %%
corpus.isnull().sum()
# Out:
# username          0
# tweet             0
# clean_tweet       0
# en_tweet          0
# text              0
# text_tokenized    0
# dtype: int64

# %% [markdown]
# > **POS-TAGGING**

# %%
# import nltk

# def tokenization(text):
#   sentence = nltk.sent_tokenize(text)
#   for sent in sentence:
#     pos_tagging = nltk.pos_tag(nltk.word_tokenize(sent))
#     print(pos_tagging)
 
# looping = corpus['text']
# for text in looping:
#   tokenization(text)

# %%
#create function for pos-tagging
import nltk

def tokenization(text):
  sentence = nltk.sent_tokenize(text)
  for sent in sentence:
    pos_tagging = nltk.pos_tag(nltk.word_tokenize(sent))
  return pos_tagging

array_baru = []
looping = corpus['text']
for text in looping:
  array_baru.append(tokenization(text))
# print(array_baru)

#apply function for pos-tagging
corpus['text_tagging']  = array_baru
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
corpus.head()
# Out:
#           username  ...                                       text_tagging
# 0           pqrzan  ...  [(after, IN), (cross-state, NN), (allowed, VBD...
# 1     mcreativepky  ...  [(keep, VB), (covid, NN), (vaccination, NN), (...
# 2        veemarisa  ...  [(control, VB), (the, DT), (movement, NN), (of...
# 3          GSaraw4  ...  [(vaccination, NN), (to, TO), (save, VB), (you...
# 4  Papalov03973158  ...  [(important, JJ), (vaccination, NN), (is, VBZ)...
#
# [5 rows x 7 columns]

# %% [markdown]
# > **STOPWORD**

# %%
import nltk
stopwords = nltk.corpus.stopwords.words('english')
stopwords[0:10]
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're"]

# %%
#create function removing stopword
def remove_stopwords(txt_tokenized):
  txt_clean = [word for word in txt_tokenized if word not in stopwords]
  return txt_clean

#apply function for removing stopword
corpus['text_stopword'] = corpus['text_tokenized'].apply(lambda x: remove_stopwords(x))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
corpus.head()
# Out:
#           username  ...                                      text_stopword
# 0           pqrzan  ...  [cross-state, allowed, roadblocks, check, pers...
# 1     mcreativepky  ...  [keep, covid, vaccination, tangkeliling, puske...
# 2        veemarisa  ...  [control, movement, refuse, receive, vaccinati...
# 3          GSaraw4  ...  [vaccination, save, vaccine, family, proved, s...
# 4  Papalov03973158  ...  [important, vaccination, done, increase, body,...
#
# [5 rows x 8 columns]

# %% [markdown]
# > **STEMMING**
# - Post Stemmer

# %%
import nltk 
from nltk.stem import PorterStemmer
ps = PorterStemmer()
dir(ps) # use stem function bellow
# Out:
# ['MARTIN_EXTENSIONS',
#  'NLTK_EXTENSIONS',
#  'ORIGINAL_ALGORITHM',
#  '__abstractmethods__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_abc_impl',
#  '_apply_rule_list',
#  '_contains_vowel',
#  '_ends_cvc',
#  '_ends_double_consonant',
#  '_has_positive_measure',
#  '_is_consonant',
#  '_measure',
#  '_replace_suffix',
#  '_step1a',
#  '_step1b',
#  '_step1c',
#  '_step2',
#  '_step3',
#  '_step4',
#  '_step5a',
#  '_step5b',
#  'mode',
#  'pool',
#  'stem',
#  'unicode_repr',
#  'vowels']

# %%
#exaxmple steaming function
print(ps.stem('coder'))
print(ps.stem('codeing'))
print(ps.stem('code'))
# Out:
# coder
# code
# code

# %%
#create function for stemming
def stemming(tokenized_text):
  text = [ps.stem(word) for word in tokenized_text]
  return text

#apply function for removing stopword
corpus['text_stemmed'] = corpus['text_stopword'].apply(lambda x: stemming(x))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
corpus.head()
# Out:
#           username  ...                                       text_stemmed
# 0           pqrzan  ...  [cross-stat, allow, roadblock, check, person, ...
# 1     mcreativepky  ...  [keep, covid, vaccin, tangkelil, puskesk, buil...
# 2        veemarisa  ...  [control, movement, refus, receiv, vaccin, inj...
# 3          GSaraw4  ...        [vaccin, save, vaccin, famili, prove, safe]
# 4  Papalov03973158  ...  [import, vaccin, done, increas, bodi, 's, immu...
#
# [5 rows x 9 columns]

# %% [markdown]
# > **LEMMATIZATION**
# - WordNet Lemmatizer

# %%
import nltk
wn = nltk.WordNetLemmatizer()
ps = nltk.PorterStemmer()
dir(wn)

# use  'lemmatize',
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  'lemmatize',
#  'unicode_repr']

# %%
#create function lemmatization
def lemmatization(token_txt):
  text = [wn.lemmatize(word) for word in token_txt]
  return text

#apply function to dataframe
corpus['text_lemmatized'] = corpus['text_stemmed'].apply(lambda x : lemmatization(x))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
corpus
# Out:
#              username  ...                                    text_lemmatized
# 0              pqrzan  ...  [cross-stat, allow, roadblock, check, person, ...
# 1        mcreativepky  ...  [keep, covid, vaccin, tangkelil, puskesk, buil...
# 2           veemarisa  ...  [control, movement, refus, receiv, vaccin, inj...
# 3             GSaraw4  ...        [vaccin, save, vaccin, famili, prove, safe]
# 4     Papalov03973158  ...  [import, vaccin, done, increas, bodi, 's, immu...
# ...               ...  ...                                                ...
# 1410       KontanNews  ...     [covid, vaccin, octob, increas, million, dose]
# 1411  SuaraBojonegoro  ...  [educ, vaccin, resid, bhabinkamtibma, babinsa,...
# 1412       sssatpolll  ...  [success, ppkm, vaccin, disciplin, proke, prev...
# 1413          KangOys  ...  [santri, alert, soul, soul, also, becam, guide...
# 1414      AnggaHertoh  ...  [peopl, vaccin, full, age, higher, risk, covid...
#
# [1414 rows x 10 columns]

# %%
#Export
#corpus.to_excel('/content/drive/MyDrive/SKRIPSI_TEXT_MINING/corpus_lemmatization_2.1.xlsx',index=False)

# %% [markdown]
# ## Labeling dengan TextBlob

# %%
import pandas as pd 
import numpy as np
import csv
import re
from datetime import datetime

# menghitung sentimen kata-kata yang berbahasa inggris
from textblob import TextBlob

# %%
corpus_2 = pd.read_excel('/content/drive/MyDrive/SKRIPSI_TEXT_MINING/corpus_lemmatization_2.1.xlsx')
corpus_2.head()
# Out:
#           username  ...                                    text_lemmatized
# 0           pqrzan  ...  ['cross-stat', 'allow', 'roadblock', 'check', ...
# 1     mcreativepky  ...  ['keep', 'covid', 'vaccin', 'tangkelil', 'pusk...
# 2        veemarisa  ...  ['control', 'movement', 'refus', 'receiv', 'va...
# 3          GSaraw4  ...  ['vaccin', 'save', 'vaccin', 'famili', 'prove'...
# 4  Papalov03973158  ...  ['import', 'vaccin', 'done', 'increas', 'bodi'...
#
# [5 rows x 10 columns]

# %%
#determine the polarity value from dataset
sample_reviews = corpus_2

def detect_polarity(text_lemmatized):
    return TextBlob(text_lemmatized).sentiment.polarity

sample_reviews['polarity'] = sample_reviews.text_lemmatized.apply(detect_polarity)
sample_reviews.head()
# Out:
#           username  ... polarity
# 0           pqrzan  ...      0.0
# 1     mcreativepky  ...      0.0
# 2        veemarisa  ...      0.0
# 3          GSaraw4  ...      0.5
# 4  Papalov03973158  ...      0.0
#
# [5 rows x 11 columns]

# %% [markdown]
# - Seperti yang bisa dilihat pada source code diatas, attribute **text_lemmatized** yang akan dipilih untuk menentukan polarity.
# - Statement row dari attribute **text_lemmatized** akan menerima nilai index untuk statment polarity secara otomatis.
# - Nila polarity akan membantu dalam proses penentuan kelas label.

# %%
#Membuat functionnya untuk memetakan label sentiment dari nilai polarity
def convert_label_category(row):
  if row['polarity'] > 0:
    return 'positif'
  elif row['polarity'] == 0:
    return 'netral'
  else:
    return 'negatif'

#Apply the function into dataframe
sample_reviews['label'] = sample_reviews.apply(convert_label_category,axis=1)

# %%
sample_reviews
# Out:
#              username  ...    label
# 0              pqrzan  ...   netral
# 1        mcreativepky  ...   netral
# 2           veemarisa  ...   netral
# 3             GSaraw4  ...  positif
# 4     Papalov03973158  ...   netral
# ...               ...  ...      ...
# 1409       KontanNews  ...   netral
# 1410  SuaraBojonegoro  ...   netral
# 1411       sssatpolll  ...  positif
# 1412          KangOys  ...   netral
# 1413      AnggaHertoh  ...  positif
#
# [1414 rows x 12 columns]

# %%
#Hasil dari penentuan kelas label dengan TextBlob 
sample_reviews['label'].value_counts()
# Out:
# netral     946
# positif    343
# negatif    125
# Name: label, dtype: int64

# %%
sample_reviews[sample_reviews['label']=='negatif'].head(3)
# Out:
#            username  ...    label
# 12  heni_dalimunthe  ...  negatif
# 17          asri786  ...  negatif
# 25      Ammmmmmm777  ...  negatif
#
# [3 rows x 12 columns]

# %%
#Export analisis sentiment dan pnentuan kelas label menggunakan text blob
#sample_reviews.to_excel('/content/drive/MyDrive/SKRIPSI_TEXT_MINING/sample_reviews_2.1.xlsx',index=False)

# %% [markdown]
# ## WorldCloud

# %%
import pandas as pd
import numpy as np

from bs4 import BeautifulSoup

# import visualisasi untuk worldcloud
import seaborn as sns
import folium
from folium import plugins
from PIL import Image
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_excel('/content/drive/MyDrive/SKRIPSI_TEXT_MINING/sample_reviews_2.1.xlsx')
dfclean = df.copy()
dfclean.head(2)
# Out:
#        username  ...                         text_lemmatized_detokenize
# 0        pqrzan  ...  cross-stat allow roadblock check person either...
# 1  mcreativepky  ...  keep covid vaccin tangkelil puskesk build batu...
#
# [2 rows x 13 columns]

# %%
# !pip install treebank
# nltk.download('all')

# %%
# import treebank
# import nltk
# from nltk.tokenize.treebank import TreebankWordDetokenizer

# %%
# from nltk.tokenize.treebank import TreebankWordDetokenizer
# TreebankWordDetokenizer().detokenize(['the', 'quick', 'brown'])
# # 'The quick brown'

# %%
# cleansing
# dfclean['text_lemmatized_clean2'] = dfclean['text_lemmatized'].replace({'\'':''})

# %%
# # detokenize
# treebank = TreebankWordDetokenizer()

# dfclean['text_lemmatized_clean']= ''
# for i in dfclean.index:
#   dfclean['text_lemmatized_clean'][i]=treebank.detokenize(dfclean['text_stopword'][i])

# dfclean

# %%
dfclean.head()
# Out:
#           username  ...                         text_lemmatized_detokenize
# 0           pqrzan  ...  cross-stat allow roadblock check person either...
# 1     mcreativepky  ...  keep covid vaccin tangkelil puskesk build batu...
# 2        veemarisa  ...  control movement refus receiv vaccin inject co...
# 3          GSaraw4  ...               vaccin save vaccin famili prove safe
# 4  Papalov03973158  ...  import vaccin done increas bodi "s" immun avoi...
#
# [5 rows x 13 columns]

# %%
wc_negatif= dfclean[dfclean['label'] == 'negatif']
wc_negatif
# Out:
#              username  ...                         text_lemmatized_detokenize
# 12    heni_dalimunthe  ...  base circular hk concern covid vaccin menu pre...
# 17            asri786  ...  plea check risk statu mysejahtera hous exit in...
# 25        Ammmmmmm777  ...  dont think need explan especi follow long time...
# 27        Infodept_bn  ...      announc close stadium vaccin center open walk
# 70            fzfreak  ...  khalid "s" friend wrong vaccin said vaccin vir...
# ...               ...  ...                                                ...
# 1354         19as_don  ...  covid case gradual fell perform vaccin get hig...
# 1364       Fadhila948  ...  surpris vaccin expert other covid peopl believ...
# 1369      Selena_imut  ...  govern target least end year million dose vacc...
# 1370      Selena_imut  ...  vaccin suppress risk symptom sever ill even de...
# 1394     MinselPolres  ...  minsel region polic rank mobil vaccin market shop
#
# [125 rows x 13 columns]

# %%
comment_words = ''
stopwords = set(STOPWORDS)
 
# iterate through the csv file
for val in wc_negatif.text_lemmatized_detokenize:
     
    # typecaste each val to string
    val = str(val)
 
    # split the value
    tokens = val.split()
     
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
     
    comment_words += " ".join(tokens)+" "
 
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %%
rel_freq=wordcloud.words_
#rel_freq

list(rel_freq.items())[:]
# Out:
# [('vaccin', 1.0),
#  ('covid', 0.17796610169491525),
#  ('nt', 0.1016949152542373),
#  ('center', 0.0847457627118644),
#  ('dose', 0.07627118644067797),
#  ('long', 0.06779661016949153),
#  ('time', 0.06779661016949153),
#  ('need', 0.059322033898305086),
#  ('wrong', 0.059322033898305086),
#  ('rank', 0.059322033898305086),
#  ('mean', 0.059322033898305086),
#  ('case', 0.059322033898305086),
#  ('still', 0.05084745762711865),
#  ('use', 0.05084745762711865),
#  ('world', 0.05084745762711865),
#  ('take', 0.05084745762711865),
#  ('peopl', 0.05084745762711865),
#  ('must', 0.05084745762711865),
#  ('target', 0.05084745762711865),
#  ('hard', 0.05084745762711865),
#  ('year', 0.05084745762711865),
#  ('due', 0.05084745762711865),
#  ('sick', 0.05084745762711865),
#  ('ppv', 0.0423728813559322),
#  ('viru', 0.0423728813559322),
#  ('inform', 0.0423728813559322),
#  ('afraid', 0.0423728813559322),
#  ('usual', 0.0423728813559322),
#  ('program', 0.0423728813559322),
#  ('increas', 0.0423728813559322),
#  ('stupid', 0.0423728813559322),
#  ('want', 0.0423728813559322),
#  ('pcr', 0.0423728813559322),
#  ('govern', 0.0423728813559322),
#  ('base', 0.03389830508474576),
#  ('open', 0.03389830508474576),
#  ('slow', 0.03389830508474576),
#  ('spread', 0.03389830508474576),
#  ('presid', 0.03389830508474576),
#  ('relat', 0.03389830508474576),
#  ('report', 0.03389830508474576),
#  ('faint', 0.03389830508474576),
#  ('polic', 0.03389830508474576),
#  ('new', 0.03389830508474576),
#  ('teenag', 0.03389830508474576),
#  ('death', 0.03389830508474576),
#  ('one', 0.03389830508474576),
#  ('age', 0.03389830508474576),
#  ('pegel', 0.03389830508474576),
#  ('realli', 0.03389830508474576),
#  ('alreadi', 0.03389830508474576),
#  ('area', 0.03389830508474576),
#  ('pandem', 0.03389830508474576),
#  ('jokowi', 0.03389830508474576),
#  ('check', 0.025423728813559324),
#  ('mysejahtera', 0.025423728813559324),
#  ('said', 0.025423728813559324),
#  ('come', 0.025423728813559324),
#  ('vax', 0.025423728813559324),
#  ('amp', 0.025423728813559324),
#  ('make', 0.025423728813559324),
#  ('minist', 0.025423728813559324),
#  ('health', 0.025423728813559324),
#  ('indonesia', 0.025423728813559324),
#  ('next', 0.025423728813559324),
#  ('least', 0.025423728813559324),
#  ('difficult', 0.025423728813559324),
#  ('inject', 0.025423728813559324),
#  ('implement', 0.025423728813559324),
#  ('small', 0.025423728813559324),
#  ('support', 0.025423728813559324),
#  ('continu', 0.025423728813559324),
#  ('achiev', 0.025423728813559324),
#  ('fake', 0.025423728813559324),
#  ('yesterday', 0.025423728813559324),
#  ('public', 0.025423728813559324),
#  ('region', 0.025423728813559324),
#  ('last', 0.025423728813559324),
#  ('even', 0.025423728813559324),
#  ('famili', 0.025423728813559324),
#  ('mayb', 0.025423728813559324),
#  ('thing', 0.025423728813559324),
#  ('je', 0.025423728813559324),
#  ('possibl', 0.025423728813559324),
#  ('yok', 0.025423728813559324),
#  ('fever', 0.025423728813559324),
#  ('hand', 0.025423728813559324),
#  ('sleepi', 0.025423728813559324),
#  ('second', 0.025423728813559324),
#  ('dizzi', 0.025423728813559324),
#  ('test', 0.025423728813559324),
#  ('believ', 0.025423728813559324),
#  ('start', 0.025423728813559324),
#  ('symptom', 0.025423728813559324),
#  ('kovid', 0.025423728813559324),
#  ('manipul', 0.025423728813559324),
#  ('door', 0.025423728813559324),
#  ('careless', 0.025423728813559324),
#  ('perform', 0.025423728813559324),
#  ('travel travel', 0.025423728813559324),
#  ('plea', 0.01694915254237288),
#  ('risk', 0.01694915254237288),
#  ('especi', 0.01694915254237288),
#  ('follow', 0.01694915254237288),
#  ('instead', 0.01694915254237288),
#  ('solut', 0.01694915254237288),
#  ('ta', 0.01694915254237288),
#  ('announc', 0.01694915254237288),
#  ('close', 0.01694915254237288),
#  ('khalid', 0.01694915254237288),
#  ('claim', 0.01694915254237288),
#  ('counter', 0.01694915254237288),
#  ('trade', 0.01694915254237288),
#  ('kuala', 0.01694915254237288),
#  ('lumpur', 0.01694915254237288),
#  ('wtckl', 0.01694915254237288),
#  ('octob', 0.01694915254237288),
#  ('question', 0.01694915254237288),
#  ('parti', 0.01694915254237288),
#  ('israel', 0.01694915254237288),
#  ('green', 0.01694915254237288),
#  ('countri', 0.01694915254237288),
#  ('readi', 0.01694915254237288),
#  ('call', 0.01694915254237288),
#  ('mortal', 0.01694915254237288),
#  ('rate', 0.01694915254237288),
#  ('si', 0.01694915254237288),
#  ('pdg', 0.01694915254237288),
#  ('read', 0.01694915254237288),
#  ('student', 0.01694915254237288),
#  ('sman', 0.01694915254237288),
#  ('elderli', 0.01694915254237288),
#  ('everi', 0.01694915254237288),
#  ('father', 0.01694915254237288),
#  ('today', 0.01694915254237288),
#  ('work', 0.01694915254237288),
#  ('mask', 0.01694915254237288),
#  ('sleep', 0.01694915254237288),
#  ('board', 0.01694915254237288),
#  ('doubl', 0.01694915254237288),
#  ('fail', 0.01694915254237288),
#  ('ask', 0.01694915254237288),
#  ('school', 0.01694915254237288),
#  ('group', 0.01694915254237288),
#  ('seriou', 0.01694915254237288),
#  ('effect', 0.01694915254237288),
#  ('antivaksin', 0.01694915254237288),
#  ('go', 0.01694915254237288),
#  ('inde', 0.01694915254237288),
#  ('duh', 0.01694915254237288),
#  ('anti', 0.01694915254237288),
#  ('sourc', 0.01694915254237288),
#  ('dead', 0.01694915254237288),
#  ('eat', 0.01694915254237288),
#  ('huh', 0.01694915254237288),
#  ('let', 0.01694915254237288),
#  ('someon', 0.01694915254237288),
#  ('hear', 0.01694915254237288),
#  ('disciplin', 0.01694915254237288),
#  ('process', 0.01694915254237288),
#  ('day', 0.01694915254237288),
#  ('bodi', 0.01694915254237288),
#  ('weak', 0.01694915254237288),
#  ('hospit', 0.01694915254237288),
#  ('million', 0.01694915254237288),
#  ('morn', 0.01694915254237288),
#  ('shop', 0.01694915254237288),
#  ('antivax', 0.01694915254237288),
#  ('ni', 0.01694915254237288),
#  ('made', 0.01694915254237288),
#  ('ye', 0.01694915254237288),
#  ('cold', 0.01694915254237288),
#  ('hot', 0.01694915254237288),
#  ('bad', 0.01694915254237288),
#  ('tomorrow', 0.01694915254237288),
#  ('diseas', 0.01694915254237288),
#  ('monday', 0.01694915254237288),
#  ('normal', 0.01694915254237288),
#  ('problem', 0.01694915254237288),
#  ('wednesday', 0.01694915254237288),
#  ('directli', 0.01694915254237288),
#  ('home', 0.01694915254237288),
#  ('look', 0.01694915254237288),
#  ('info', 0.01694915254237288),
#  ('turn', 0.01694915254237288),
#  ('park', 0.01694915254237288),
#  ('place', 0.01694915254237288),
#  ('behind', 0.01694915254237288),
#  ('java', 0.01694915254237288),
#  ('oblig', 0.01694915254237288),
#  ('life', 0.01694915254237288),
#  ('keep', 0.01694915254237288),
#  ('network', 0.01694915254237288),
#  ('alway', 0.01694915254237288),
#  ('holiday', 0.01694915254237288),
#  ('lib', 0.01694915254237288),
#  ('sell', 0.01694915254237288),
#  ('certif', 0.01694915254237288),
#  ('kitul', 0.01694915254237288),
#  ('modern', 0.01694915254237288)]

# %%
wc_positif= dfclean[dfclean['label'] == 'positif']
wc_positif
# Out:
#              username  ...                         text_lemmatized_detokenize
# 3             GSaraw4  ...               vaccin save vaccin famili prove safe
# 6             GSaraw4  ...  enthusiasm commun particip vaccin covid still ...
# 8             GSaraw4  ...       vaccin creation herd immun vaccin prove safe
# 11    heni_dalimunthe  ...  let "s" immedi vaccin order reduc number covid...
# 21        KhanzaPtrri  ...  good disciplin applic covid patient care proto...
# ...               ...  ...                                                ...
# 1398    Walid60185809  ...  latest octob malaysia among fastest countri pr...
# 1406    RadioElshinta  ...  total million shake convers spread social medi...
# 1408         asasfuro  ...  physic torment meter live virus reli vaccin al...
# 1411       sssatpolll  ...  success ppkm vaccin disciplin proke prevent tr...
# 1413      AnggaHertoh  ...  peopl vaccin full age higher risk covid infect...
#
# [343 rows x 13 columns]

# %%
comment_words = ''
stopwords = set(STOPWORDS)
 
# iterate through the csv file
for val in wc_positif.text_lemmatized_detokenize:
     
    # typecaste each val to string
    val = str(val)
 
    # split the value
    tokens = val.split()
     
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
     
    comment_words += " ".join(tokens)+" "
 
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %%
rel_freq=wordcloud.words_
#rel_freq

list(rel_freq.items())[:]
# Out:
# [('vaccin', 1.0),
#  ('covid', 0.22590361445783133),
#  ('success', 0.07228915662650602),
#  ('first vaccin', 0.07228915662650602),
#  ('new', 0.06927710843373494),
#  ('safe', 0.060240963855421686),
#  ('indonesia', 0.0572289156626506),
#  ('countri', 0.05120481927710843),
#  ('first', 0.05120481927710843),
#  ('high', 0.04819277108433735),
#  ('good', 0.04819277108433735),
#  ('govern', 0.04819277108433735),
#  ('second', 0.04819277108433735),
#  ('continu', 0.045180722891566265),
#  ('jokowi', 0.045180722891566265),
#  ('social', 0.04216867469879518),
#  ('free', 0.0391566265060241),
#  ('peopl', 0.0391566265060241),
#  ('day', 0.0391566265060241),
#  ('program', 0.0391566265060241),
#  ('adult popul', 0.0391566265060241),
#  ('commun', 0.03614457831325301),
#  ('child', 0.03614457831325301),
#  ('dose', 0.03614457831325301),
#  ('nation', 0.03614457831325301),
#  ('nt', 0.03614457831325301),
#  ('complet', 0.03614457831325301),
#  ('polic', 0.03614457831325301),
#  ('full', 0.03614457831325301),
#  ('still', 0.03313253012048193),
#  ('inject', 0.03313253012048193),
#  ('case', 0.03313253012048193),
#  ('octob', 0.03313253012048193),
#  ('normal', 0.03313253012048193),
#  ('want', 0.03313253012048193),
#  ('far', 0.030120481927710843),
#  ('live', 0.030120481927710843),
#  ('import', 0.030120481927710843),
#  ('best', 0.030120481927710843),
#  ('fever', 0.030120481927710843),
#  ('receiv', 0.030120481927710843),
#  ('first dose', 0.030120481927710843),
#  ('high school', 0.030120481927710843),
#  ('health', 0.02710843373493976),
#  ('latest', 0.02710843373493976),
#  ('rate', 0.02710843373493976),
#  ('achiev', 0.02710843373493976),
#  ('world', 0.02710843373493976),
#  ('effect', 0.02710843373493976),
#  ('right', 0.02710843373493976),
#  ('disciplin', 0.024096385542168676),
#  ('acceler', 0.024096385542168676),
#  ('much', 0.024096385542168676),
#  ('effort', 0.024096385542168676),
#  ('malaysia', 0.024096385542168676),
#  ('carri', 0.024096385542168676),
#  ('amp', 0.024096385542168676),
#  ('target', 0.024096385542168676),
#  ('open', 0.024096385542168676),
#  ('better', 0.024096385542168676),
#  ('death', 0.024096385542168676),
#  ('ni', 0.024096385542168676),
#  ('pcr', 0.024096385542168676),
#  ('variant', 0.02108433734939759),
#  ('adult', 0.02108433734939759),
#  ('done', 0.02108433734939759),
#  ('year', 0.02108433734939759),
#  ('alreadi', 0.02108433734939759),
#  ('reach', 0.02108433734939759),
#  ('level', 0.02108433734939759),
#  ('state', 0.02108433734939759),
#  ('need', 0.02108433734939759),
#  ('pon', 0.02108433734939759),
#  ('work', 0.02108433734939759),
#  ('use', 0.02108433734939759),
#  ('herd immun', 0.02108433734939759),
#  ('covid pandem', 0.02108433734939759),
#  ('particip', 0.018072289156626505),
#  ('immun', 0.018072289156626505),
#  ('let', 0.018072289156626505),
#  ('immedi', 0.018072289156626505),
#  ('must', 0.018072289156626505),
#  ('parti', 0.018072289156626505),
#  ('protect', 0.018072289156626505),
#  ('thank', 0.018072289156626505),
#  ('implement', 0.018072289156626505),
#  ('total', 0.018072289156626505),
#  ('one', 0.018072289156626505),
#  ('public', 0.018072289156626505),
#  ('special', 0.018072289156626505),
#  ('halal', 0.018072289156626505),
#  ('fast', 0.018072289156626505),
#  ('read', 0.018072289156626505),
#  ('believ', 0.018072289156626505),
#  ('time', 0.018072289156626505),
#  ('requir', 0.018072289156626505),
#  ('test', 0.018072289156626505),
#  ('review', 0.018072289156626505),
#  ('activ', 0.018072289156626505),
#  ('go', 0.018072289156626505),
#  ('papua', 0.018072289156626505),
#  ('card', 0.018072289156626505),
#  ('form', 0.018072289156626505),
#  ('year old', 0.018072289156626505),
#  ('halal safe', 0.018072289156626505),
#  ('presid jokowi', 0.018072289156626505),
#  ('famili', 0.015060240963855422),
#  ('spread', 0.015060240963855422),
#  ('prevent', 0.015060240963855422),
#  ('restor', 0.015060240963855422),
#  ('almost', 0.015060240963855422),
#  ('cross', 0.015060240963855422),
#  ('pandem', 0.015060240963855422),
#  ('hospit', 0.015060240963855422),
#  ('citi', 0.015060240963855422),
#  ('area', 0.015060240963855422),
#  ('build', 0.015060240963855422),
#  ('awar', 0.015060240963855422),
#  ('west', 0.015060240963855422),
#  ('student', 0.015060240963855422),
#  ('includ', 0.015060240963855422),
#  ('ppv', 0.015060240963855422),
#  ('yesterday', 0.015060240963855422),
#  ('ye', 0.015060240963855422),
#  ('jakarta', 0.015060240963855422),
#  ('control', 0.015060240963855422),
#  ('week', 0.015060240963855422),
#  ('said', 0.015060240963855422),
#  ('develop', 0.015060240963855422),
#  ('allow', 0.015060240963855422),
#  ('coverag', 0.015060240963855422),
#  ('press', 0.015060240963855422),
#  ('pfizer', 0.015060240963855422),
#  ('today', 0.015060240963855422),
#  ('die', 0.015060240963855422),
#  ('answer', 0.015060240963855422),
#  ('million', 0.015060240963855422),
#  ('never', 0.015060240963855422),
#  ('enthusiasm commun', 0.015060240963855422),
#  ('health protocol', 0.015060240963855422),
#  ('disciplin proke', 0.015060240963855422),
#  ('success ppkm', 0.015060240963855422),
#  ('prevent transmiss', 0.015060240963855422),
#  ('best presid', 0.015060240963855422),
#  ('order', 0.012048192771084338),
#  ('number', 0.012048192771084338),
#  ('care', 0.012048192771084338),
#  ('take', 0.012048192771084338),
#  ('percentag', 0.012048192771084338),
#  ('infect', 0.012048192771084338),
#  ('report', 0.012048192771084338),
#  ('declar', 0.012048192771084338),
#  ('call', 0.012048192771084338),
#  ('follow', 0.012048192771084338),
#  ('say', 0.012048192771084338),
#  ('help', 0.012048192771084338),
#  ('emerg', 0.012048192771084338),
#  ('old', 0.012048192771084338),
#  ('held', 0.012048192771084338),
#  ('certif', 0.012048192771084338),
#  ('mysejahtera', 0.012048192771084338),
#  ('remain', 0.012048192771084338),
#  ('data', 0.012048192771084338),
#  ('forc', 0.012048192771084338),
#  ('indonesian', 0.012048192771084338),
#  ('minist', 0.012048192771084338),
#  ('especi', 0.012048192771084338),
#  ('support', 0.012048192771084338),
#  ('pregnant', 0.012048192771084338),
#  ('pnm', 0.012048192771084338),
#  ('low', 0.012048192771084338),
#  ('handl', 0.012048192771084338),
#  ('reject', 0.012048192771084338),
#  ('give', 0.012048192771084338),
#  ('love', 0.012048192771084338),
#  ('feel', 0.012048192771084338),
#  ('forget', 0.012048192771084338),
#  ('breakfast', 0.012048192771084338),
#  ('two', 0.012048192771084338),
#  ('pegel', 0.012048192771084338),
#  ('tr', 0.012048192771084338),
#  ('increas', 0.012048192771084338),
#  ('invit', 0.012048192771084338),
#  ('region', 0.012048192771084338),
#  ('proven safe', 0.012048192771084338),
#  ('make sure', 0.012048192771084338),
#  ('latest percentag', 0.012048192771084338),
#  ('protect famili', 0.012048192771084338),
#  ('school student', 0.012048192771084338),
#  ('good morn', 0.012048192771084338),
#  ('proke prevent', 0.012048192771084338),
#  ('prove', 0.009036144578313253),
#  ('make', 0.009036144578313253),
#  ('sure', 0.009036144578313253),
#  ('present', 0.009036144578313253),
#  ('statement', 0.009036144578313253),
#  ('legal', 0.009036144578313253),
#  ('governor', 0.009036144578313253),
#  ('elderli', 0.009036144578313253),
#  ('individu', 0.009036144578313253)]

# %%
wc_netral = dfclean[dfclean['label'] == 'netral']
wc_netral
# Out:
#              username  ...                         text_lemmatized_detokenize
# 0              pqrzan  ...  cross-stat allow roadblock check person either...
# 1        mcreativepky  ...  keep covid vaccin tangkelil puskesk build batu...
# 2           veemarisa  ...  control movement refus receiv vaccin inject co...
# 4     Papalov03973158  ...  import vaccin done increas bodi "s" immun avoi...
# 5           nazlieyta  ...  individu take vaccin still cross-countri need ...
# ...               ...  ...                                                ...
# 1405          Sek_Cly  ...  synergi vaccin precis vaccin servic polic band...
# 1407         haijoon_  ...                  "m" vaccin schedul next week come
# 1409       KontanNews  ...            covid vaccin octob increas million dose
# 1410  SuaraBojonegoro  ...      educ vaccin resid bhabinkamtibma babinsa nake
# 1412          KangOys  ...  santri alert soul soul also becam guidelin era...
#
# [946 rows x 13 columns]

# %%
comment_words = ''
stopwords = set(STOPWORDS)
 
# iterate through the csv file
for val in wc_netral.text_lemmatized_detokenize:
     
    # typecaste each val to string
    val = str(val)
 
    # split the value
    tokens = val.split()
     
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
     
    comment_words += " ".join(tokens)+" "
 
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %%
rel_freq=wordcloud.words_
#rel_freq

list(rel_freq.items())[:]
# Out:
# [('vaccin', 1.0),
#  ('covid', 0.15341701534170155),
#  ('covid vaccin', 0.1492329149232915),
#  ('peopl', 0.0794979079497908),
#  ('acceler', 0.07252440725244072),
#  ('govern', 0.06276150627615062),
#  ('vaccin vaccin', 0.05718270571827057),
#  ('activ', 0.05439330543933055),
#  ('want', 0.05160390516039052),
#  ('continu', 0.04602510460251046),
#  ('target', 0.04602510460251046),
#  ('villag', 0.04602510460251046),
#  ('still', 0.044630404463040445),
#  ('commun', 0.044630404463040445),
#  ('today', 0.044630404463040445),
#  ('case', 0.043235704323570434),
#  ('octob', 0.043235704323570434),
#  ('student', 0.04184100418410042),
#  ('day', 0.040446304044630406),
#  ('jokowi', 0.040446304044630406),
#  ('resid', 0.03905160390516039),
#  ('achiev', 0.03765690376569038),
#  ('support', 0.03765690376569038),
#  ('let', 0.03765690376569038),
#  ('pandem', 0.03626220362622036),
#  ('implement', 0.03486750348675035),
#  ('indonesia', 0.03486750348675035),
#  ('disciplin', 0.03486750348675035),
#  ('need', 0.03347280334728033),
#  ('nt', 0.03347280334728033),
#  ('herd immun', 0.03347280334728033),
#  ('complet', 0.03207810320781032),
#  ('polic', 0.03207810320781032),
#  ('carri', 0.03207810320781032),
#  ('health', 0.03207810320781032),
#  ('dose', 0.030683403068340307),
#  ('mani', 0.030683403068340307),
#  ('alreadi', 0.030683403068340307),
#  ('come', 0.030683403068340307),
#  ('take', 0.029288702928870293),
#  ('proke', 0.029288702928870293),
#  ('use', 0.029288702928870293),
#  ('hold', 0.02789400278940028),
#  ('prevent', 0.02789400278940028),
#  ('year', 0.02789400278940028),
#  ('must', 0.02789400278940028),
#  ('second', 0.02789400278940028),
#  ('effect', 0.02789400278940028),
#  ('vaccin program', 0.02789400278940028),
#  ('nation', 0.026499302649930265),
#  ('reach', 0.026499302649930265),
#  ('protect', 0.026499302649930265),
#  ('one', 0.026499302649930265),
#  ('child', 0.026499302649930265),
#  ('import', 0.02510460251046025),
#  ('health protocol', 0.02510460251046025),
#  ('heal nation', 0.02510460251046025),
#  ('requir', 0.023709902370990237),
#  ('make', 0.023709902370990237),
#  ('follow', 0.023709902370990237),
#  ('vaccin heal', 0.023709902370990237),
#  ('secur', 0.022315202231520222),
#  ('schedul', 0.022315202231520222),
#  ('test', 0.022315202231520222),
#  ('program', 0.022315202231520222),
#  ('indonesian', 0.022315202231520222),
#  ('elderli', 0.022315202231520222),
#  ('polic chief', 0.022315202231520222),
#  ('region polic', 0.022315202231520222),
#  ('keep', 0.02092050209205021),
#  ('region', 0.02092050209205021),
#  ('citi', 0.02092050209205021),
#  ('ni', 0.02092050209205021),
#  ('countri', 0.019525801952580194),
#  ('inform', 0.019525801952580194),
#  ('school', 0.019525801952580194),
#  ('amp', 0.019525801952580194),
#  ('immun', 0.01813110181311018),
#  ('collabor', 0.01813110181311018),
#  ('run', 0.01813110181311018),
#  ('monitor', 0.01813110181311018),
#  ('help', 0.01813110181311018),
#  ('dosag', 0.01813110181311018),
#  ('pcr', 0.01813110181311018),
#  ('wave', 0.01813110181311018),
#  ('receiv', 0.016736401673640166),
#  ('inject', 0.016736401673640166),
#  ('tni', 0.016736401673640166),
#  ('said', 0.016736401673640166),
#  ('percent', 0.016736401673640166),
#  ('effort', 0.016736401673640166),
#  ('time', 0.016736401673640166),
#  ('offic', 0.016736401673640166),
#  ('locat', 0.016736401673640166),
#  ('famili', 0.016736401673640166),
#  ('public', 0.016736401673640166),
#  ('morn', 0.016736401673640166),
#  ('check', 0.015341701534170154),
#  ('increas', 0.015341701534170154),
#  ('regenc', 0.015341701534170154),
#  ('world', 0.015341701534170154),
#  ('statu', 0.015341701534170154),
#  ('place', 0.015341701534170154),
#  ('condit', 0.015341701534170154),
#  ('provid', 0.015341701534170154),
#  ('total', 0.015341701534170154),
#  ('sake', 0.015341701534170154),
#  ('open', 0.015341701534170154),
#  ('start', 0.015341701534170154),
#  ('parent', 0.015341701534170154),
#  ('koramil', 0.015341701534170154),
#  ('ask', 0.01394700139470014),
#  ('appli', 0.01394700139470014),
#  ('perform', 0.01394700139470014),
#  ('particip', 0.01394700139470014),
#  ('level', 0.01394700139470014),
#  ('review', 0.01394700139470014),
#  ('papua', 0.01394700139470014),
#  ('applic', 0.01394700139470014),
#  ('know', 0.01394700139470014),
#  ('east java', 0.01394700139470014),
#  ('vaccin card', 0.01394700139470014),
#  ('precis', 0.012552301255230125),
#  ('updat', 0.012552301255230125),
#  ('group', 0.012552301255230125),
#  ('remind', 0.012552301255230125),
#  ('state', 0.012552301255230125),
#  ('kodim', 0.012552301255230125),
#  ('ppkm', 0.012552301255230125),
#  ('work', 0.012552301255230125),
#  ('ye', 0.012552301255230125),
#  ('societi', 0.012552301255230125),
#  ('bulk', 0.012552301255230125),
#  ('babinsa', 0.012552301255230125),
#  ('last', 0.012552301255230125),
#  ('friend', 0.012552301255230125),
#  ('hour', 0.012552301255230125),
#  ('die', 0.012552301255230125),
#  ('presid jokowi', 0.012552301255230125),
#  ('problem', 0.011157601115760111),
#  ('meet', 0.011157601115760111),
#  ('regent', 0.011157601115760111),
#  ('protocol', 0.011157601115760111),
#  ('hoax', 0.011157601115760111),
#  ('aceh', 0.011157601115760111),
#  ('parti', 0.011157601115760111),
#  ('especi', 0.011157601115760111),
#  ('hope', 0.011157601115760111),
#  ('go', 0.011157601115760111),
#  ('puskesma', 0.011157601115760111),
#  ('number', 0.011157601115760111),
#  ('district', 0.011157601115760111),
#  ('data', 0.011157601115760111),
#  ('give', 0.011157601115760111),
#  ('reason', 0.011157601115760111),
#  ('global', 0.011157601115760111),
#  ('yet', 0.011157601115760111),
#  ('remain', 0.011157601115760111),
#  ('proce', 0.011157601115760111),
#  ('yesterday', 0.011157601115760111),
#  ('viru', 0.011157601115760111),
#  ('obey', 0.011157601115760111),
#  ('nation polic', 0.011157601115760111),
#  ('review implement', 0.011157601115760111),
#  ('allow', 0.009762900976290097),
#  ('build', 0.009762900976290097),
#  ('individu', 0.009762900976290097),
#  ('jakarta', 0.009762900976290097),
#  ('process', 0.009762900976290097),
#  ('member', 0.009762900976290097),
#  ('commit', 0.009762900976290097),
#  ('governor', 0.009762900976290097),
#  ('citizen', 0.009762900976290097),
#  ('news', 0.009762900976290097),
#  ('leader', 0.009762900976290097),
#  ('element', 0.009762900976290097),
#  ('popul', 0.009762900976290097),
#  ('sinovac', 0.009762900976290097),
#  ('info', 0.009762900976290097),
#  ('dine', 0.009762900976290097),
#  ('bandung', 0.009762900976290097),
#  ('stop', 0.009762900976290097),
#  ('medic', 0.009762900976290097),
#  ('term', 0.009762900976290097),
#  ('wednesday', 0.009762900976290097),
#  ('well', 0.009762900976290097),
#  ('issu', 0.009762900976290097),
#  ('polici', 0.009762900976290097),
#  ('presid', 0.009762900976290097),
#  ('minist', 0.009762900976290097),
#  ('held', 0.009762900976290097),
#  ('order', 0.009762900976290097),
#  ('servic', 0.009762900976290097),
#  ('alway', 0.009762900976290097),
#  ('directli', 0.009762900976290097),
#  ('anti', 0.009762900976290097),
#  ('west', 0.009762900976290097),
#  ('join', 0.009762900976290097),
#  ('doctor', 0.009762900976290097),
#  ('encourag', 0.009762900976290097)]

# %% [markdown]
# ----------------------

# %% [markdown]
# ## #Code Lama - Status: **Tidak di pakai**
# > Untuk code lama prosesnya merujuk ke transalate -> kemudian dari translate dicari polaritynya | data preprocessingnya dilakukan terpisah.

# %% [markdown]
# ## Translate tweet ke bahasa inggris

# %% [markdown]
# > **install googletrans library**
# - https://youtu.be/8zfS23WSIuI
# - https://py-googletrans.readthedocs.io/en/latest/ [*googletrans*]

# %%
# !pip install googletrans
# !pip install google-trans-new
# !pip install google_trans_new
# Out:
# Requirement already satisfied: googletrans in /usr/local/lib/python3.7/dist-packages (3.1.0a0)
# Requirement already satisfied: httpx==0.13.3 in /usr/local/lib/python3.7/dist-packages (from googletrans) (0.13.3)
# Requirement already satisfied: chardet==3.* in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans) (3.0.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans) (1.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans) (2021.10.8)
# Requirement already satisfied: rfc3986<2,>=1.3 in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans) (1.5.0)
# Requirement already satisfied: httpcore==0.9.* in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans) (0.9.1)
# Requirement already satisfied: hstspreload in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans) (2021.11.1)
# Requirement already satisfied: idna==2.* in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans) (2.10)
# Requirement already satisfied: h2==3.* in /usr/local/lib/python3.7/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans) (3.2.0)
# Requirement already satisfied: h11<0.10,>=0.8 in /usr/local/lib/python3.7/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans) (0.9.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in /usr/local/lib/python3.7/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans) (3.0.0)
# Requirement already satisfied: google-trans-new in /usr/local/lib/python3.7/dist-packages (1.1.9)
# Requirement already satisfied: google_trans_new in /usr/local/lib/python3.7/dist-packages (1.1.9)

# %%
# !pip install googletrans==3.1.0a0
# Out:
# Requirement already satisfied: googletrans==3.1.0a0 in /usr/local/lib/python3.7/dist-packages (3.1.0a0)
# Requirement already satisfied: httpx==0.13.3 in /usr/local/lib/python3.7/dist-packages (from googletrans==3.1.0a0) (0.13.3)
# Requirement already satisfied: rfc3986<2,>=1.3 in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (1.5.0)
# Requirement already satisfied: chardet==3.* in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (3.0.4)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2021.10.8)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (1.2.0)
# Requirement already satisfied: idna==2.* in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2.10)
# Requirement already satisfied: httpcore==0.9.* in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (0.9.1)
# Requirement already satisfied: hstspreload in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2021.11.1)
# Requirement already satisfied: h11<0.10,>=0.8 in /usr/local/lib/python3.7/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (0.9.0)
# Requirement already satisfied: h2==3.* in /usr/local/lib/python3.7/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in /usr/local/lib/python3.7/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (3.0.0)

# %%
# Contoh eng to ind
from googletrans import Translator
translator = Translator()
translator.translate('This sentence is written in English', dest='id').text
# Out:
# 'Kalimat ini ditulis dalam bahasa Inggris'

# %%
# Contoh ind to eng
from googletrans import Translator
translator = Translator()
translator.translate('Kalimat ini ditulis dalam bahasa Inggris', dest='en').text
# Out:
# 'This sentence is written in English'

# %%
translated_data = df_new_list_tweet
translated_data.head() #1416 rows × 3 columns
# Out:
#           username  ...                                        clean_tweet
# 0           pqrzan  ...  RT Selepas rentas negeri dibenarkan tiada seka...
# 1     mcreativepky  ...  Jaga Vaksinasi Covid di Puskesmas Tangkiling K...
# 2        veemarisa  ...  RT mengawal pergerakan mereka yang enggan mene...
# 3          GSaraw4  ...  Vaksinasi untuk Menyelamatkan diri sendiri dan...
# 4  Papalov03973158  ...  Vaksinasi penting dilakukan untuk meningkatkan...
#
# [5 rows x 3 columns]

# %%
# from googletrans import Translator
# translator = Translator()

# #replace column's name, text value 'rt', and data type into string
# translated_data = translated_data.rename(columns={"clean_tweet": "Indonesian"})
# translated_data['Indonesian']=translated_data['Indonesian'].replace(regex={'rt': ''})

# #change data type
# translated_data['Indonesian'] = translated_data['Indonesian'].astype(str)

# %%
# #apply google trans function into dataframe 
# translated_data['English'] = translated_data['Indonesian'].apply(lambda x:translator.translate(x).text)

# #replace column's name
# translated_data = translated_data.rename(columns={"Indonesian":"clean_tweet","English": "en_tweet"})

# %%
# translated_data
# Out:
#              username  ...                                           en_tweet
# 0              pqrzan  ...  After cross-state allowed no roadblocks to che...
# 1        mcreativepky  ...  Keep Covid Vaccination at Tangkeliling Puskesk...
# 2           veemarisa  ...  Control the movement of those who refuse to re...
# 3             GSaraw4  ...  vaccination to save yourself and the vaccine f...
# 4     Papalov03973158  ...  Important vaccination is done to increase the ...
# ...               ...  ...                                                ...
# 1409       KontanNews  ...  Covid Vaccination per October Beach Million Doses
# 1410  SuaraBojonegoro  ...  education vaccination to residents by Bhabinka...
# 1411       sssatpolll  ...  The success of PPKM Vaccination and Discipline...
# 1412          KangOys  ...  Santri Alert Soul Soul also became a guideline...
# 1413      AnggaHertoh  ...  People who are vaccinated in full aged have a ...
#
# [1414 rows x 4 columns]

# %% [markdown]
# > **setelah itu**

# %%
# #Membuat functionnya untuk memetakan label sentiment dari nilai polarity
# def convert_label_category(row):
#   if row['polarity'] > 0:
#     return 'positif'
#   elif row['polarity'] == 0:
#     return 'netral'
#   else:
#     return 'negatif'

# #Apply the function into dataframe
# sample_reviews['label'] = sample_reviews.apply(convert_label_category,axis=1)

# %%
# sample_reviews #1414 rows × 6 columns
# Out:
#              username  ...    label
# 0              pqrzan  ...  positif
# 1        mcreativepky  ...   netral
# 2           veemarisa  ...   netral
# 3             GSaraw4  ...  positif
# 4     Papalov03973158  ...  positif
# ...               ...  ...      ...
# 1409       KontanNews  ...   netral
# 1410  SuaraBojonegoro  ...   netral
# 1411       sssatpolll  ...  positif
# 1412          KangOys  ...   netral
# 1413      AnggaHertoh  ...  positif
#
# [1414 rows x 6 columns]

# %%
# #Hasil dari penentuan kelas label dengan TextBlob 
# sample_reviews['label'].value_counts()
# Out:
# netral     766
# positif    476
# negatif    172
# Name: label, dtype: int64

# %%
# #determine the polarity value from dataset
# sample_reviews = translated_data

# def detect_polarity(en_tweet):
#     return TextBlob(en_tweet).sentiment.polarity

# sample_reviews['polarity'] = sample_reviews.en_tweet.apply(detect_polarity)
# sample_reviews.head() #1414 rows × 5 columns
# Out:
#           username  ... polarity
# 0           pqrzan  ...      0.1
# 1     mcreativepky  ...      0.0
# 2        veemarisa  ...      0.0
# 3          GSaraw4  ...      0.5
# 4  Papalov03973158  ...      0.4
#
# [5 rows x 5 columns]
