# %%
# !pip install Sastrawi
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk) (1.15.0)

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: numpy>=1.14.6 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.19.5)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.1.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.4.1)

# %%
# !pip install pydotplus
# Out:
# Requirement already satisfied: pydotplus in /usr/local/lib/python3.7/dist-packages (2.0.2)
# Requirement already satisfied: pyparsing>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from pydotplus) (3.0.7)

# %%
#mount process for access google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Import Library
import pandas as pd
import numpy as np
import string
import os
import re
from datetime import datetime

# Import matplotlib library for visualize the data
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import NLTK library - word_tokenize library for tokenization process using nltk
# for process of pos-tagging, lemmatization and cleaning the stopwords  
import nltk
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize 
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
from nltk.stem import LancasterStemmer
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')

# Import Sklearn Library
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import accuracy_score, confusion_matrix, recall_score, f1_score, precision_score, plot_confusion_matrix
from sklearn.metrics import precision_recall_fscore_support as score

from sklearn import model_selection, svm 
from sklearn import svm #for svm algorithm
from sklearn.svm import SVC

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
import sklearn.tree as tree

# ------------------------------------------------------------------------------------------------------------------------------------
# Additional library for data pre-processing process
import spacy
import csv

from sklearn.feature_extraction.text import CountVectorizer
from sklearn import model_selection, naive_bayes 
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

import pydotplus
#from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
#from Sastrawi.Stemmer.StemmerFactory import StemmerFactory #import Indonesian Stemmer
from scipy.spatial import distance
from six import StringIO
from IPython.display import Image
porter_stemmer = PorterStemmer()

#for stopwords removal
from spacy.lang.en import English

#load English tokenizer, tagger, parser, NER and word vectors
nlp = English()
from spacy.lang.en.stop_words import STOP_WORDS
sp = spacy.load('en_core_web_sm')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %% [markdown]
# ---------------------------

# %% [markdown]
# # **SVM Classifier Algorithm (Support vector machine Algorithm)**
# > **data training 70% dan data testing 30% dengan menjadikan test_size=0.3**

# %% [markdown]
# ## **Hold-Out Method**

# %%
corpus = pd.read_excel('/content/drive/MyDrive/SKRIPSI_TEXT_MINING/sample_reviews_2.1.xlsx')

# %%
corpus.head()
# Out:
#           username  ...    label
# 0           pqrzan  ...   netral
# 1     mcreativepky  ...   netral
# 2        veemarisa  ...   netral
# 3          GSaraw4  ...  positif
# 4  Papalov03973158  ...   netral
#
# [5 rows x 12 columns]

# %% [markdown]
# > **Text Classification dan Kalkulasi Akurasi**
# - data training 70% dan data testing 30% dengan menjadikan test_size=0.3

# %%
#rename colume text_lemmatized into text_final
corpus = corpus.rename(columns={'text_lemmatized':'text_final'})

#HOLD-OUT - Dividing testing and training data
#Train_X,Test_X,Train_Y,Test_Y = model_selection.train_test_split(df_new['text_final'],df_new['label'],test_size=0.3)
#Train_X,Test_X,Train_Y,Test_Y = model_selection.train_test_split(df_new['text_final'],df_new['label'],test_size=0.33, random_state=66)
Train_X,Test_X,Train_Y,Test_Y = train_test_split(corpus['text_final'],corpus['label'],test_size=0.3)

# Label encode - transform Categorical data of string (negatif, netral, positif) into numerical values (0,1,2)
Encoder = LabelEncoder()
Train_Y = Encoder.fit_transform(Train_Y)
Test_Y = Encoder.fit_transform(Test_Y)

# %%
#TF-IDF Vectorizer 
Tfidf_vect = TfidfVectorizer(max_features=5000)
Tfidf_vect.fit(corpus['text_final'])

Train_X_Tfidf = Tfidf_vect.transform(Train_X)
Test_X_Tfidf = Tfidf_vect.transform(Test_X)

#CHECKING
print(Tfidf_vect.vocabulary_)
print(Train_X_Tfidf)
# Out:
# {'cross': 628, 'stat': 2702, 'allow': 89, 'roadblock': 2415, 'check': 473, 'person': 2096, 'either': 834, 'complet': 549, 'vaccin': 3041, 'keep': 1438, 'covid': 612, 'tangkelil': 2842, 'puskesk': 2282, 'build': 396, 'batu': 274, 'polic': 2158, 'chief': 476, 'personnel': 2097, 'pam': 1999, 'control': 581, 'movement': 1806, 'refus': 2347, 'receiv': 2331, 'inject': 1297, 'freedom': 1029, 'save': 2471, 'famili': 951, 'prove': 2252, 'safe': 2447, 'import': 1259, 'done': 766, 'increas': 1272, 'bodi': 354, 'immun': 1254, 'avoid
 'walk': 3110, 'framework': 1026, 'month': 1789, 'bakti': 241, 'parti': 2026, 'iba': 1234, 'channel': 468, 'much': 1816, 'dose': 775, 'elector': 838, 'district': 748, 'support': 2782, 'learn': 1548, 'face': 938, 'kean': 1435, 'kuskan': 1510, 'hulu': 1222, 'tanah': 2840, 'season': 2494, 'form': 1011, 'proke': 2236, 'effort': 831, 'prevent': 2209, 'corona': 596, 'viru': 3082, 'mu': 1813, 'variant': 3059, 'goodby': 1087, 'nusantara': 1914, 'red': 2341, 'white': 3148, 'news': 1871, 'plan': 2137, 'factori': 942, 'protect': 2246, 'wow': 3188, 'realli': 2328, 'chaotic': 469, 'thank': 2887, 'indonesia': 1281, 'quickli': 2298, 'updat': 3022, 'coverag': 609, 'post': 2177, 'airport': 71, 'tjilik': 2923, 'riwut': 2411, 'polresta': 2162, 'palangka': 1996, 'raya': 2319, 'hel ...
#   (0, 3230)	0.38070802073257193
#   (0, 3041)	0.06254632936463649
#   (0, 2447)	0.25821232053396304
#   (0, 2016)	0.2853878384564045
#   (0, 1387)	0.22694253627988054
#   (0, 1318)	0.38070802073257193
#   (0, 1216)	0.38070802073257193
#   (0, 1135)	0.28842862072624104
#   (0, 622)	0.38070802073257193
#   (0, 286)	0.36540356270980867
#   (1, 2143)	0.6460884624951565
#   (1, 1327)	0.7632625358489992
#   (2, 2596)	0.3681189229559984
#   (2, 2075)	0.4121776548649886
#   (2, 1837)	0.3533205465180026
#   (2, 1751)	0.3533205465180026
#   (2, 1569)	0.34184203399229635
#   (2, 1029)	0.34184203399229635
#   (2, 858)	0.3889760631007427
#   (2, 93)	0.24477110151082082
#   (3, 3041)	0.09113658404321652
#   (3, 2352)	0.35590487499678186
#   (3, 1725)	0.5861620255625531
#   (3, 1350)	0.4472704888205368
#   (3, 1258)	0.3483362491205009
#   :	:
#   (986, 3041)	0.0909908913489017
#   (986, 2340)	0.5852249756861967
#   (986, 630)	0.5538448459250236
#   (986, 410)	0.5852249756861967
#   (987, 3041)	0.06533247121884081
#   (987, 2257)	0.4201980364601271
#   (987, 1927)	0.24843196453957117
#   (987, 1647)	0.3120657970434758
#   (987, 1534)	0.3120657970434758
#   (987, 957)	0.3976667545474779
#   (987, 612)	0.14084363463914884
#   (987, 605)	0.26789235584393767
#   (987, 110)	0.3692806963956972
#   (987, 43)	0.4201980364601271
#   (988, 3041)	0.06340783539055475
#   (988, 2851)	0.2423532522825557
#   (988, 2169)	0.27380347819329504
#   (988, 2082)	0.31118626869685145
#   (988, 2078)	0.4078193803208598
#   (988, 1628)	0.3402554099040088
#   (988, 1534)	0.3028726194004524
#   (988, 1036)	0.3859518497039643
#   (988, 710)	0.32101922878536365
#   (988, 44)	0.28100508878355696
#   (988, 23)	0.2462536477782508

# %% [markdown]
# ## **SVM Classifier Algorithm (Support vector machine Algorithm)**
# > **Hyperparameter Tuning**

# %%
# from sklearn.model_selection import GridSearchCV

# # defining parameter range
# parameters = {'C': [0.5, 1, 10, 100, 1000],
#               'gamma': ['scale', 1, 0.1, 0.01, 0.001, 0.0001],
#               'kernel': ['rbf','poly','sigmoid']}

# grid = GridSearchCV(estimator=SVC(random_state=0), 
#                     param_grid=parameters, 
#                     n_jobs=6, 
#                     verbose=1,
#                     scoring='accuracy')

# # fitting the model for grid search
# grid.fit(Train_X_Tfidf, Train_Y)

# %%
from sklearn.model_selection import GridSearchCV

# defining parameter range
param_grid = {'C': [0.1, 1, 10, 100, 1000],
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
              'kernel': ['rbf']}

grid = GridSearchCV(SVC(), param_grid, refit = True, verbose=3)

# fitting the model for grid search
grid.fit(Train_X_Tfidf, Train_Y)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.672 total time=   0.1s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.670 total time=   0.1s
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.672 total time=   0.1s
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.670 total time=   0.1s
# [CV 1/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 2/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 3/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 4/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.672 total time=   0.1s
# [CV 5/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.670 total time=   0.1s
# [CV 1/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 2/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 3/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 4/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.672 total time=   0.1s
# [CV 5/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.670 total time=   0.1s
# [CV 1/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 2/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 3/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 4/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.672 total time=   0.1s
# [CV 5/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.670 total time=   0.1s
# [CV 1/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.707 total time=   0.1s
# [CV 2/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.707 total time=   0.1s
# [CV 3/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.722 total time=   0.1s
# [CV 4/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.727 total time=   0.1s
# [CV 5/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.721 total time=   0.1s
# [CV 1/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 2/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 3/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 4/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.672 total time=   0.1s
# [CV 5/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.670 total time=   0.1s
# [CV 1/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 2/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 3/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 4/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.672 total time=   0.1s
# [CV 5/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.670 total time=   0.1s
# [CV 1/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 2/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 3/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 4/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.672 total time=   0.1s
# [CV 5/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.670 total time=   0.1s
# [CV 1/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 2/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 3/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 4/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.672 total time=   0.1s
# [CV 5/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.670 total time=   0.1s
# [CV 1/5] END .........C=10, gamma=1, kernel=rbf;, score=0.737 total time=   0.1s
# [CV 2/5] END .........C=10, gamma=1, kernel=rbf;, score=0.742 total time=   0.1s
# [CV 3/5] END .........C=10, gamma=1, kernel=rbf;, score=0.763 total time=   0.1s
# [CV 4/5] END .........C=10, gamma=1, kernel=rbf;, score=0.773 total time=   0.1s
# [CV 5/5] END .........C=10, gamma=1, kernel=rbf;, score=0.761 total time=   0.1s
# [CV 1/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.813 total time=   0.1s
# [CV 2/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.813 total time=   0.1s
# [CV 3/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.828 total time=   0.1s
# [CV 4/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.828 total time=   0.1s
# [CV 5/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.817 total time=   0.1s
# [CV 1/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.672 total time=   0.1s
# [CV 2/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 3/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 4/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.672 total time=   0.1s
# [CV 5/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.670 total time=   0.1s
# [CV 1/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 2/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 3/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 4/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.672 total time=   0.1s
# [CV 5/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.670 total time=   0.1s
# [CV 1/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 2/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 3/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 4/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.672 total time=   0.1s
# [CV 5/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.670 total time=   0.1s
# [CV 1/5] END ........C=100, gamma=1, kernel=rbf;, score=0.737 total time=   0.1s
# [CV 2/5] END ........C=100, gamma=1, kernel=rbf;, score=0.742 total time=   0.1s
# [CV 3/5] END ........C=100, gamma=1, kernel=rbf;, score=0.768 total time=   0.1s
# [CV 4/5] END ........C=100, gamma=1, kernel=rbf;, score=0.773 total time=   0.1s
# [CV 5/5] END ........C=100, gamma=1, kernel=rbf;, score=0.761 total time=   0.1s
# [CV 1/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.808 total time=   0.1s
# [CV 2/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.813 total time=   0.1s
# [CV 3/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.838 total time=   0.1s
# [CV 4/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.833 total time=   0.1s
# [CV 5/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.822 total time=   0.1s
# [CV 1/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.818 total time=   0.1s
# [CV 2/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.808 total time=   0.1s
# [CV 3/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.833 total time=   0.1s
# [CV 4/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.828 total time=   0.1s
# [CV 5/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.817 total time=   0.1s
# [CV 1/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.672 total time=   0.1s
# [CV 2/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 3/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 4/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.672 total time=   0.1s
# [CV 5/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.670 total time=   0.1s
# [CV 1/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 2/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 3/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 4/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.672 total time=   0.1s
# [CV 5/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.670 total time=   0.1s
# [CV 1/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.737 total time=   0.1s
# [CV 2/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.742 total time=   0.1s
# [CV 3/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.768 total time=   0.1s
# [CV 4/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.773 total time=   0.1s
# [CV 5/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.761 total time=   0.1s
# [CV 1/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.808 total time=   0.1s
# [CV 2/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.813 total time=   0.1s
# [CV 3/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.838 total time=   0.1s
# [CV 4/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.838 total time=   0.1s
# [CV 5/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.822 total time=   0.1s
# [CV 1/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.823 total time=   0.1s
# [CV 2/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.803 total time=   0.1s
# [CV 3/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.838 total time=   0.1s
# [CV 4/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.843 total time=   0.1s
# [CV 5/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.822 total time=   0.1s
# [CV 1/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.818 total time=   0.1s
# [CV 2/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.813 total time=   0.1s
# [CV 3/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.833 total time=   0.1s
# [CV 4/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.828 total time=   0.1s
# [CV 5/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.817 total time=   0.1s
# [CV 1/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.672 total time=   0.1s
# [CV 2/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 3/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.667 total time=   0.1s
# [CV 4/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.672 total time=   0.1s
# [CV 5/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.670 total time=   0.1s
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['rbf']},
#              verbose=3)

# %%
# #look best score from grid
# print(f'Best Score: {grid.best_score_}')

# #print how our model looks after hyper-parameter tunning - 02
# best_params = grid.best_estimator_.get_params()
# print(f'Best Parameters:')
# for param in parameters:
#   print(f'\t{param}: {best_params[param]}')
# -------------------------------------------------------------------------

# print best parameter after tuning
print(grid.best_params_)

# print how our model looks after hyper-parameter tunning
print(grid.best_estimator_)
# Out:
# {'C': 1000, 'gamma': 0.01, 'kernel': 'rbf'}
# SVC(C=1000, gamma=0.01)

# %%
# re-run prediction model 
grid_predictions = grid.predict(Test_X_Tfidf)

#print classification report
print(classification_report(Test_Y, grid_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.40      0.53        30
#            1       0.86      0.98      0.91       285
#            2       0.93      0.72      0.81       110
#
#     accuracy                           0.87       425
#    macro avg       0.86      0.70      0.75       425
# weighted avg       0.87      0.87      0.86       425

# %%
from sklearn.metrics import mean_squared_error, mean_squared_log_error, mean_absolute_error

print("Check MAE, RMSE, MSE from the model")
print("MAE:"+str(mean_absolute_error(Test_Y, grid_predictions)))
print("RMSE:"+str(np.sqrt(mean_squared_error(Test_Y, grid_predictions))))
print("MSE:"+str(mean_squared_error(Test_Y, grid_predictions)))
# print("MSLE:"+str(mean_squared_log_error(Test_Y, grid_predictions)))
# print("RMSLE:"+str(np.sqrt(mean_squared_log_error(Test_Y, grid_predictions)))
# Out:
# Check MAE, RMSE, MSE from the model
# MAE:0.13647058823529412
# RMSE:0.3819454842528924
# MSE:0.14588235294117646

# %% [markdown]
# > **Classifier - SVM Algorithm**

# %%
# fit the training dataset on the classifier
SVM = svm.SVC(C=1000, kernel='rbf', gamma=0.01)
SVM.fit(Train_X_Tfidf,Train_Y)

# predict the labels on validation dataset
predictions_SVM = SVM.predict(Test_X_Tfidf)

# %% [markdown]
# > **Visualize Classifier - SVM Algorithm**

# %%
# visualize classifier SVM algorithm toward the data
conf_matrix = confusion_matrix(Test_Y, predictions_SVM)
class_label = ["NEGATIF", "NETRAL", "POSITIF"]
test = pd.DataFrame(conf_matrix, index = class_label, columns = class_label)
sns.heatmap(test, annot = True, fmt = "d")
plt.title("Confusion Matrix SVM")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
# SVM RESULT
print("SVM RESULT")
print("Accuracy Score =",accuracy_score(predictions_SVM, Test_Y))
precision, recall, fscore, support = score(Test_Y, predictions_SVM, average='weighted')
print("Precision =", precision)
print("Recall =", recall)
print("F-score =", fscore)
# Out:
# SVM RESULT
# Accuracy Score = 0.8682352941176471
# Precision = 0.870635081181794
# Recall = 0.8682352941176471
# F-score = 0.8585851692505502

# %%
# Test model prediction to new sentence
texts = ["Vaccinations haven't gone well", 
         "good government",
         "Vaccination is going well",
         "The space shuttle is made in 2018", 
         "negative",
         "the windows are transparent."]

text_features = Tfidf_vect.transform(texts)
predictions = SVM.predict(text_features)
for text, predicted in zip(texts, predictions):
   print('"{}"'.format(text))
   print("  - Predicted as: '{}'".format(predicted))
   print("")
# Out:
# "Vaccinations haven't gone well"
#   - Predicted as: '1'
#
# "good government"
#   - Predicted as: '2'
#
# "Vaccination is going well"
#   - Predicted as: '1'
#
# "The space shuttle is made in 2018"
#   - Predicted as: '1'
#
# "negative"
#   - Predicted as: '1'
#
# "the windows are transparent."
#   - Predicted as: '1'

# %% [markdown]
# # **Random-forest-Classifier Algorithm**
# > **data training 70% dan data testing 30% dengan menjadikan test_size=0.3**

# %% [markdown]
# ## **Random-forest-Classifier Algorithm**
# > **Hyperparameter Tuning**

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier

# %%
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 50, stop = 300, num = 5)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 110, num = 5)]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Method of selecting samples for training each tree
bootstrap = [True, False]

# %%
# Create the param grid
param_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}
print(param_grid)
# Out:
# {'n_estimators': [50, 112, 175, 237, 300], 'max_features': ['auto', 'sqrt'], 'max_depth': [10, 35, 60, 85, 110, None], 'min_samples_split': [2, 5, 10], 'min_samples_leaf': [1, 2, 4], 'bootstrap': [True, False]}

# %%
rf_Model = RandomForestClassifier()

# %%
from sklearn.model_selection import GridSearchCV
rf_Grid = GridSearchCV(estimator = rf_Model, param_grid = param_grid, cv = 3, verbose=2, n_jobs = 4)

# %%
rf_Grid.fit(Train_X_Tfidf, Train_Y)
# Out:
# Fitting 3 folds for each of 1080 candidates, totalling 3240 fits
# GridSearchCV(cv=3, estimator=RandomForestClassifier(), n_jobs=4,
#              param_grid={'bootstrap': [True, False],
#                          'max_depth': [10, 35, 60, 85, 110, None],
#                          'max_features': ['auto', 'sqrt'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [50, 112, 175, 237, 300]},
#              verbose=2)

# %%
# print how our model looks after hyper-parameter tunning
rf_Grid.best_params_
# Out:
# {'bootstrap': False,
#  'max_depth': None,
#  'max_features': 'auto',
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 300}

# %%
#check accuracy
print (f'Train Accuracy - : {rf_Grid.score(Train_X_Tfidf,Train_Y):.3f}')
print (f'Test Accuracy - : {rf_Grid.score(Test_X_Tfidf,Test_Y):.3f}')
# Out:
# Train Accuracy - : 1.000
# Test Accuracy - : 0.918

# %% [markdown]
# > **Classifier - Random-forest Algorithm**

# %%
# from sklearn.model_selection import train_test_split
# from sklearn import model_selection

# fit the training dataset on the classifier
rf_clf = RandomForestClassifier(n_estimators=300, max_depth=None, max_features='sqrt', bootstrap=False, min_samples_leaf=1, min_samples_split=2)
rf_clf.fit(Train_X_Tfidf, Train_Y)

# predict the labels on validation dataset
predictions_RFC = rf_clf.predict(Test_X_Tfidf )

# %%
from sklearn.metrics import mean_squared_error, mean_squared_log_error, mean_absolute_error

print("MAE:"+str(mean_absolute_error(Test_Y, predictions_RFC)))
print("RMSE:"+str(np.sqrt(mean_squared_error(Test_Y, predictions_RFC))))
print("MSE:"+str(mean_squared_error(Test_Y, predictions_RFC)))
# print("MSLE:"+str(mean_squared_log_error(Test_Y, predictions_RFC)))
# print("RMSLE:"+str(np.sqrt(mean_squared_log_error(Test_Y, predictions_RFC)))
# Out:
# MAE:0.08705882352941176
# RMSE:0.32539568672798425
# MSE:0.10588235294117647

# %% [markdown]
# > **Visualize Classifier - Random-forest Algorithm**

# %%
# visualize classifier Random-forest algorithm toward the data
conf_matrix = confusion_matrix(Test_Y, predictions_RFC)
class_label = ["NEGATIF", "NETRAL", "POSITIF"]
test = pd.DataFrame(conf_matrix, index = class_label, columns = class_label)
sns.heatmap(test, annot = True, fmt = "d")
plt.title("Confusion Matrix Random-Forest")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
# RANDOM FOREST RESULT
print("RANDOM FOREST RESULT")
print("Accuracy Score =",accuracy_score(predictions_RFC, Test_Y))
precision, recall, fscore, support = score(Test_Y, predictions_RFC, average='weighted')
print("Precision =", precision)
print("Recall =", recall)
print("F-score =", fscore)
# Out:
# RANDOM FOREST RESULT
# Accuracy Score = 0.9223529411764706
# Precision = 0.9228645161290323
# Recall = 0.9223529411764706
# F-score = 0.9178504146756741

# %%
# Test model prediction to new sentence
texts = ["Vaccinations haven't gone well", 
         "good government",
         "Vaccination is going well",
         "The space shuttle is made in 2018", 
         "negative",
         "the windows are transparent."]

text_features = Tfidf_vect.transform(texts)
predictions = rf_clf.predict(text_features)
for text, predicted in zip(texts, predictions):
   print('"{}"'.format(text))
   print("  - Predicted as: '{}'".format(predicted))
   print("")
# Out:
# "Vaccinations haven't gone well"
#   - Predicted as: '1'
#
# "good government"
#   - Predicted as: '2'
#
# "Vaccination is going well"
#   - Predicted as: '1'
#
# "The space shuttle is made in 2018"
#   - Predicted as: '1'
#
# "negative"
#   - Predicted as: '1'
#
# "the windows are transparent."
#   - Predicted as: '1'

# %% [markdown]
# <br>

# %% [markdown]
# --------------------------

# %% [markdown]
# # **SVM Classifier Algorithm (Support vector machine Algorithm)**
# > **data training 80% dan data testing 20% dengan menjadikan test_size=0.2**

# %% [markdown]
# ## **Hold-Out Method**

# %%
corpus = pd.read_excel('/content/drive/MyDrive/SKRIPSI_TEXT_MINING/sample_reviews_2.1.xlsx')

# %%
corpus.head()
# Out:
#           username  ...    label
# 0           pqrzan  ...   netral
# 1     mcreativepky  ...   netral
# 2        veemarisa  ...   netral
# 3          GSaraw4  ...  positif
# 4  Papalov03973158  ...   netral
#
# [5 rows x 12 columns]

# %% [markdown]
# > **Text Classification dan Kalkulasi Akurasi**
# - data training 80% dan data testing 20% dengan menjadikan test_size=0.2

# %%
#rename colume text_lemmatized into text_final
corpus = corpus.rename(columns={'text_lemmatized':'text_final'})

#HOLD-OUT - Dividing testing and training data
#Train_X,Test_X,Train_Y,Test_Y = model_selection.train_test_split(df_new['text_final'],df_new['label'],test_size=0.2)
#Train_X,Test_X,Train_Y,Test_Y = model_selection.train_test_split(df_new['text_final'],df_new['label'],test_size=0.20, random_state=66)
Train_X,Test_X,Train_Y,Test_Y = train_test_split(corpus['text_final'],corpus['label'],test_size=0.2)

# Label encode - transform Categorical data of string (negatif, netral, positif) into numerical values (0,1,2)
Encoder = LabelEncoder()
Train_Y = Encoder.fit_transform(Train_Y)
Test_Y = Encoder.fit_transform(Test_Y)

# %%

# [CV 1/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.749 total time=   0.2s
# [CV 2/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.779 total time=   0.2s
# [CV 3/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.792 total time=   0.2s
# [CV 4/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.761 total time=   0.2s
# [CV 5/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.739 total time=   0.2s
# [CV 1/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.824 total time=   0.2s
# [CV 2/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.836 total time=   0.2s
# [CV 3/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.845 total time=   0.2s
# [CV 4/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.836 total time=   0.2s
# [CV 5/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.805 total time=   0.2s
# [CV 1/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.815 total time=   0.2s
# [CV 2/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.832 total time=   0.2s
# [CV 3/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.854 total time=   0.2s
# [CV 4/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.827 total time=   0.2s
# [CV 5/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.801 total time=   0.2s
# [CV 1/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.819 total time=   0.2s
# [CV 2/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.827 total time=   0.2s
# [CV 3/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.863 total time=   0.2s
# [CV 4/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.814 total time=   0.2s
# [CV 5/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.810 total time=   0.2s
# [CV 1/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.678 total time=   0.2s
# [CV 2/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.686 total time=   0.2s
# [CV 3/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.681 total time=   0.2s
# [CV 4/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.677 total time=   0.2s
# [CV 5/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.681 total time=   0.2s
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['rbf']},
#              verbose=3)

# %%
# print best parameter after tuning
print(grid.best_params_)

# print how our model looks after hyper-parameter tunning
print(grid.best_estimator_)
# Out:
# {'C': 100, 'gamma': 0.1, 'kernel': 'rbf'}
# SVC(C=100, gamma=0.1)

# %%
# re-run prediction model 
grid_predictions = grid.predict(Test_X_Tfidf)

#print classification report
print(classification_report(Test_Y, grid_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.47      0.64        19
#            1       0.85      0.99      0.91       179
#            2       0.97      0.75      0.85        85
#
#     accuracy                           0.88       283
#    macro avg       0.94      0.74      0.80       283
# weighted avg       0.90      0.88      0.88       283

# %%
from sklearn.metrics import mean_squared_error, mean_squared_log_error, mean_absolute_error

print("Check MAE, RMSE, MSE from the model")
print("MAE:"+str(mean_absolute_error(Test_Y, grid_predictions)))
print("RMSE:"+str(np.sqrt(mean_squared_error(Test_Y, grid_predictions))))
print("MSE:"+str(mean_squared_error(Test_Y, grid_predictions)))
# print("MSLE:"+str(mean_squared_log_error(Test_Y, grid_predictions)))
# print("RMSLE:"+str(np.sqrt(mean_squared_log_error(Test_Y, grid_predictions)))
# Out:
# Check MAE, RMSE, MSE from the model
# MAE:0.1166077738515901
# RMSE:0.3414788043958074
# MSE:0.1166077738515901

# %% [markdown]
# > **Classifier - SVM Algorithm**

# %%
# fit the training dataset on the classifier
SVM = svm.SVC(C=1000, kernel='rbf', gamma=0.01)
SVM.fit(Train_X_Tfidf,Train_Y)

# predict the labels on validation dataset
predictions_SVM = SVM.predict(Test_X_Tfidf)

# %% [markdown]
# > **Visualize Classifier - SVM Algorithm**

# %%
# visualize classifier SVM algorithm toward the data
conf_matrix = confusion_matrix(Test_Y, predictions_SVM)
class_label = ["NEGATIF", "NETRAL", "POSITIF"]
test = pd.DataFrame(conf_matrix, index = class_label, columns = class_label)
sns.heatmap(test, annot = True, fmt = "d")
plt.title("Confusion Matrix SVM")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
# SVM RESULT
print("SVM RESULT")
print("Accuracy Score =",accuracy_score(predictions_SVM, Test_Y))
precision, recall, fscore, support = score(Test_Y, predictions_SVM, average='weighted')
print("Precision =", precision)
print("Recall =", recall)
print("F-score =", fscore)
# Out:
# SVM RESULT
# Accuracy Score = 0.8798586572438163
# Precision = 0.8877246243310872
# Recall = 0.8798586572438163
# F-score = 0.87289467729272

# %%
# Test model prediction to new sentence
texts = ["Vaccinations haven't gone well", 
         "good government",
         "Vaccination is going well",
         "The space shuttle is made in 2018", 
         "negative",
         "the windows are transparent."]

text_features = Tfidf_vect.transform(texts)
predictions = SVM.predict(text_features)
for text, predicted in zip(texts, predictions):
   print('"{}"'.format(text))
   print("  - Predicted as: '{}'".format(predicted))
   print("")
# Out:
# "Vaccinations haven't gone well"
#   - Predicted as: '1'
#
# "good government"
#   - Predicted as: '2'
#
# "Vaccination is going well"
#   - Predicted as: '1'
#
# "The space shuttle is made in 2018"
#   - Predicted as: '1'
#
# "negative"
#   - Predicted as: '1'
#
# "the windows are transparent."
#   - Predicted as: '1'

# %% [markdown]
# # **Random-forest-Classifier Algorithm**
# > **data training 80% dan data testing 20% dengan menjadikan test_size=0.2**

# %% [markdown]
# ## **Random-forest-Classifier Algorithm**
# > **Hyperparameter Tuning**

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier

# %%
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 50, stop = 300, num = 5)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 110, num = 5)]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Method of selecting samples for training each tree
bootstrap = [True, False]

# %%
# Create the param grid
param_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}
print(param_grid)
# Out:
# {'n_estimators': [50, 112, 175, 237, 300], 'max_features': ['auto', 'sqrt'], 'max_depth': [10, 35, 60, 85, 110, None], 'min_samples_split': [2, 5, 10], 'min_samples_leaf': [1, 2, 4], 'bootstrap': [True, False]}

# %%
rf_Model = RandomForestClassifier()

# %%
from sklearn.model_selection import GridSearchCV
rf_Grid = GridSearchCV(estimator = rf_Model, param_grid = param_grid, cv = 3, verbose=2, n_jobs = 4)

# %%
rf_Grid.fit(Train_X_Tfidf, Train_Y)
# Out:
# Fitting 3 folds for each of 1080 candidates, totalling 3240 fits
# GridSearchCV(cv=3, estimator=RandomForestClassifier(), n_jobs=4,
#              param_grid={'bootstrap': [True, False],
#                          'max_depth': [10, 35, 60, 85, 110, None],
#                          'max_features': ['auto', 'sqrt'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [50, 112, 175, 237, 300]},
#              verbose=2)

# %%
# print how our model looks after hyper-parameter tunning
rf_Grid.best_params_
# Out:
# {'bootstrap': False,
#  'max_depth': None,
#  'max_features': 'auto',
#  'min_samples_leaf': 1,
#  'min_samples_split': 5,
#  'n_estimators': 175}

# %%
#check accuracy
print (f'Train Accuracy - : {rf_Grid.score(Train_X_Tfidf,Train_Y ):.3f}')
print (f'Test Accuracy - : {rf_Grid.score(Test_X_Tfidf,Test_Y):.3f}')
# Out:
# Train Accuracy - : 1.000
# Test Accuracy - : 0.933

# %% [markdown]
# > **Classifier - Random-forest Algorithm**

# %%
# from sklearn.model_selection import train_test_split
# from sklearn import model_selection

# fit the training dataset on the classifier
rf_clf = RandomForestClassifier(n_estimators=175, max_depth= 110, max_features='sqrt', bootstrap=False, min_samples_leaf=1, min_samples_split=2)
rf_clf.fit(Train_X_Tfidf, Train_Y)

# predict the labels on validation dataset
predictions_RFC = rf_clf.predict(Test_X_Tfidf )

# %%
from sklearn.metrics import mean_squared_error, mean_squared_log_error, mean_absolute_error

print("MAE:"+str(mean_absolute_error(Test_Y, predictions_RFC)))
print("RMSE:"+str(np.sqrt(mean_squared_error(Test_Y, predictions_RFC))))
print("MSE:"+str(mean_squared_error(Test_Y, predictions_RFC)))
# print("MSLE:"+str(mean_squared_log_error(Test_Y, predictions_RFC)))
# print("RMSLE:"+str(np.sqrt(mean_squared_log_error(Test_Y, predictions_RFC)))
# Out:
# MAE:0.07420494699646643
# RMSE:0.2724058497838591
# MSE:0.07420494699646643

# %% [markdown]
# > **Visualize Classifier - Random-forest Algorithm**

# %%
# visualize classifier Random-forest algorithm toward the data
conf_matrix = confusion_matrix(Test_Y, predictions_RFC)
class_label = ["NEGATIF", "NETRAL", "POSITIF"]
test = pd.DataFrame(conf_matrix, index = class_label, columns = class_label)
sns.heatmap(test, annot = True, fmt = "d")
plt.title("Confusion Matrix Random-Forest")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
# RANDOM FOREST RESULT
print("RANDOM FOREST RESULT")
print("Accuracy Score =",accuracy_score(predictions_RFC, Test_Y))
precision, recall, fscore, support = score(Test_Y, predictions_RFC, average='weighted')
print("Precision =", precision)
print("Recall =", recall)
print("F-score =", fscore)
# Out:
# RANDOM FOREST RESULT
# Accuracy Score = 0.9257950530035336
# Precision = 0.9305154013634578
# Recall = 0.9257950530035336
# F-score = 0.9224641430531562

# %%
# Test model prediction to new sentence
texts = ["Vaccinations haven't gone well", 
         "good government",
         "Vaccination is going well",
         "The space shuttle is made in 2018", 
         "negative",
         "the windows are transparent."]

text_features = Tfidf_vect.transform(texts)
predictions = rf_clf.predict(text_features)
for text, predicted in zip(texts, predictions):
   print('"{}"'.format(text))
   print("  - Predicted as: '{}'".format(predicted))
   print("")
# Out:
# "Vaccinations haven't gone well"
#   - Predicted as: '1'
#
# "good government"
#   - Predicted as: '2'
#
# "Vaccination is going well"
#   - Predicted as: '1'
#
# "The space shuttle is made in 2018"
#   - Predicted as: '1'
#
# "negative"
#   - Predicted as: '1'
#
# "the windows are transparent."
#   - Predicted as: '1'

# %% [markdown]
# <br>

# %% [markdown]
# -------------------------------------------------------------------

# %% [markdown]
# #@Additional Experiment
# With random-parameters in hypertunning process

# %% [markdown]
# ## **Hold-Out Method**

# %%
corpus = pd.read_excel('/content/drive/MyDrive/SKRIPSI_TEXT_MINING/sample_reviews_2.1.xlsx')

# %%
corpus.head()
# Out:
#           username  ...    label
# 0           pqrzan  ...   netral
# 1     mcreativepky  ...   netral
# 2        veemarisa  ...   netral
# 3          GSaraw4  ...  positif
# 4  Papalov03973158  ...   netral
#
# [5 rows x 12 columns]

# %% [markdown]
# > **Text Classification dan Kalkulasi Akurasi**
# - data training 70% dan data testing 30% dengan menjadikan test_size=0.3

# %%
#rename colume text_lemmatized into text_final
corpus = corpus.rename(columns={'text_lemmatized':'text_final'})

#HOLD-OUT - Dividing testing and training data
#Train_X,Test_X,Train_Y,Test_Y = model_selection.train_test_split(df_new['text_final'],df_new['label'],test_size=0.3)
#Train_X,Test_X,Train_Y,Test_Y = model_selection.train_test_split(df_new['text_final'],df_new['label'],test_size=0.33, random_state=66)
Train_X,Test_X,Train_Y,Test_Y = train_test_split(corpus['text_final'],corpus['label'],test_size=0.3)

# Label encode - transform Categorical data of string (negatif, netral, positif) into numerical values (0,1,2)
Encoder = LabelEncoder()
Train_Y = Encoder.fit_transform(Train_Y)
Test_Y = Encoder.fit_transform(Test_Y)

# %%
#TF-IDF Vectorizer 
Tfidf_vect = TfidfVectorizer(max_features=5000)
Tfidf_vect.fit(corpus['text_final'])

Train_X_Tfidf = Tfidf_vect.transform(Train_X)
Test_X_Tfidf = Tfidf_vect.transform(Test_X)

#CHECKING
print(Tfidf_vect.vocabulary_)
print(Train_X_Tfidf)
# Out:
# {'cross': 632, 'stat': 2740, 'allow': 92, 'roadblock': 2447, 'check': 478, 'person': 2128, 'either': 839, 'complet': 554, 'vaccin': 3083, 'keep': 1452, 'covid': 615, 'tangkelil': 2878, 'puskesk': 2314, 'build': 400, 'batu': 274, 'polic': 2190, 'chief': 481, 'personnel': 2129, 'pam': 2017, 'control': 584, 'movement': 1818, 'refus': 2379, 'receiv': 2363, 'inject': 1309, 'freedom': 1036, 'save': 2503, 'famili': 956, 'prove': 2284, 'safe': 2478, 'import': 1270, 'done': 770, 'increas': 1284, 'bodi': 356, 'immun': 1265, 'avoid': 211, 'spread': 2720, 'individu': 1292, 'take': 2863, 'still': 2750, 'countri': 609, 'need': 1874, 'acknowledg': 24, 'exist': 924, 'sop': 2694, 'sepei': 2572, 'enthusiasm': 879, 'commun': 549, 'particip': 2044, 'high': 1191, 'proven': 2285, 'commemor': 543, 'tni': 2964, 'anniversari': 126, 'east': 825, 'java': 1374, 'region': 2384, 'appreci': 162, 'simultan': 2626, 'creation': 625, 'herd': 1184, 'pandem': 2025, 'humanitarian': 1235, 'problem': 2257, 'across': 25, 'nation': 1861, 'alhamdulillah': 87, 'dki': 760, 'provinci': 2288, 'govern': 1100, 'jakaa': 1362, 'collabor': 531, 'deng': 703, 'lead': 1558, 'coordin': 594, 'meet': 1723, 'acceler': 13, 'aglomer': 61, 'regenc': 2381, 'citi': 506, 'let': 1575, 'immedi': 1264, 'order': 1977, 'reduc': 2375, 'number': 1923, 'must': 1839, 'compli': 555, 'health': 1169, 'protocol': 2281, 'make': 1653, 'sure': 2823, 'base': 269, 'circular': 502, 'hk': 1199, 'concern': 561, 'menu': 1742, 'prepar': 2234, 'agenc': 58, 'three': 2943, 'pillar': 2156, 'desa': 711, 'bungatang': 407, 'hold': 1206, 'deliber': 692, 'process': 2261, 'continu': 581, 'run': 2465, 'around': 174, 'world': 3222, 'regardless': 2380, 'whether': 3188, 'benefici': 298, 'resid': 2418, 
#   (1, 1661)	0.3120445173411353
#   (1, 1549)	0.3120445173411353
#   (1, 963)	0.3976612015339946
#   (1, 615)	0.1411565517092689
#   (1, 609)	0.2678629605552094
#   (1, 114)	0.3692699282687683
#   (1, 43)	0.4201966229150624
#   (2, 3203)	0.26885483691497747
#   (2, 3083)	0.08345835364291875
#   (2, 2964)	0.2022911391002389
#   (2, 2858)	0.4884112596734937
#   (2, 2384)	0.32288927039797466
#   (2, 2190)	0.5696883106697976
#   :	:
#   (985, 3083)	0.13501331262604968
#   (985, 2918)	0.27914477260387305
#   (985, 2555)	0.3628654996803922
#   (985, 2409)	0.37173358201171325
#   (985, 2326)	0.34840771692172123
#   (985, 1723)	0.34234646744574704
#   (985, 666)	0.25711174083864674
#   (985, 577)	0.37173358201171325
#   (985, 554)	0.2640513075558988
#   (986, 3083)	0.08362576056496535
#   (986, 3021)	0.4110980819939344
#   (986, 2926)	0.3905963499016752
#   (986, 1088)	0.40539381917812434
#   (986, 666)	0.3185043676006455
#   (986, 416)	0.4399936504537515
#   (986, 172)	0.4604953825460107
#   (987, 3083)	0.06259963835789363
#   (987, 2780)	0.2644745690988568
#   (987, 2210)	0.3663428151997598
#   (987, 1284)	0.5916623760354873
#   (987, 1265)	0.2295106202033686
#   (987, 879)	0.30346517988749633
#   (987, 615)	0.13548722371018768
#   (987, 581)	0.2316029251662231
#   (987, 549)	0.4744471721788003

# %% [markdown]
# ## **SVM Classifier Algorithm (Support vector machine Algorithm)** & **Random-forest-Classifier Algorithm**

# %% [markdown]
# > **Classifier - SVM Algorithm**

# %%
# fit the training dataset on the classifier
SVM = svm.SVC(C=1.0, kernel='linear', degree=3, gamma='auto')
SVM.fit(Train_X_Tfidf,Train_Y)

# predict the labels on validation dataset
predictions_SVM = SVM.predict(Test_X_Tfidf)

# %% [markdown]
# > **Visualize Classifier - SVM Algorithm**

# %%
# visualize classifier SVM algorithm toward the data
conf_matrix = confusion_matrix(Test_Y, predictions_SVM)
class_label = ["NEGATIF", "NETRAL", "POSITIF"]
test = pd.DataFrame(conf_matrix, index = class_label, columns = class_label)
sns.heatmap(test, annot = True, fmt = "d")
plt.title("Confusion Matrix SVM")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
# SVM RESULT
print("SVM RESULT")
print("Accuracy Score =",accuracy_score(predictions_SVM, Test_Y))
precision, recall, fscore, support = score(Test_Y, predictions_SVM, average='weighted')
print("Precision =", precision)
print("Recall =", recall)
print("F-score =", fscore)
# Out:
# SVM RESULT
# Accuracy Score = 0.8278301886792453
# Precision = 0.8312166476081572
# Recall = 0.8278301886792453
# F-score = 0.7988153163442848

# %% [markdown]
# > **Classifier - Random-forest Algorithm**

# %%
# from sklearn.model_selection import train_test_split
# from sklearn import model_selection

# fit the training dataset on the classifier
rf_clf = RandomForestClassifier(n_estimators=10, max_depth=10)
rf_clf.fit(Train_X_Tfidf, Train_Y)

# predict the labels on validation dataset
predictions_RFC = rf_clf.predict(Test_X_Tfidf )

# %% [markdown]
# > **Visualize Classifier - Random-forest Algorithm**

# %%
# visualize classifier Random-forest algorithm toward the data
conf_matrix = confusion_matrix(Test_Y, predictions_RFC)
class_label = ["NEGATIF", "NETRAL", "POSITIF"]
test = pd.DataFrame(conf_matrix, index = class_label, columns = class_label)
sns.heatmap(test, annot = True, fmt = "d")
plt.title("Confusion Matrix Random-Forest")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
# RANDOM FOREST RESULT
print("RANDOM FOREST RESULT")
print("Accuracy Score =",accuracy_score(predictions_RFC, Test_Y))
precision, recall, fscore, support = score(Test_Y, predictions_RFC, average='weighted')
print("Precision =", precision)
print("Recall =", recall)
print("F-score =", fscore)
# Out:
# RANDOM FOREST RESULT
# Accuracy Score = 0.7429245283018868
# Precision = 0.7149058916019237
# Recall = 0.7429245283018868
# F-score = 0.6598641616183182
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# <br>

# %% [markdown]
# ------------------------------------------------------------------------------------

# %% [markdown]
# > **Text Classification dan Kalkulasi Akurasi**
# - data training 80% dan data testing 20% dengan menjadikan test_size=0.2

# %% [markdown]
# ## **Hold-Out Method**

# %%
corpus = pd.read_excel('/content/drive/MyDrive/SKRIPSI_TEXT_MINING/sample_reviews_2.1.xlsx')

# %%
corpus.head()
# Out:
#           username  ...    label
# 0           pqrzan  ...   netral
# 1     mcreativepky  ...   netral
# 2        veemarisa  ...   netral
# 3          GSaraw4  ...  positif
# 4  Papalov03973158  ...   netral
#
# [5 rows x 12 columns]

# %% [markdown]
# > **Text Classification dan Kalkulasi Akurasi**
# - data training 80% dan data testing 20% dengan menjadikan test_size=0.2

# %%
#rename colume text_lemmatized into text_final
corpus = corpus.rename(columns={'text_lemmatized':'text_final'})

#HOLD-OUT - Dividing testing and training data
#Train_X,Test_X,Train_Y,Test_Y = model_selection.train_test_split(df_new['text_final'],df_new['label'],test_size=0.2)
#Train_X,Test_X,Train_Y,Test_Y = model_selection.train_test_split(df_new['text_final'],df_new['label'],test_size=0.20, random_state=66)
Train_X,Test_X,Train_Y,Test_Y = train_test_split(corpus['text_final'],corpus['label'],test_size=0.2)

# Label encode - transform Categorical data of string (negatif, netral, positif) into numerical values (0,1,2)
Encoder = LabelEncoder()
Train_Y = Encoder.fit_transform(Train_Y)
Test_Y = Encoder.fit_transform(Test_Y)

# %%
#TF-IDF Vectorizer 
Tfidf_vect = TfidfVectorizer(max_features=5000)
Tfidf_vect.fit(corpus['text_final'])

Train_X_Tfidf = Tfidf_vect.transform(Train_X)
Test_X_Tfidf = Tfidf_vect.transform(Test_X)

#CHECKING
print(Tfidf_vect.vocabulary_)
print(Train_X_Tfidf)
# Out:
# {'cross': 632, 'stat': 2740, 'allow': 92, 'roadblock': 2447, 'check': 478, 'person': 2128, 'either': 839, 'complet': 554, 'vaccin': 3083, 'keep': 1452, 'covid': 615, 'tangkelil': 2878, 'puskesk': 2314, 'build': 400, 'batu': 274, 'polic': 2190, 'chief': 481, 'personnel': 2129, 'pam': 2017, 'control': 584, 'movement': 1818, 'refus': 2379, 'receiv': 2363, 'inject': 1309, 'freedom': 1036, 'save': 2503, 'famili': 956, 'prove': 2284, 'safe': 2478, 'import': 1270, 'done': 770, 'increas': 1284, 'bodi': 356, 'immun': 1265, 'avoid': 211, 'spread': 2720, 'individu': 1292, 'take': 2863, 'still': 2750, 'countri': 609, 'need': 1874, 'acknowledg': 24, 'exist': 924, 'sop': 2694, 'sepei': 2572, 'enthusiasm': 879, 'commun': 549, 'particip': 2044, 'high': 1191, 'proven': 2285, 'commemor': 543, 'tni': 2964, 'anniversari': 126, 'east': 825, 'java': 1374, 'region': 2384, 'appreci': 162, 'simultan': 2626, 'creation': 625, 'herd': 1184, 'pandem': 2025, 'humanitarian': 1235, 'problem': 2257, 'across': 25, 'nation': 1861, 'alhamdulillah': 87, 'dki': 760, 'provinci': 2288, 'govern': 1100, 'jakaa': 1362, 'collabor': 531, 'deng': 703, 'lead': 1558, 'coordin': 594, 'meet': 1723, 'acceler': 13, 'aglomer': 61, 'regenc': 2381, 'citi': 506, 'let': 1575, 'immedi': 1264, 'order': 1977, 'reduc': 2375, 'number': 1923, 'must': 1839, 'compli': 555, 'health': 1169, 'protocol': 2281, 'make': 1653, 'sure': 2823, 'base': 269, 'circular': 502, 'hk': 1199, 'concern': 561, 'menu': 1742, 'prepar': 2234, 'agenc': 58, 'three': 2943, 'pillar': 2156, 'desa': 711, 'bungatang': 407, 'hold': 1206, 'deliber': 692, 'process': 2261, 'continu': 581, 'run': 2465, 'around': 174, 'world': 3222, 'regardless': 2380, 'whether': 3188, 'benefici': 298, 'resid': 2418, 'enthusiast': 880, 'member': 
#   (1, 2080)	0.6086672686572324
#   (1, 2007)	0.48392525884158677
#   (1, 1612)	0.4907345310333476
#   (1, 666)	0.38020389369970803
#   (2, 3222)	0.2816900066085734
#   (2, 3083)	0.06667443528809812
#   (2, 2813)	0.42957340142308925
#   (2, 2357)	0.3775102665728463
#   (2, 2354)	0.2838343912636975
#   (2, 1921)	0.42957340142308925
#   (2, 1611)	0.36715085610707116
#   (2, 1206)	0.2860628905890649
#   :	:
#   (1125, 163)	0.3269474482768424
#   (1126, 3083)	0.07576591762403947
#   (1126, 2888)	0.2900530515295295
#   (1126, 2655)	0.4433939282507649
#   (1126, 2113)	0.34278898368418637
#   (1126, 1975)	0.46196873742867983
#   (1126, 1940)	0.2885686840453945
#   (1126, 1514)	0.46196873742867983
#   (1126, 22)	0.2931282585243625
#   (1127, 3083)	0.05731892661370741
#   (1127, 2465)	0.2647619711419955
#   (1127, 2370)	0.30158127819074937
#   (1127, 2330)	0.3156336140895324
#   (1127, 2268)	0.23236220057814946
#   (1127, 2044)	0.2647619711419955
#   (1127, 1839)	0.23090398018166083
#   (1127, 1684)	0.34949160504986704
#   (1127, 1225)	0.32453943062450996
#   (1127, 828)	0.2906814396641753
#   (1127, 741)	0.22296545774350593
#   (1127, 286)	0.3156336140895324
#   (1127, 28)	0.21943282805866712
#   (1127, 22)	0.2217593037298714
#   (1128, 3083)	0.21374312809924123
#   (1128, 2511)	0.9768898992160536

# %% [markdown]
# ## **SVM Classifier Algorithm (Support vector machine Algorithm)** & **Random-forest-Classifier Algorithm**

# %% [markdown]
# > **Classifier - SVM Algorithm**

# %%
# fit the training dataset on the classifier
SVM = svm.SVC(C=1.0, kernel='linear', degree=3, gamma='auto')
SVM.fit(Train_X_Tfidf,Train_Y)

# predict the labels on validation dataset
predictions_SVM = SVM.predict(Test_X_Tfidf)

# %% [markdown]
# > **Visualize Classifier - SVM Algorithm**

# %%
# visualize classifier SVM algorithm toward the data
conf_matrix = confusion_matrix(Test_Y, predictions_SVM)
class_label = ["NEGATIF", "NETRAL", "POSITIF"]
test = pd.DataFrame(conf_matrix, index = class_label, columns = class_label)
sns.heatmap(test, annot = True, fmt = "d")
plt.title("Confusion Matrix SVM")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
# SVM RESULT
print("SVM RESULT")
print("Accuracy Score =",accuracy_score(predictions_SVM, Test_Y))
precision, recall, fscore, support = score(Test_Y, predictions_SVM, average='weighted')
print("Precision =", precision)
print("Recall =", recall)
print("F-score =", fscore)
# Out:
# SVM RESULT
# Accuracy Score = 0.7809187279151943
# Precision = 0.8266045601014083
# Recall = 0.7809187279151943
# F-score = 0.7451049649358821

# %% [markdown]
# > **Classifier - Random-forest Algorithm**

# %%
# from sklearn.model_selection import train_test_split
# from sklearn import model_selection

# fit the training dataset on the classifier
rf_clf = RandomForestClassifier(n_estimators=10, max_depth=10)
rf_clf.fit(Train_X_Tfidf, Train_Y)

# predict the labels on validation dataset
predictions_RFC = rf_clf.predict(Test_X_Tfidf )

# %% [markdown]
# > **Visualize Classifier - Random-forest Algorithm**

# %%
# visualize classifier Random-forest algorithm toward the data
conf_matrix = confusion_matrix(Test_Y, predictions_RFC)
class_label = ["NEGATIF", "NETRAL", "POSITIF"]
test = pd.DataFrame(conf_matrix, index = class_label, columns = class_label)
sns.heatmap(test, annot = True, fmt = "d")
plt.title("Confusion Matrix Random-Forest")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
# RANDOM FOREST RESULT
print("RANDOM FOREST RESULT")
print("Accuracy Score =",accuracy_score(predictions_RFC, Test_Y))
precision, recall, fscore, support = score(Test_Y, predictions_RFC, average='weighted')
print("Precision =", precision)
print("Recall =", recall)
print("F-score =", fscore)
# Out:
# RANDOM FOREST RESULT
# Accuracy Score = 0.657243816254417
# Precision = 0.6602308259399547
# Recall = 0.657243816254417
# F-score = 0.5373631790177207
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# #@Additional Experiment
# ###Repository Draft for Classifier - Random-forest Algorithm menggunakan uji 3 parameter
# - n-estimator=100 / n-estimator=10
# - max_depth=100 / max_depth=10
# - random_state=0
# <br><br>
# - Random forest terbentuk dari sejumlah decision tree nah berapa banyak kita tentuin decision yang kita tentuin u/ kasus 100 buah model decision 100. Makanya **n-estimator=100**
# - Nah agar model yang bisa kita duplicate dengan hasil yang konsisten kita perlu set **random_statenya**. Disana kita define 0.
# - **max_depth** adalah cara untuk menyempurnakan pohon keputusan. dalam kode di atas, angka 10 dipilih untuk tujuan preprune pohon keputusan kami (memastikan pohon keputusan yang di prepune/dipangkas tidak memiliki kedalaman lebih dari 10). Link: https://ichi.pro/id/memahami-pohon-keputusan-untuk-klasifikasi-python-165355544889682

# %% [markdown]
# > **Classifier - Random-forest Algorithm**

# %%
# from sklearn.model_selection import train_test_split
# from sklearn import model_selection

# fit the training dataset on the classifier
rf_clf = RandomForestClassifier(n_estimators=100, max_depth=100)
rf_clf.fit(Train_X_Tfidf, Train_Y)

# predict the labels on validation dataset
predictions_RFC = rf_clf.predict(Test_X_Tfidf )

# %% [markdown]
# > **Visualize Classifier - Random-forest Algorithm**

# %%
# visualize classifier Random-forest algorithm toward the data
conf_matrix = confusion_matrix(Test_Y, predictions_RFC)
class_label = ["NEGATIF", "NETRAL", "POSITIF"]
test = pd.DataFrame(conf_matrix, index = class_label, columns = class_label)
sns.heatmap(test, annot = True, fmt = "d")
plt.title("Confusion Matrix Random-Forest")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
# RANDOM FOREST
print("RANDOM FOREST RESULT")
print("Accuracy Score =",accuracy_score(predictions_RFC, Test_Y))
precision, recall, fscore, support = score(Test_Y, predictions_RFC, average='weighted')
print("Precision =", precision)
print("Recall =", recall)
print("F-score =", fscore)
# Out:
# RANDOM FOREST RESULT
# Accuracy Score = 0.8586572438162544
# Precision = 0.8654895404413554
# Recall = 0.8586572438162544
# F-score = 0.8324541520802815

# %% [markdown]
# > **Classifier - Random-forest Algorithm**

# %%
# from sklearn.model_selection import train_test_split
# from sklearn import model_selection

# fit the training dataset on the classifier
rf_clf = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=0)
rf_clf.fit(Train_X_Tfidf, Train_Y)

# predict the labels on validation dataset
predictions_RFC = rf_clf.predict(Test_X_Tfidf )

# %% [markdown]
# > **Visualize Classifier - Random-forest Algorithm**

# %%
# visualize classifier Random-forest algorithm toward the data
conf_matrix = confusion_matrix(Test_Y, predictions_RFC)
class_label = ["NEGATIF", "NETRAL", "POSITIF"]
test = pd.DataFrame(conf_matrix, index = class_label, columns = class_label)
sns.heatmap(test, annot = True, fmt = "d")
plt.title("Confusion Matrix Random-Forest")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
# RANDOM FOREST RESULT
print("RANDOM FOREST RESULT")
print("Accuracy Score =",accuracy_score(predictions_RFC, Test_Y))
precision, recall, fscore, support = score(Test_Y, predictions_RFC, average='weighted')
print("Precision =", precision)
print("Recall =", recall)
print("F-score =", fscore)
# Out:
# RANDOM FOREST RESULT
# Accuracy Score = 0.7243816254416962
# Precision = 0.5247287392775538
# Recall = 0.7243816254416962
# F-score = 0.6085993164571627
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# <br>

# %% [markdown]
# ------------------------------------------

# %% [markdown]
# #@Additional Experiment
# ### **Repository Draft for SVM and Random-forest-Classifier Algorithm**

# %%
# !pip install Sastrawi
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk) (1.15.0)

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (1.0.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.1.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (3.0.0)
# Requirement already satisfied: numpy>=1.14.6 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.19.5)

# %%
# !pip install pydotplus
# Out:
# Requirement already satisfied: pydotplus in /usr/local/lib/python3.7/dist-packages (2.0.2)
# Requirement already satisfied: pyparsing>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from pydotplus) (3.0.6)

# %%
#mount process for access google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Import Library
import pandas as pd
import numpy as np
import string
import os
import re
from datetime import datetime

# Import matplotlib library for visualize the data
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import NLTK library - word_tokenize library for tokenization process using nltk
# for process of pos-tagging, lemmatization and cleaning the stopwords  
import nltk
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize 
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
from nltk.stem import LancasterStemmer
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')

# Import Sklearn Library
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import accuracy_score, confusion_matrix, recall_score, f1_score, precision_score, plot_confusion_matrix
from sklearn.metrics import precision_recall_fscore_support as score

from sklearn import model_selection, svm 
from sklearn import svm #for svm algorithm
from sklearn.svm import SVC

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
import sklearn.tree as tree

# ------------------------------------------------------------------------------------------------------------------------------------
# Additional library for data pre-processing process
import spacy
import csv

from sklearn.feature_extraction.text import CountVectorizer
from sklearn import model_selection, naive_bayes 
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

import pydotplus
#from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
#from Sastrawi.Stemmer.StemmerFactory import StemmerFactory #import Indonesian Stemmer
from scipy.spatial import distance
from six import StringIO
from IPython.display import Image
porter_stemmer = PorterStemmer()

#for stopwords removal
from spacy.lang.en import English

#load English tokenizer, tagger, parser, NER and word vectors
nlp = English()
from spacy.lang.en.stop_words import STOP_WORDS
sp = spacy.load('en_core_web_sm')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %% [markdown]
# # **SVM Classifier Algorithm (Support vector machine Algorithm)**
# > **data training 70% dan data testing 30% dengan menjadikan test_size=0.3**

# %% [markdown]
# ## **Hold-Out Method**

# %%
corpus = pd.read_excel('/content/drive/MyDrive/SKRIPSI_TEXT_MINING/sample_reviews_2.1.xlsx')

# %%
corpus.head()
# Out:
#           username  ...    label
# 0           pqrzan  ...   netral
# 1     mcreativepky  ...   netral
# 2        veemarisa  ...   netral
# 3          GSaraw4  ...  positif
# 4  Papalov03973158  ...   netral
#
# [5 rows x 12 columns]

# %% [markdown]
# > **Text Classification dan Kalkulasi Akurasi**
# - data training 70% dan data testing 30% dengan menjadikan test_size=0.3

# %%
#rename colume text_lemmatized into text_final
corpus = corpus.rename(columns={'text_lemmatized':'text_final'})

#HOLD-OUT - Dividing testing and training data
Train_X,Test_X,Train_Y,Test_Y = train_test_split(corpus['text_final'],corpus['label'],test_size=0.3)

# Label encode - transform Categorical data of string (negatif, netral, positif) into numerical values (0,1,2)
Encoder = LabelEncoder()
Train_Y = Encoder.fit_transform(Train_Y)
Test_Y = Encoder.fit_transform(Test_Y)

# %%
#TF-IDF Vectorizer 
Tfidf_vect = TfidfVectorizer(max_features=5000)
Tfidf_vect.fit(corpus['text_final'])

Train_X_Tfidf = Tfidf_vect.transform(Train_X)
Test_X_Tfidf = Tfidf_vect.transform(Test_X)

#CHECKING
print(Tfidf_vect.vocabulary_)
print(Train_X_Tfidf)
# Out:
# {'cross': 628, 'stat': 2702, 'allow': 89, 'roadblock': 2415, 'check': 473, 'person': 2096, 'either': 834, 'complet': 549, 'vaccin': 3041, 'keep': 1438, 'covid': 612, 'tangkelil': 2842, 'puskesk': 2282, 'build': 396, 'batu': 274, 'polic': 2158, 'chief': 476, 'personnel': 2097, 'pam': 1999, 'control': 581, 'movement': 1806, 'refus': 2347, 'receiv': 2331, 'inject': 1297, 'freedom': 1029, 'save': 2471, 'famili': 951, 'prove': 2252, 'safe': 2447, 'import': 1259, 'done': 766, 'increas': 1272, 'bodi': 354, 'immun': 1254, 'avoid': 211, 'spread': 2682, 'individu': 1280, 'take': 2827, 'still': 2711, 'countri': 605, 'need': 1860, 'adher': 37, 'exist': 919, 'sop': 2653, 'like': 1571, 'enthusiasm': 874, 'commun': 544, 'particip': 2027, 'high': 1181, 'proven': 2253, 'commemor': 538, 'tni': 2925, 'anniversari': 122, 'east': 821, 'java': 1361, 'region': 2352, 'appreci': 158, 'simultan': 2587, 'creation': 621, 'herd': 1175, 'pandem': 2007, 'humanitarian': 1225, 'problem': 2225, 'across': 25, 'nation': 1847, 'alhamdulillah': 84, 'dki': 756, 'jakarta': 1350, 'provinci': 2256, 'govern': 1092, 'collabor': 526, 'deng': 699, 'lead': 1544, 'coordin': 591, 'meet': 1709, 'acceler': 14, 'aglomer': 61, 'regenc': 2349, 'citi': 501, 'let': 1561, 'immedi': 1253, 'order': 1963, 'reduc': 2343, 'number': 1910, 'must': 1825, 'compli': 550, 'health': 1160, 'protocol': 2249, 'make': 1639, 'sure': 2786, 'base': 269, 'circular': 497, 'hk': 1189, 'concern': 556, 'menu': 1728, 'prepar': 2202, 'agenc': 58, 'three': 2904, 'pillar': 2125, 'desa': 707, 'bungatang': 403, 'hold': 1196, 'deliber': 688, 'process': 2229, 'continu': 577, 'run': 2433, 'around': 170, 'world': 3181, 'regardless': 2348, 'whether': 3147, 'benefici': 295, 'resid': 2386, 'en
#   (0, 590)	0.2695495075397119
#   (0, 211)	0.2621542658645263
#   (1, 3118)	0.7955509369228255
#   (1, 3041)	0.14074742925078046
#   (1, 533)	0.589312199025704
#   (2, 2362)	0.3261503528044292
#   (2, 2311)	0.33249190666479206
#   (2, 2204)	0.25302765584060377
#   (2, 2050)	0.2711436502124515
#   (2, 1918)	0.33968136747006533
#   (2, 1793)	0.28883063053556834
#   (2, 1785)	0.3261503528044292
#   (2, 1203)	0.29864700150844037
#   :	:
#   (985, 2266)	0.3221584637139783
#   (985, 2204)	0.23425130401285468
#   (985, 1730)	0.34236912178247614
#   (985, 1630)	0.34236912178247614
#   (985, 1387)	0.4252729024590036
#   (985, 1294)	0.3769194699562166
#   (985, 1266)	0.3769194699562166
#   (985, 312)	0.27648538777497056
#   (986, 3224)	0.736067685649918
#   (986, 3041)	0.1209281900936494
#   (986, 2927)	0.4696423990246919
#   (986, 2499)	0.47224649498008964
#   (987, 2947)	0.4814031305573924
#   (987, 2827)	0.32430223869838076
#   (987, 2379)	0.4814031305573924
#   (987, 2177)	0.41542265377572674
#   (987, 892)	0.5086788067968189
#   (988, 3041)	0.1341653434984347
#   (988, 2781)	0.391905448365381
#   (988, 2169)	0.2896719110233311
#   (988, 1181)	0.2873427050261883
#   (988, 1117)	0.37917340761007395
#   (988, 609)	0.33962407669578465
#   (988, 605)	0.5501379218002359
#   (988, 312)	0.31648920118231344

# %% [markdown]
# ## **SVM Classifier Algorithm (Support vector machine Algorithm)**

# %%
# fit the training dataset on the classifier
#SVM = svm.SVC(C=1.0, kernel='rbf', degree=3, gamma='scale')
SVM = svm.SVC()
SVM.fit(Train_X_Tfidf,Train_Y)

# predict the labels on validation dataset
predictions_SVM = SVM.predict(Test_X_Tfidf)

# %%
# visualize classifier SVM algorithm toward the data
conf_matrix = confusion_matrix(Test_Y, predictions_SVM)
class_label = ["NEGATIF", "NETRAL", "POSITIF"]
test = pd.DataFrame(conf_matrix, index = class_label, columns = class_label)
sns.heatmap(test, annot = True, fmt = "d")
plt.title("Confusion Matrix SVM")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
# SVM RESULT
print("SVM RESULT")
print("Accuracy Score =",accuracy_score(predictions_SVM, Test_Y))
precision, recall, fscore, support = score(Test_Y, predictions_SVM, average='weighted')
print("Precision =", precision)
print("Recall =", recall)
print("F-score =", fscore)
# Out:
# SVM RESULT
# Accuracy Score = 0.7129411764705882
# Precision = 0.7100627052851598
# Recall = 0.7129411764705882
# F-score = 0.6374564747303084
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # **Random-forest-Classifier Algorithm**
# > **data training 70% dan data testing 30% dengan menjadikan test_size=0.3**

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# > **Classifier - Random-forest Algorithm**

# %%
# from sklearn.model_selection import train_test_split
# from sklearn import model_selection

# fit the training dataset on the classifier
# rf_clf = RandomForestClassifier(n_estimators=100, max_depth= 'None', max_features='auto', bootstrap=True, min_samples_leaf=1, min_samples_split=2)
rf_clf = RandomForestClassifier()
rf_clf.fit(Train_X_Tfidf, Train_Y)

# predict the labels on validation dataset
predictions_RFC = rf_clf.predict(Test_X_Tfidf )

# %% [markdown]
# > **Visualize Classifier - Random-forest Algorithm**

# %%
# visualize classifier Random-forest algorithm toward the data
conf_matrix = confusion_matrix(Test_Y, predictions_RFC)
class_label = ["NEGATIF", "NETRAL", "POSITIF"]
test = pd.DataFrame(conf_matrix, index = class_label, columns = class_label)
sns.heatmap(test, annot = True, fmt = "d")
plt.title("Confusion Matrix Random-Forest")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
# RANDOM FOREST RESULT
print("RANDOM FOREST RESULT")
print("Accuracy Score =",accuracy_score(predictions_RFC, Test_Y))
precision, recall, fscore, support = score(Test_Y, predictions_RFC, average='weighted')
print("Precision =", precision)
print("Recall =", recall)
print("F-score =", fscore)
# Out:
# RANDOM FOREST RESULT
# Accuracy Score = 0.8658823529411764
# Precision = 0.8655218216318786
# Recall = 0.8658823529411764
# F-score = 0.8468277635240175

# %% [markdown]
# # **SVM Classifier Algorithm (Support vector machine Algorithm)**
# > **data training 80% dan data testing 20% dengan menjadikan test_size=0.2**

# %% [markdown]
# ## **Hold-Out Method**

# %%
corpus = pd.read_excel('/content/drive/MyDrive/SKRIPSI_TEXT_MINING/sample_reviews_2.1.xlsx')

# %%
corpus.head()
# Out:
#           username  ...    label
# 0           pqrzan  ...   netral
# 1     mcreativepky  ...   netral
# 2        veemarisa  ...   netral
# 3          GSaraw4  ...  positif
# 4  Papalov03973158  ...   netral
#
# [5 rows x 12 columns]

# %% [markdown]
# > **Text Classification dan Kalkulasi Akurasi**
# - data training 80% dan data testing 20% dengan menjadikan test_size=0.2

# %%
#rename colume text_lemmatized into text_final
corpus = corpus.rename(columns={'text_lemmatized':'text_final'})

#HOLD-OUT - Dividing testing and training data
Train_X,Test_X,Train_Y,Test_Y = train_test_split(corpus['text_final'],corpus['label'],test_size=0.2)

# Label encode - transform Categorical data of string (negatif, netral, positif) into numerical values (0,1,2)
Encoder = LabelEncoder()
Train_Y = Encoder.fit_transform(Train_Y)
Test_Y = Encoder.fit_transform(Test_Y)

# %%
#TF-IDF Vectorizer 
Tfidf_vect = TfidfVectorizer(max_features=5000)
Tfidf_vect.fit(corpus['text_final'])

Train_X_Tfidf = Tfidf_vect.transform(Train_X)
Test_X_Tfidf = Tfidf_vect.transform(Test_X)

#CHECKING
print(Tfidf_vect.vocabulary_)
print(Train_X_Tfidf)
# Out:
# {'cross': 628, 'stat': 2702, 'allow': 89, 'roadblock': 2415, 'check': 473, 'person': 2096, 'either': 834, 'complet': 549, 'vaccin': 3041, 'keep': 1438, 'covid': 612, 'tangkelil': 2842, 'puskesk': 2282, 'build': 396, 'batu': 274, 'polic': 2158, 'chief': 476, 'personnel': 2097, 'pam': 1999, 'control': 581, 'movement': 1806, 'refus': 2347, 'receiv': 2331, 'inject': 1297, 'freedom': 1029, 'save': 2471, 'famili': 951, 'prove': 2252, 'safe': 2447, 'import': 1259, 'done': 766, 'increas': 1272, 'bodi': 354, 'immun': 1254, 'avoid': 211, 'spread': 2682, 'individu': 1280, 'take': 2827, 'still': 2711, 'countri': 605, 'need': 1860, 'adher': 37, 'exist': 919, 'sop': 2653, 'like': 1571, 'enthusiasm': 874, 'commun': 544, 'particip': 2027, 'high': 1181, 'proven': 2253, 'commemor': 538, 'tni': 2925, 'anniversari': 122, 'east': 821, 'java': 1361, 'region': 2352, 'appreci': 158, 'simultan': 2587, 'creation': 621, 'herd': 1175, 'pandem': 2007, 'humanitarian': 1225, 'problem': 2225, 'across': 25, 'nation': 1847, 'alhamdulillah': 84, 'dki': 756, 'jakarta': 1350, 'provinci': 2256, 'govern': 1092, 'collabor': 526, 'deng': 699, 'lead': 1544, 'coordin': 591, 'meet': 1709, 'acceler': 14, 'aglomer': 61, 'regenc': 2349, 'citi': 501, 'let': 1561, 'immedi': 1253, 'order': 1963, 'reduc': 2343, 'number': 1910, 'must': 1825, 'compli': 550, 'health': 1160, 'protocol': 2249, 'make': 1639, 'sure': 2786, 'base': 269, 'circular': 497, 'hk': 1189, 'concern': 556, 'menu': 1728, 'prepar': 2202, 'agenc': 58, 'three': 2904, 'pillar': 2125, 'desa': 707, 'bungatang': 403, 'hold': 1196, 'deliber': 688, 'process': 2229, 'continu': 577, 'run': 2433, 'around': 170, 'world': 3181, 'regardless': 2348, 'whether': 3147, 'benefici': 295, 'resid': 2386, 'enthusiast': 875, 'member': 1718, 'panarukan': 2004, 'siamap': 2573, 'siaman': 2572, 'carri': 435, 'secur': 2505, 'statu': 2707, 'involv': 1329, 'student': 2731
#   (2, 3041)	0.0583568810751658
#   (2, 2928)	0.31315127489603317
#   (2, 2505)	0.25862072796923097
#   (2, 2489)	0.37533322074384107
#   (2, 2305)	0.37533322074384107
#   (2, 1060)	0.37533322074384107
#   (2, 384)	0.35520761835168296
#   (2, 322)	0.30652333167455287
#   :	:
#   (1128, 3041)	0.06911549981252775
#   (1128, 2231)	0.39066362294813234
#   (1128, 2204)	0.276270065905176
#   (1128, 1847)	0.24458426222999005
#   (1128, 1799)	0.4037814868836394
#   (1128, 1387)	0.25077805497208044
#   (1128, 855)	0.36303367970608685
#   (1128, 426)	0.4037814868836394
#   (1128, 14)	0.24265665808580525
#   (1128, 8)	0.3561096085126702
#   (1129, 3228)	0.7762891687837298
#   (1129, 3203)	0.25876305626124324
#   (1129, 3041)	0.08046505913309353
#   (1129, 2236)	0.16283191774442657
#   (1129, 2229)	0.20042648758935555
#   (1129, 1825)	0.16283191774442657
#   (1129, 1697)	0.20368800691564162
#   (1129, 1397)	0.25876305626124324
#   (1129, 1009)	0.19470988809513
#   (1129, 737)	0.15624894153986965
#   (1129, 341)	0.24488801910420027
#   (1130, 3041)	0.09851183728116533
#   (1130, 2409)	0.5075708329277093
#   (1130, 1828)	0.6335973493941207
#   (1130, 185)	0.5755186064040894

# %% [markdown]
# ## **SVM Classifier Algorithm (Support vector machine Algorithm)**

# %%
# fit the training dataset on the classifier
#SVM = svm.SVC(C=1.0, kernel='rbf', degree=3, gamma='scale')
SVM = svm.SVC()
SVM.fit(Train_X_Tfidf,Train_Y)

# predict the labels on validation dataset
predictions_SVM = SVM.predict(Test_X_Tfidf)

# %%
# visualize classifier SVM algorithm toward the data
conf_matrix = confusion_matrix(Test_Y, predictions_SVM)
class_label = ["NEGATIF", "NETRAL", "POSITIF"]
test = pd.DataFrame(conf_matrix, index = class_label, columns = class_label)
sns.heatmap(test, annot = True, fmt = "d")
plt.title("Confusion Matrix SVM")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
# SVM RESULT
print("SVM RESULT")
print("Accuracy Score =",accuracy_score(predictions_SVM, Test_Y))
precision, recall, fscore, support = score(Test_Y, predictions_SVM, average='weighted')
print("Precision =", precision)
print("Recall =", recall)
print("F-score =", fscore)
# Out:
# SVM RESULT
# Accuracy Score = 0.7667844522968198
# Precision = 0.7313537126878373
# Recall = 0.7667844522968198
# F-score = 0.7044077805964724
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # **Random-forest-Classifier Algorithm**
# > **data training 80% dan data testing 20% dengan menjadikan test_size=0.2**

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# > **Classifier - Random-forest Algorithm**

# %%
# from sklearn.model_selection import train_test_split
# from sklearn import model_selection

# fit the training dataset on the classifier
# rf_clf = RandomForestClassifier(n_estimators=100, max_depth= 'None', max_features='auto', bootstrap=True, min_samples_leaf=1, min_samples_split=2)
rf_clf = RandomForestClassifier()
rf_clf.fit(Train_X_Tfidf, Train_Y)

# predict the labels on validation dataset
predictions_RFC = rf_clf.predict(Test_X_Tfidf )

# %% [markdown]
# > **Visualize Classifier - Random-forest Algorithm**

# %%
# visualize classifier Random-forest algorithm toward the data
conf_matrix = confusion_matrix(Test_Y, predictions_RFC)
class_label = ["NEGATIF", "NETRAL", "POSITIF"]
test = pd.DataFrame(conf_matrix, index = class_label, columns = class_label)
sns.heatmap(test, annot = True, fmt = "d")
plt.title("Confusion Matrix Random-Forest")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
# RANDOM FOREST RESULT
print("RANDOM FOREST RESULT")
print("Accuracy Score =",accuracy_score(predictions_RFC, Test_Y))
precision, recall, fscore, support = score(Test_Y, predictions_RFC, average='weighted')
print("Precision =", precision)
print("Recall =", recall)
print("F-score =", fscore)
# Out:
# RANDOM FOREST RESULT
# Accuracy Score = 0.8975265017667845
# Precision = 0.9010581713569883
# Recall = 0.8975265017667845
# F-score = 0.8882672415283467
